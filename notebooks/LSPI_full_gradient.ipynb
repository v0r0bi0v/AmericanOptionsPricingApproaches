# %%
if 'already_executed' not in globals():
    already_executed = False

if not already_executed:
    import os
    os.chdir("../")
    # %load_ext autoreload
    # %autoreload 2
    already_executed = True

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from src.pricers.pricers import LSPIFullGradientPricer as LSPIPricer
from src.samplers.samplers import GeometricBrownianMotionPutSampler

# %%
sampler = GeometricBrownianMotionPutSampler(**{
    "asset0": 100.0,
    "sigma": 0.2,
    "r": 0.05,
    "strike": 100.0,
    "t": 1.0,
    "cnt_times": 365,
    "seed": 42, 
    "cnt_trajectories": 1_000_0
})

# %%
pricer = LSPIPricer(sampler=sampler, **{
    "iterations": 1000,
    "lambda_reg": 0,
    "tol": 1e-9
})

# %%
pricer.price(test=False, quiet=False)
# Out:
# GBM sampling:   0%|          | 0/364 [00:00<?, ?it/s]
# Iteration 0: ||Δw|| = 695.992214758
# Iteration 1: ||Δw|| = 1597.608943414
# Iteration 2: ||Δw|| = 312.066840185
# Iteration 3: ||Δw|| = 210.921352020
# Iteration 4: ||Δw|| = 107.598670567
# Iteration 5: ||Δw|| = 34.711512733
# Iteration 6: ||Δw|| = 13.018790900
# Iteration 7: ||Δw|| = 71.288149631
# Iteration 8: ||Δw|| = 69.321028893
# Iteration 9: ||Δw|| = 8.476018359
# Iteration 10: ||Δw|| = 5.565454596
# Iteration 11: ||Δw|| = 0.605510539
# Iteration 12: ||Δw|| = 2.911046250
# Iteration 13: ||Δw|| = 6.927395104
# Iteration 14: ||Δw|| = 3.484212527
# Iteration 15: ||Δw|| = 1.520782983
# Iteration 16: ||Δw|| = 3.238229107
# Iteration 17: ||Δw|| = 6.917477555
# Iteration 18: ||Δw|| = 3.477017143
# Iteration 19: ||Δw|| = 1.523465735
# Iteration 20: ||Δw|| = 3.231959190
# Iteration 21: ||Δw|| = 6.917477555
# Iteration 22: ||Δw|| = 3.477017143
# Iteration 23: ||Δw|| = 1.523465735
# Iteration 24: ||Δw|| = 3.231959190
# Iteration 25: ||Δw|| = 6.917477555
# Iteration 26: ||Δw|| = 3.477017143
# Iteration 27: ||Δw|| = 1.523465735
# Iteration 28: ||Δw|| = 3.231959190
# Iteration 29: ||Δw|| = 6.917477555
# Iteration 30: ||Δw|| = 3.477017143
# Iteration 31: ||Δw|| = 1.523465735
# Iteration 32: ||Δw|| = 3.231959190
# Iteration 33: ||Δw|| = 6.917477555
# Iteration 34: ||Δw|| = 3.477017143
# Iteration 35: ||Δw|| = 1.523465735
# Iteration 36: ||Δw|| = 3.231959190
# Iteration 37: ||Δw|| = 6.917477555
# Iteration 38: ||Δw|| = 3.477017143
# Iteration 39: ||Δw|| = 1.523465735
# Iteration 40: ||Δw|| = 3.231959190
# Iteration 41: ||Δw|| = 6.917477555
# Iteration 42: ||Δw|| = 3.477017143
# Iteration 43: ||Δw|| = 1.523465735
# Iteration 44: ||Δw|| = 3.231959190
# Iteration 45: ||Δw|| = 6.917477555
# Iteration 46: ||Δw|| = 3.477017143
# Iteration 47: ||Δw|| = 1.523465735
# Iteration 48: ||Δw|| = 3.231959190
# Iteration 49: ||Δw|| = 6.917477555
# Iteration 50: ||Δw|| = 3.477017143
# Iteration 51: ||Δw|| = 1.523465735
# Iteration 52: ||Δw|| = 3.231959190
# Iteration 53: ||Δw|| = 6.917477555
# Iteration 54: ||Δw|| = 3.477017143
# Iteration 55: ||Δw|| = 1.523465735
# Iteration 56: ||Δw|| = 3.231959190
# Iteration 57: ||Δw|| = 6.917477555
# Iteration 58: ||Δw|| = 3.477017143
# Iteration 59: ||Δw|| = 1.523465735
# Iteration 60: ||Δw|| = 3.231959190
# Iteration 61: ||Δw|| = 6.917477555
# Iteration 62: ||Δw|| = 3.477017143
# Iteration 63: ||Δw|| = 1.523465735
# Iteration 64: ||Δw|| = 3.231959190
# Iteration 65: ||Δw|| = 6.917477555
# Iteration 66: ||Δw|| = 3.477017143
# Iteration 67: ||Δw|| = 1.523465735
# Iteration 68: ||Δw|| = 3.231959190
# Iteration 69: ||Δw|| = 6.917477555
# Iteration 70: ||Δw|| = 3.477017143
# Iteration 71: ||Δw|| = 1.523465735
# Iteration 72: ||Δw|| = 3.231959190
# Iteration 73: ||Δw|| = 6.917477555
# Iteration 74: ||Δw|| = 3.477017143
# Iteration 75: ||Δw|| = 1.523465735
# Iteration 76: ||Δw|| = 3.231959190
# Iteration 77: ||Δw|| = 6.917477555
# Iteration 78: ||Δw|| = 3.477017143
# Iteration 79: ||Δw|| = 1.523465735
# Iteration 80: ||Δw|| = 3.231959190
# Iteration 81: ||Δw|| = 6.917477555
# Iteration 82: ||Δw|| = 3.477017143
# Iteration 83: ||Δw|| = 1.523465735
# Iteration 84: ||Δw|| = 3.231959190
# Iteration 85: ||Δw|| = 6.917477555
# Iteration 86: ||Δw|| = 3.477017143
# Iteration 87: ||Δw|| = 1.523465735
# Iteration 88: ||Δw|| = 3.231959190
# Iteration 89: ||Δw|| = 6.917477555
# Iteration 90: ||Δw|| = 3.477017143
# Iteration 91: ||Δw|| = 1.523465735
# Iteration 92: ||Δw|| = 3.231959190
# Iteration 93: ||Δw|| = 6.917477555
# Iteration 94: ||Δw|| = 3.477017143
# Iteration 95: ||Δw|| = 1.523465735
# Iteration 96: ||Δw|| = 3.231959190
# Iteration 97: ||Δw|| = 6.917477555
# Iteration 98: ||Δw|| = 3.477017143
# Iteration 99: ||Δw|| = 1.523465735
# Iteration 100: ||Δw|| = 3.231959190
# Iteration 101: ||Δw|| = 6.917477555
# Iteration 102: ||Δw|| = 3.477017143
# Iteration 103: ||Δw|| = 1.523465735
# Iteration 104: ||Δw|| = 3.231959190
# Iteration 105: ||Δw|| = 6.917477555
# Iteration 106: ||Δw|| = 3.477017143
# Iteration 107: ||Δw|| = 1.523465735
# Iteration 108: ||Δw|| = 3.231959190
# Iteration 109: ||Δw|| = 6.917477555
# Iteration 110: ||Δw|| = 3.477017143
# Iteration 111: ||Δw|| = 1.523465735
# Iteration 112: ||Δw|| = 3.231959190
# Iteration 113: ||Δw|| = 6.917477555
# Iteration 114: ||Δw|| = 3.477017143
# Iteration 115: ||Δw|| = 1.523465735
# Iteration 116: ||Δw|| = 3.231959190
# Iteration 117: ||Δw|| = 6.917477555
# Iteration 118: ||Δw|| = 3.477017143
# Iteration 119: ||Δw|| = 1.523465735
# Iteration 120: ||Δw|| = 3.231959190
# Iteration 121: ||Δw|| = 6.917477555
# Iteration 122: ||Δw|| = 3.477017143
# Iteration 123: ||Δw|| = 1.523465735
# Iteration 124: ||Δw|| = 3.231959190
# Iteration 125: ||Δw|| = 6.917477555
# Iteration 126: ||Δw|| = 3.477017143
# Iteration 127: ||Δw|| = 1.523465735
# Iteration 128: ||Δw|| = 3.231959190
# Iteration 129: ||Δw|| = 6.917477555
# Iteration 130: ||Δw|| = 3.477017143
# Iteration 131: ||Δw|| = 1.523465735
# Iteration 132: ||Δw|| = 3.231959190
# Iteration 133: ||Δw|| = 6.917477555
# Iteration 134: ||Δw|| = 3.477017143
# Iteration 135: ||Δw|| = 1.523465735
# Iteration 136: ||Δw|| = 3.231959190
# Iteration 137: ||Δw|| = 6.917477555
# Iteration 138: ||Δw|| = 3.477017143
# Iteration 139: ||Δw|| = 1.523465735
# Iteration 140: ||Δw|| = 3.231959190
# Iteration 141: ||Δw|| = 6.917477555
# Iteration 142: ||Δw|| = 3.477017143
# Iteration 143: ||Δw|| = 1.523465735
# Iteration 144: ||Δw|| = 3.231959190
# Iteration 145: ||Δw|| = 6.917477555
# Iteration 146: ||Δw|| = 3.477017143
# Iteration 147: ||Δw|| = 1.523465735
# Iteration 148: ||Δw|| = 3.231959190
# Iteration 149: ||Δw|| = 6.917477555
# Iteration 150: ||Δw|| = 3.477017143
# Iteration 151: ||Δw|| = 1.523465735
# Iteration 152: ||Δw|| = 3.231959190
# Iteration 153: ||Δw|| = 6.917477555
# Iteration 154: ||Δw|| = 3.477017143
# Iteration 155: ||Δw|| = 1.523465735
# Iteration 156: ||Δw|| = 3.231959190
# Iteration 157: ||Δw|| = 6.917477555
# Iteration 158: ||Δw|| = 3.477017143
# Iteration 159: ||Δw|| = 1.523465735
# Iteration 160: ||Δw|| = 3.231959190
# Iteration 161: ||Δw|| = 6.917477555
# Iteration 162: ||Δw|| = 3.477017143
# Iteration 163: ||Δw|| = 1.523465735
# Iteration 164: ||Δw|| = 3.231959190
# Iteration 165: ||Δw|| = 6.917477555
# Iteration 166: ||Δw|| = 3.477017143
# Iteration 167: ||Δw|| = 1.523465735
# Iteration 168: ||Δw|| = 3.231959190
# Iteration 169: ||Δw|| = 6.917477555
# Iteration 170: ||Δw|| = 3.477017143
# Iteration 171: ||Δw|| = 1.523465735
# Iteration 172: ||Δw|| = 3.231959190
# Iteration 173: ||Δw|| = 6.917477555
# Iteration 174: ||Δw|| = 3.477017143
# Iteration 175: ||Δw|| = 1.523465735
# Iteration 176: ||Δw|| = 3.231959190
# Iteration 177: ||Δw|| = 6.917477555
# Iteration 178: ||Δw|| = 3.477017143
# Iteration 179: ||Δw|| = 1.523465735
# Iteration 180: ||Δw|| = 3.231959190
# Iteration 181: ||Δw|| = 6.917477555
# Iteration 182: ||Δw|| = 3.477017143
# Iteration 183: ||Δw|| = 1.523465735
# Iteration 184: ||Δw|| = 3.231959190
# Iteration 185: ||Δw|| = 6.917477555
# Iteration 186: ||Δw|| = 3.477017143
# Iteration 187: ||Δw|| = 1.523465735
# Iteration 188: ||Δw|| = 3.231959190
# Iteration 189: ||Δw|| = 6.917477555
# Iteration 190: ||Δw|| = 3.477017143
# Iteration 191: ||Δw|| = 1.523465735
# Iteration 192: ||Δw|| = 3.231959190
# Iteration 193: ||Δw|| = 6.917477555
# Iteration 194: ||Δw|| = 3.477017143
# Iteration 195: ||Δw|| = 1.523465735
# Iteration 196: ||Δw|| = 3.231959190
# Iteration 197: ||Δw|| = 6.917477555
# Iteration 198: ||Δw|| = 3.477017143
# Iteration 199: ||Δw|| = 1.523465735
# Iteration 200: ||Δw|| = 3.231959190
# Iteration 201: ||Δw|| = 6.917477555
# Iteration 202: ||Δw|| = 3.477017143
# Iteration 203: ||Δw|| = 1.523465735
# Iteration 204: ||Δw|| = 3.231959190
# Iteration 205: ||Δw|| = 6.917477555
# Iteration 206: ||Δw|| = 3.477017143
# Iteration 207: ||Δw|| = 1.523465735
# Iteration 208: ||Δw|| = 3.231959190
# Iteration 209: ||Δw|| = 6.917477555
# Iteration 210: ||Δw|| = 3.477017143
# Iteration 211: ||Δw|| = 1.523465735
# Iteration 212: ||Δw|| = 3.231959190
# Iteration 213: ||Δw|| = 6.917477555
# Iteration 214: ||Δw|| = 3.477017143
# Iteration 215: ||Δw|| = 1.523465735
# Iteration 216: ||Δw|| = 3.231959190
# Iteration 217: ||Δw|| = 6.917477555
# Iteration 218: ||Δw|| = 3.477017143
# Iteration 219: ||Δw|| = 1.523465735
# Iteration 220: ||Δw|| = 3.231959190
# Iteration 221: ||Δw|| = 6.917477555
# Iteration 222: ||Δw|| = 3.477017143
# Iteration 223: ||Δw|| = 1.523465735
# Iteration 224: ||Δw|| = 3.231959190
# Iteration 225: ||Δw|| = 6.917477555
# Iteration 226: ||Δw|| = 3.477017143
# Iteration 227: ||Δw|| = 1.523465735
# Iteration 228: ||Δw|| = 3.231959190
# Iteration 229: ||Δw|| = 6.917477555
# Iteration 230: ||Δw|| = 3.477017143
# Iteration 231: ||Δw|| = 1.523465735
# Iteration 232: ||Δw|| = 3.231959190
# Iteration 233: ||Δw|| = 6.917477555
# Iteration 234: ||Δw|| = 3.477017143
# Iteration 235: ||Δw|| = 1.523465735
# Iteration 236: ||Δw|| = 3.231959190
# Iteration 237: ||Δw|| = 6.917477555
# Iteration 238: ||Δw|| = 3.477017143
# Iteration 239: ||Δw|| = 1.523465735
# Iteration 240: ||Δw|| = 3.231959190
# Iteration 241: ||Δw|| = 6.917477555
# Iteration 242: ||Δw|| = 3.477017143
# Iteration 243: ||Δw|| = 1.523465735
# Iteration 244: ||Δw|| = 3.231959190
# Iteration 245: ||Δw|| = 6.917477555
# Iteration 246: ||Δw|| = 3.477017143
# Iteration 247: ||Δw|| = 1.523465735
# Iteration 248: ||Δw|| = 3.231959190
# Iteration 249: ||Δw|| = 6.917477555
# Iteration 250: ||Δw|| = 3.477017143
# Iteration 251: ||Δw|| = 1.523465735
# Iteration 252: ||Δw|| = 3.231959190
# Iteration 253: ||Δw|| = 6.917477555
# Iteration 254: ||Δw|| = 3.477017143
# Iteration 255: ||Δw|| = 1.523465735
# Iteration 256: ||Δw|| = 3.231959190
# Iteration 257: ||Δw|| = 6.917477555
# Iteration 258: ||Δw|| = 3.477017143
# Iteration 259: ||Δw|| = 1.523465735
# Iteration 260: ||Δw|| = 3.231959190
# Iteration 261: ||Δw|| = 6.917477555
# Iteration 262: ||Δw|| = 3.477017143
# Iteration 263: ||Δw|| = 1.523465735
# Iteration 264: ||Δw|| = 3.231959190
# Iteration 265: ||Δw|| = 6.917477555
# Iteration 266: ||Δw|| = 3.477017143
# Iteration 267: ||Δw|| = 1.523465735
# Iteration 268: ||Δw|| = 3.231959190
# Iteration 269: ||Δw|| = 6.917477555
# Iteration 270: ||Δw|| = 3.477017143
# Iteration 271: ||Δw|| = 1.523465735
# Iteration 272: ||Δw|| = 3.231959190
# Iteration 273: ||Δw|| = 6.917477555
# Iteration 274: ||Δw|| = 3.477017143
# Iteration 275: ||Δw|| = 1.523465735
# Iteration 276: ||Δw|| = 3.231959190
# Iteration 277: ||Δw|| = 6.917477555
# Iteration 278: ||Δw|| = 3.477017143
# Iteration 279: ||Δw|| = 1.523465735
# Iteration 280: ||Δw|| = 3.231959190
# Iteration 281: ||Δw|| = 6.917477555
# Iteration 282: ||Δw|| = 3.477017143
# Iteration 283: ||Δw|| = 1.523465735
# Iteration 284: ||Δw|| = 3.231959190
# Iteration 285: ||Δw|| = 6.917477555
# Iteration 286: ||Δw|| = 3.477017143
# Iteration 287: ||Δw|| = 1.523465735
# Iteration 288: ||Δw|| = 3.231959190
# Iteration 289: ||Δw|| = 6.917477555
# Iteration 290: ||Δw|| = 3.477017143
# Iteration 291: ||Δw|| = 1.523465735
# Iteration 292: ||Δw|| = 3.231959190
# Iteration 293: ||Δw|| = 6.917477555
# Iteration 294: ||Δw|| = 3.477017143
# Iteration 295: ||Δw|| = 1.523465735
# Iteration 296: ||Δw|| = 3.231959190
# Iteration 297: ||Δw|| = 6.917477555
# Iteration 298: ||Δw|| = 3.477017143
# Iteration 299: ||Δw|| = 1.523465735
# Iteration 300: ||Δw|| = 3.231959190
# Iteration 301: ||Δw|| = 6.917477555
# Iteration 302: ||Δw|| = 3.477017143
# Iteration 303: ||Δw|| = 1.523465735
# Iteration 304: ||Δw|| = 3.231959190
# Iteration 305: ||Δw|| = 6.917477555
# Iteration 306: ||Δw|| = 3.477017143
# Iteration 307: ||Δw|| = 1.523465735
# Iteration 308: ||Δw|| = 3.231959190
# Iteration 309: ||Δw|| = 6.917477555
# Iteration 310: ||Δw|| = 3.477017143
# Iteration 311: ||Δw|| = 1.523465735
# Iteration 312: ||Δw|| = 3.231959190
# Iteration 313: ||Δw|| = 6.917477555
# Iteration 314: ||Δw|| = 3.477017143
# Iteration 315: ||Δw|| = 1.523465735
# Iteration 316: ||Δw|| = 3.231959190
# Iteration 317: ||Δw|| = 6.917477555
# Iteration 318: ||Δw|| = 3.477017143
# Iteration 319: ||Δw|| = 1.523465735
# Iteration 320: ||Δw|| = 3.231959190
# Iteration 321: ||Δw|| = 6.917477555
# Iteration 322: ||Δw|| = 3.477017143
# Iteration 323: ||Δw|| = 1.523465735
# Iteration 324: ||Δw|| = 3.231959190
# Iteration 325: ||Δw|| = 6.917477555
# Iteration 326: ||Δw|| = 3.477017143
# Iteration 327: ||Δw|| = 1.523465735
# Iteration 328: ||Δw|| = 3.231959190
# Iteration 329: ||Δw|| = 6.917477555
# Iteration 330: ||Δw|| = 3.477017143
# Iteration 331: ||Δw|| = 1.523465735
# Iteration 332: ||Δw|| = 3.231959190
# Iteration 333: ||Δw|| = 6.917477555
# Iteration 334: ||Δw|| = 3.477017143
# Iteration 335: ||Δw|| = 1.523465735
# Iteration 336: ||Δw|| = 3.231959190
# Iteration 337: ||Δw|| = 6.917477555
# Iteration 338: ||Δw|| = 3.477017143
# Iteration 339: ||Δw|| = 1.523465735
# Iteration 340: ||Δw|| = 3.231959190
# Iteration 341: ||Δw|| = 6.917477555
# Iteration 342: ||Δw|| = 3.477017143
# Iteration 343: ||Δw|| = 1.523465735
# Iteration 344: ||Δw|| = 3.231959190
# Iteration 345: ||Δw|| = 6.917477555
# Iteration 346: ||Δw|| = 3.477017143
# Iteration 347: ||Δw|| = 1.523465735
# Iteration 348: ||Δw|| = 3.231959190
# Iteration 349: ||Δw|| = 6.917477555
# Iteration 350: ||Δw|| = 3.477017143
# Iteration 351: ||Δw|| = 1.523465735
# Iteration 352: ||Δw|| = 3.231959190
# Iteration 353: ||Δw|| = 6.917477555
# Iteration 354: ||Δw|| = 3.477017143
# Iteration 355: ||Δw|| = 1.523465735
# Iteration 356: ||Δw|| = 3.231959190
# Iteration 357: ||Δw|| = 6.917477555
# Iteration 358: ||Δw|| = 3.477017143
# Iteration 359: ||Δw|| = 1.523465735
# Iteration 360: ||Δw|| = 3.231959190
# Iteration 361: ||Δw|| = 6.917477555
# Iteration 362: ||Δw|| = 3.477017143
# Iteration 363: ||Δw|| = 1.523465735
# Iteration 364: ||Δw|| = 3.231959190
# Iteration 365: ||Δw|| = 6.917477555
# Iteration 366: ||Δw|| = 3.477017143
# Iteration 367: ||Δw|| = 1.523465735
# Iteration 368: ||Δw|| = 3.231959190
# Iteration 369: ||Δw|| = 6.917477555
# Iteration 370: ||Δw|| = 3.477017143
# Iteration 371: ||Δw|| = 1.523465735
# Iteration 372: ||Δw|| = 3.231959190
# Iteration 373: ||Δw|| = 6.917477555
# Iteration 374: ||Δw|| = 3.477017143
# Iteration 375: ||Δw|| = 1.523465735
# Iteration 376: ||Δw|| = 3.231959190
# Iteration 377: ||Δw|| = 6.917477555
# Iteration 378: ||Δw|| = 3.477017143
# Iteration 379: ||Δw|| = 1.523465735
# Iteration 380: ||Δw|| = 3.231959190
# Iteration 381: ||Δw|| = 6.917477555
# Iteration 382: ||Δw|| = 3.477017143
# Iteration 383: ||Δw|| = 1.523465735
# Iteration 384: ||Δw|| = 3.231959190
# Iteration 385: ||Δw|| = 6.917477555
# Iteration 386: ||Δw|| = 3.477017143
# Iteration 387: ||Δw|| = 1.523465735
# Iteration 388: ||Δw|| = 3.231959190
# Iteration 389: ||Δw|| = 6.917477555
# Iteration 390: ||Δw|| = 3.477017143
# Iteration 391: ||Δw|| = 1.523465735
# Iteration 392: ||Δw|| = 3.231959190
# Iteration 393: ||Δw|| = 6.917477555
# Iteration 394: ||Δw|| = 3.477017143
# Iteration 395: ||Δw|| = 1.523465735
# Iteration 396: ||Δw|| = 3.231959190
# Iteration 397: ||Δw|| = 6.917477555
# Iteration 398: ||Δw|| = 3.477017143
# Iteration 399: ||Δw|| = 1.523465735
# Iteration 400: ||Δw|| = 3.231959190
# Iteration 401: ||Δw|| = 6.917477555
# Iteration 402: ||Δw|| = 3.477017143
# Iteration 403: ||Δw|| = 1.523465735
# Iteration 404: ||Δw|| = 3.231959190
# Iteration 405: ||Δw|| = 6.917477555
# Iteration 406: ||Δw|| = 3.477017143
# Iteration 407: ||Δw|| = 1.523465735
# Iteration 408: ||Δw|| = 3.231959190
# Iteration 409: ||Δw|| = 6.917477555
# Iteration 410: ||Δw|| = 3.477017143
# Iteration 411: ||Δw|| = 1.523465735
# Iteration 412: ||Δw|| = 3.231959190
# Iteration 413: ||Δw|| = 6.917477555
# Iteration 414: ||Δw|| = 3.477017143
# Iteration 415: ||Δw|| = 1.523465735
# Iteration 416: ||Δw|| = 3.231959190
# Iteration 417: ||Δw|| = 6.917477555
# Iteration 418: ||Δw|| = 3.477017143
# Iteration 419: ||Δw|| = 1.523465735
# Iteration 420: ||Δw|| = 3.231959190
# Iteration 421: ||Δw|| = 6.917477555
# Iteration 422: ||Δw|| = 3.477017143
# Iteration 423: ||Δw|| = 1.523465735
# Iteration 424: ||Δw|| = 3.231959190
# Iteration 425: ||Δw|| = 6.917477555
# Iteration 426: ||Δw|| = 3.477017143
# Iteration 427: ||Δw|| = 1.523465735
# Iteration 428: ||Δw|| = 3.231959190
# Iteration 429: ||Δw|| = 6.917477555
# Iteration 430: ||Δw|| = 3.477017143
# Iteration 431: ||Δw|| = 1.523465735
# Iteration 432: ||Δw|| = 3.231959190
# Iteration 433: ||Δw|| = 6.917477555
# Iteration 434: ||Δw|| = 3.477017143
# Iteration 435: ||Δw|| = 1.523465735
# Iteration 436: ||Δw|| = 3.231959190
# Iteration 437: ||Δw|| = 6.917477555
# Iteration 438: ||Δw|| = 3.477017143
# Iteration 439: ||Δw|| = 1.523465735
# Iteration 440: ||Δw|| = 3.231959190
# Iteration 441: ||Δw|| = 6.917477555
# Iteration 442: ||Δw|| = 3.477017143
# Iteration 443: ||Δw|| = 1.523465735
# Iteration 444: ||Δw|| = 3.231959190
# Iteration 445: ||Δw|| = 6.917477555
# Iteration 446: ||Δw|| = 3.477017143
# Iteration 447: ||Δw|| = 1.523465735
# Iteration 448: ||Δw|| = 3.231959190
# Iteration 449: ||Δw|| = 6.917477555
# Iteration 450: ||Δw|| = 3.477017143
# Iteration 451: ||Δw|| = 1.523465735
# Iteration 452: ||Δw|| = 3.231959190
# Iteration 453: ||Δw|| = 6.917477555
# Iteration 454: ||Δw|| = 3.477017143
# Iteration 455: ||Δw|| = 1.523465735
# Iteration 456: ||Δw|| = 3.231959190
# Iteration 457: ||Δw|| = 6.917477555
# Iteration 458: ||Δw|| = 3.477017143
# Iteration 459: ||Δw|| = 1.523465735
# Iteration 460: ||Δw|| = 3.231959190
# Iteration 461: ||Δw|| = 6.917477555
# Iteration 462: ||Δw|| = 3.477017143
# Iteration 463: ||Δw|| = 1.523465735
# Iteration 464: ||Δw|| = 3.231959190
# Iteration 465: ||Δw|| = 6.917477555
# Iteration 466: ||Δw|| = 3.477017143
# Iteration 467: ||Δw|| = 1.523465735
# Iteration 468: ||Δw|| = 3.231959190
# Iteration 469: ||Δw|| = 6.917477555
# Iteration 470: ||Δw|| = 3.477017143
# Iteration 471: ||Δw|| = 1.523465735
# Iteration 472: ||Δw|| = 3.231959190
# Iteration 473: ||Δw|| = 6.917477555
# Iteration 474: ||Δw|| = 3.477017143
# Iteration 475: ||Δw|| = 1.523465735
# Iteration 476: ||Δw|| = 3.231959190
# Iteration 477: ||Δw|| = 6.917477555
# Iteration 478: ||Δw|| = 3.477017143
# Iteration 479: ||Δw|| = 1.523465735
# Iteration 480: ||Δw|| = 3.231959190
# Iteration 481: ||Δw|| = 6.917477555
# Iteration 482: ||Δw|| = 3.477017143
# Iteration 483: ||Δw|| = 1.523465735
# Iteration 484: ||Δw|| = 3.231959190
# Iteration 485: ||Δw|| = 6.917477555
# Iteration 486: ||Δw|| = 3.477017143
# Iteration 487: ||Δw|| = 1.523465735
# Iteration 488: ||Δw|| = 3.231959190
# Iteration 489: ||Δw|| = 6.917477555
# Iteration 490: ||Δw|| = 3.477017143
# Iteration 491: ||Δw|| = 1.523465735
# Iteration 492: ||Δw|| = 3.231959190
# Iteration 493: ||Δw|| = 6.917477555
# Iteration 494: ||Δw|| = 3.477017143
# Iteration 495: ||Δw|| = 1.523465735
# Iteration 496: ||Δw|| = 3.231959190
# Iteration 497: ||Δw|| = 6.917477555
# Iteration 498: ||Δw|| = 3.477017143
# Iteration 499: ||Δw|| = 1.523465735
# Iteration 500: ||Δw|| = 3.231959190
# Iteration 501: ||Δw|| = 6.917477555
# Iteration 502: ||Δw|| = 3.477017143
# Iteration 503: ||Δw|| = 1.523465735
# Iteration 504: ||Δw|| = 3.231959190
# Iteration 505: ||Δw|| = 6.917477555
# Iteration 506: ||Δw|| = 3.477017143
# Iteration 507: ||Δw|| = 1.523465735
# Iteration 508: ||Δw|| = 3.231959190
# Iteration 509: ||Δw|| = 6.917477555
# Iteration 510: ||Δw|| = 3.477017143
# Iteration 511: ||Δw|| = 1.523465735
# Iteration 512: ||Δw|| = 3.231959190
# Iteration 513: ||Δw|| = 6.917477555
# Iteration 514: ||Δw|| = 3.477017143
# Iteration 515: ||Δw|| = 1.523465735
# Iteration 516: ||Δw|| = 3.231959190
# Iteration 517: ||Δw|| = 6.917477555
# Iteration 518: ||Δw|| = 3.477017143
# Iteration 519: ||Δw|| = 1.523465735
# Iteration 520: ||Δw|| = 3.231959190
# Iteration 521: ||Δw|| = 6.917477555
# Iteration 522: ||Δw|| = 3.477017143
# Iteration 523: ||Δw|| = 1.523465735
# Iteration 524: ||Δw|| = 3.231959190
# Iteration 525: ||Δw|| = 6.917477555
# Iteration 526: ||Δw|| = 3.477017143
# Iteration 527: ||Δw|| = 1.523465735
# Iteration 528: ||Δw|| = 3.231959190
# Iteration 529: ||Δw|| = 6.917477555
# Iteration 530: ||Δw|| = 3.477017143
# Iteration 531: ||Δw|| = 1.523465735
# Iteration 532: ||Δw|| = 3.231959190
# Iteration 533: ||Δw|| = 6.917477555
# Iteration 534: ||Δw|| = 3.477017143
# Iteration 535: ||Δw|| = 1.523465735
# Iteration 536: ||Δw|| = 3.231959190
# Iteration 537: ||Δw|| = 6.917477555
# Iteration 538: ||Δw|| = 3.477017143
# Iteration 539: ||Δw|| = 1.523465735
# Iteration 540: ||Δw|| = 3.231959190
# Iteration 541: ||Δw|| = 6.917477555
# Iteration 542: ||Δw|| = 3.477017143
# Iteration 543: ||Δw|| = 1.523465735
# Iteration 544: ||Δw|| = 3.231959190
# Iteration 545: ||Δw|| = 6.917477555
# Iteration 546: ||Δw|| = 3.477017143
# Iteration 547: ||Δw|| = 1.523465735
# Iteration 548: ||Δw|| = 3.231959190
# Iteration 549: ||Δw|| = 6.917477555
# Iteration 550: ||Δw|| = 3.477017143
# Iteration 551: ||Δw|| = 1.523465735
# Iteration 552: ||Δw|| = 3.231959190
# Iteration 553: ||Δw|| = 6.917477555
# Iteration 554: ||Δw|| = 3.477017143
# Iteration 555: ||Δw|| = 1.523465735
# Iteration 556: ||Δw|| = 3.231959190
# Iteration 557: ||Δw|| = 6.917477555
# Iteration 558: ||Δw|| = 3.477017143
# Iteration 559: ||Δw|| = 1.523465735
# Iteration 560: ||Δw|| = 3.231959190
# Iteration 561: ||Δw|| = 6.917477555
# Iteration 562: ||Δw|| = 3.477017143
# Iteration 563: ||Δw|| = 1.523465735
# Iteration 564: ||Δw|| = 3.231959190
# Iteration 565: ||Δw|| = 6.917477555
# Iteration 566: ||Δw|| = 3.477017143
# Iteration 567: ||Δw|| = 1.523465735
# Iteration 568: ||Δw|| = 3.231959190
# Iteration 569: ||Δw|| = 6.917477555
# Iteration 570: ||Δw|| = 3.477017143
# Iteration 571: ||Δw|| = 1.523465735
# Iteration 572: ||Δw|| = 3.231959190
# Iteration 573: ||Δw|| = 6.917477555
# Iteration 574: ||Δw|| = 3.477017143
# Iteration 575: ||Δw|| = 1.523465735
# Iteration 576: ||Δw|| = 3.231959190
# Iteration 577: ||Δw|| = 6.917477555
# Iteration 578: ||Δw|| = 3.477017143
# Iteration 579: ||Δw|| = 1.523465735
# Iteration 580: ||Δw|| = 3.231959190
# Iteration 581: ||Δw|| = 6.917477555
# Iteration 582: ||Δw|| = 3.477017143
# Iteration 583: ||Δw|| = 1.523465735
# Iteration 584: ||Δw|| = 3.231959190
# Iteration 585: ||Δw|| = 6.917477555
# Iteration 586: ||Δw|| = 3.477017143
# Iteration 587: ||Δw|| = 1.523465735
# Iteration 588: ||Δw|| = 3.231959190
# Iteration 589: ||Δw|| = 6.917477555
# Iteration 590: ||Δw|| = 3.477017143
# Iteration 591: ||Δw|| = 1.523465735
# Iteration 592: ||Δw|| = 3.231959190
# Iteration 593: ||Δw|| = 6.917477555
# Iteration 594: ||Δw|| = 3.477017143
# Iteration 595: ||Δw|| = 1.523465735
# Iteration 596: ||Δw|| = 3.231959190
# Iteration 597: ||Δw|| = 6.917477555
# Iteration 598: ||Δw|| = 3.477017143
# Iteration 599: ||Δw|| = 1.523465735
# Iteration 600: ||Δw|| = 3.231959190
# Iteration 601: ||Δw|| = 6.917477555
# Iteration 602: ||Δw|| = 3.477017143
# Iteration 603: ||Δw|| = 1.523465735
# Iteration 604: ||Δw|| = 3.231959190
# Iteration 605: ||Δw|| = 6.917477555
# Iteration 606: ||Δw|| = 3.477017143
# Iteration 607: ||Δw|| = 1.523465735
# Iteration 608: ||Δw|| = 3.231959190
# Iteration 609: ||Δw|| = 6.917477555
# Iteration 610: ||Δw|| = 3.477017143
# Iteration 611: ||Δw|| = 1.523465735
# Iteration 612: ||Δw|| = 3.231959190
# Iteration 613: ||Δw|| = 6.917477555
# Iteration 614: ||Δw|| = 3.477017143
# Iteration 615: ||Δw|| = 1.523465735
# Iteration 616: ||Δw|| = 3.231959190
# Iteration 617: ||Δw|| = 6.917477555
# Iteration 618: ||Δw|| = 3.477017143
# Iteration 619: ||Δw|| = 1.523465735
# Iteration 620: ||Δw|| = 3.231959190
# Iteration 621: ||Δw|| = 6.917477555
# Iteration 622: ||Δw|| = 3.477017143
# Iteration 623: ||Δw|| = 1.523465735
# Iteration 624: ||Δw|| = 3.231959190
# Iteration 625: ||Δw|| = 6.917477555
# Iteration 626: ||Δw|| = 3.477017143
# Iteration 627: ||Δw|| = 1.523465735
# Iteration 628: ||Δw|| = 3.231959190
# Iteration 629: ||Δw|| = 6.917477555
# Iteration 630: ||Δw|| = 3.477017143
# Iteration 631: ||Δw|| = 1.523465735
# Iteration 632: ||Δw|| = 3.231959190
# Iteration 633: ||Δw|| = 6.917477555
# Iteration 634: ||Δw|| = 3.477017143
# Iteration 635: ||Δw|| = 1.523465735
# Iteration 636: ||Δw|| = 3.231959190
# Iteration 637: ||Δw|| = 6.917477555
# Iteration 638: ||Δw|| = 3.477017143
# Iteration 639: ||Δw|| = 1.523465735
# Iteration 640: ||Δw|| = 3.231959190
# Iteration 641: ||Δw|| = 6.917477555
# Iteration 642: ||Δw|| = 3.477017143
# Iteration 643: ||Δw|| = 1.523465735
# Iteration 644: ||Δw|| = 3.231959190
# Iteration 645: ||Δw|| = 6.917477555
# Iteration 646: ||Δw|| = 3.477017143
# Iteration 647: ||Δw|| = 1.523465735
# Iteration 648: ||Δw|| = 3.231959190
# Iteration 649: ||Δw|| = 6.917477555
# Iteration 650: ||Δw|| = 3.477017143
# Iteration 651: ||Δw|| = 1.523465735
# Iteration 652: ||Δw|| = 3.231959190
# Iteration 653: ||Δw|| = 6.917477555
# Iteration 654: ||Δw|| = 3.477017143
# Iteration 655: ||Δw|| = 1.523465735
# Iteration 656: ||Δw|| = 3.231959190
# Iteration 657: ||Δw|| = 6.917477555
# Iteration 658: ||Δw|| = 3.477017143
# Iteration 659: ||Δw|| = 1.523465735
# Iteration 660: ||Δw|| = 3.231959190
# Iteration 661: ||Δw|| = 6.917477555
# Iteration 662: ||Δw|| = 3.477017143
# Iteration 663: ||Δw|| = 1.523465735
# Iteration 664: ||Δw|| = 3.231959190
# Iteration 665: ||Δw|| = 6.917477555
# Iteration 666: ||Δw|| = 3.477017143
# Iteration 667: ||Δw|| = 1.523465735
# Iteration 668: ||Δw|| = 3.231959190
# Iteration 669: ||Δw|| = 6.917477555
# Iteration 670: ||Δw|| = 3.477017143
# Iteration 671: ||Δw|| = 1.523465735
# Iteration 672: ||Δw|| = 3.231959190
# Iteration 673: ||Δw|| = 6.917477555
# Iteration 674: ||Δw|| = 3.477017143
# Iteration 675: ||Δw|| = 1.523465735
# Iteration 676: ||Δw|| = 3.231959190
# Iteration 677: ||Δw|| = 6.917477555
# Iteration 678: ||Δw|| = 3.477017143
# Iteration 679: ||Δw|| = 1.523465735
# Iteration 680: ||Δw|| = 3.231959190
# Iteration 681: ||Δw|| = 6.917477555
# Iteration 682: ||Δw|| = 3.477017143
# Iteration 683: ||Δw|| = 1.523465735
# Iteration 684: ||Δw|| = 3.231959190
# Iteration 685: ||Δw|| = 6.917477555
# Iteration 686: ||Δw|| = 3.477017143
# Iteration 687: ||Δw|| = 1.523465735
# Iteration 688: ||Δw|| = 3.231959190
# Iteration 689: ||Δw|| = 6.917477555
# Iteration 690: ||Δw|| = 3.477017143
# Iteration 691: ||Δw|| = 1.523465735
# Iteration 692: ||Δw|| = 3.231959190
# Iteration 693: ||Δw|| = 6.917477555
# Iteration 694: ||Δw|| = 3.477017143
# Iteration 695: ||Δw|| = 1.523465735
# Iteration 696: ||Δw|| = 3.231959190
# Iteration 697: ||Δw|| = 6.917477555
# Iteration 698: ||Δw|| = 3.477017143
# Iteration 699: ||Δw|| = 1.523465735
# Iteration 700: ||Δw|| = 3.231959190
# Iteration 701: ||Δw|| = 6.917477555
# Iteration 702: ||Δw|| = 3.477017143
# Iteration 703: ||Δw|| = 1.523465735
# Iteration 704: ||Δw|| = 3.231959190
# Iteration 705: ||Δw|| = 6.917477555
# Iteration 706: ||Δw|| = 3.477017143
# Iteration 707: ||Δw|| = 1.523465735
# Iteration 708: ||Δw|| = 3.231959190
# Iteration 709: ||Δw|| = 6.917477555
# Iteration 710: ||Δw|| = 3.477017143
# Iteration 711: ||Δw|| = 1.523465735
# Iteration 712: ||Δw|| = 3.231959190
# Iteration 713: ||Δw|| = 6.917477555
# Iteration 714: ||Δw|| = 3.477017143
# Iteration 715: ||Δw|| = 1.523465735
# Iteration 716: ||Δw|| = 3.231959190
# Iteration 717: ||Δw|| = 6.917477555
# Iteration 718: ||Δw|| = 3.477017143
# Iteration 719: ||Δw|| = 1.523465735
# Iteration 720: ||Δw|| = 3.231959190
# Iteration 721: ||Δw|| = 6.917477555
# Iteration 722: ||Δw|| = 3.477017143
# Iteration 723: ||Δw|| = 1.523465735
# Iteration 724: ||Δw|| = 3.231959190
# Iteration 725: ||Δw|| = 6.917477555
# Iteration 726: ||Δw|| = 3.477017143
# Iteration 727: ||Δw|| = 1.523465735
# Iteration 728: ||Δw|| = 3.231959190
# Iteration 729: ||Δw|| = 6.917477555
# Iteration 730: ||Δw|| = 3.477017143
# Iteration 731: ||Δw|| = 1.523465735
# Iteration 732: ||Δw|| = 3.231959190
# Iteration 733: ||Δw|| = 6.917477555
# Iteration 734: ||Δw|| = 3.477017143
# Iteration 735: ||Δw|| = 1.523465735
# Iteration 736: ||Δw|| = 3.231959190
# Iteration 737: ||Δw|| = 6.917477555
# Iteration 738: ||Δw|| = 3.477017143
# Iteration 739: ||Δw|| = 1.523465735
# Iteration 740: ||Δw|| = 3.231959190
# Iteration 741: ||Δw|| = 6.917477555
# Iteration 742: ||Δw|| = 3.477017143
# Iteration 743: ||Δw|| = 1.523465735
# Iteration 744: ||Δw|| = 3.231959190
# Iteration 745: ||Δw|| = 6.917477555
# Iteration 746: ||Δw|| = 3.477017143
# Iteration 747: ||Δw|| = 1.523465735
# Iteration 748: ||Δw|| = 3.231959190
# Iteration 749: ||Δw|| = 6.917477555
# Iteration 750: ||Δw|| = 3.477017143
# Iteration 751: ||Δw|| = 1.523465735
# Iteration 752: ||Δw|| = 3.231959190
# Iteration 753: ||Δw|| = 6.917477555
# Iteration 754: ||Δw|| = 3.477017143
# Iteration 755: ||Δw|| = 1.523465735
# Iteration 756: ||Δw|| = 3.231959190
# Iteration 757: ||Δw|| = 6.917477555
# Iteration 758: ||Δw|| = 3.477017143
# Iteration 759: ||Δw|| = 1.523465735
# Iteration 760: ||Δw|| = 3.231959190
# Iteration 761: ||Δw|| = 6.917477555
# Iteration 762: ||Δw|| = 3.477017143
# Iteration 763: ||Δw|| = 1.523465735
# Iteration 764: ||Δw|| = 3.231959190
# Iteration 765: ||Δw|| = 6.917477555
# Iteration 766: ||Δw|| = 3.477017143
# Iteration 767: ||Δw|| = 1.523465735
# Iteration 768: ||Δw|| = 3.231959190
# Iteration 769: ||Δw|| = 6.917477555
# Iteration 770: ||Δw|| = 3.477017143
# Iteration 771: ||Δw|| = 1.523465735
# Iteration 772: ||Δw|| = 3.231959190
# Iteration 773: ||Δw|| = 6.917477555
# Iteration 774: ||Δw|| = 3.477017143
# Iteration 775: ||Δw|| = 1.523465735
# Iteration 776: ||Δw|| = 3.231959190
# Iteration 777: ||Δw|| = 6.917477555
# Iteration 778: ||Δw|| = 3.477017143
# Iteration 779: ||Δw|| = 1.523465735
# Iteration 780: ||Δw|| = 3.231959190
# Iteration 781: ||Δw|| = 6.917477555
# Iteration 782: ||Δw|| = 3.477017143
# Iteration 783: ||Δw|| = 1.523465735
# Iteration 784: ||Δw|| = 3.231959190
# Iteration 785: ||Δw|| = 6.917477555
# Iteration 786: ||Δw|| = 3.477017143
# Iteration 787: ||Δw|| = 1.523465735
# Iteration 788: ||Δw|| = 3.231959190
# Iteration 789: ||Δw|| = 6.917477555
# Iteration 790: ||Δw|| = 3.477017143
# Iteration 791: ||Δw|| = 1.523465735
# Iteration 792: ||Δw|| = 3.231959190
# Iteration 793: ||Δw|| = 6.917477555
# Iteration 794: ||Δw|| = 3.477017143
# Iteration 795: ||Δw|| = 1.523465735
# Iteration 796: ||Δw|| = 3.231959190
# Iteration 797: ||Δw|| = 6.917477555
# Iteration 798: ||Δw|| = 3.477017143
# Iteration 799: ||Δw|| = 1.523465735
# Iteration 800: ||Δw|| = 3.231959190
# Iteration 801: ||Δw|| = 6.917477555
# Iteration 802: ||Δw|| = 3.477017143
# Iteration 803: ||Δw|| = 1.523465735
# Iteration 804: ||Δw|| = 3.231959190
# Iteration 805: ||Δw|| = 6.917477555
# Iteration 806: ||Δw|| = 3.477017143
# Iteration 807: ||Δw|| = 1.523465735
# Iteration 808: ||Δw|| = 3.231959190
# Iteration 809: ||Δw|| = 6.917477555
# Iteration 810: ||Δw|| = 3.477017143
# Iteration 811: ||Δw|| = 1.523465735
# Iteration 812: ||Δw|| = 3.231959190
# Iteration 813: ||Δw|| = 6.917477555
# Iteration 814: ||Δw|| = 3.477017143
# Iteration 815: ||Δw|| = 1.523465735
# Iteration 816: ||Δw|| = 3.231959190
# Iteration 817: ||Δw|| = 6.917477555
# Iteration 818: ||Δw|| = 3.477017143
# Iteration 819: ||Δw|| = 1.523465735
# Iteration 820: ||Δw|| = 3.231959190
# Iteration 821: ||Δw|| = 6.917477555
# Iteration 822: ||Δw|| = 3.477017143
# Iteration 823: ||Δw|| = 1.523465735
# Iteration 824: ||Δw|| = 3.231959190
# Iteration 825: ||Δw|| = 6.917477555
# Iteration 826: ||Δw|| = 3.477017143
# Iteration 827: ||Δw|| = 1.523465735
# Iteration 828: ||Δw|| = 3.231959190
# Iteration 829: ||Δw|| = 6.917477555
# Iteration 830: ||Δw|| = 3.477017143
# Iteration 831: ||Δw|| = 1.523465735
# Iteration 832: ||Δw|| = 3.231959190
# Iteration 833: ||Δw|| = 6.917477555
# Iteration 834: ||Δw|| = 3.477017143
# Iteration 835: ||Δw|| = 1.523465735
# Iteration 836: ||Δw|| = 3.231959190
# Iteration 837: ||Δw|| = 6.917477555
# Iteration 838: ||Δw|| = 3.477017143
# Iteration 839: ||Δw|| = 1.523465735
# Iteration 840: ||Δw|| = 3.231959190
# Iteration 841: ||Δw|| = 6.917477555
# Iteration 842: ||Δw|| = 3.477017143
# Iteration 843: ||Δw|| = 1.523465735
# Iteration 844: ||Δw|| = 3.231959190
# Iteration 845: ||Δw|| = 6.917477555
# Iteration 846: ||Δw|| = 3.477017143
# Iteration 847: ||Δw|| = 1.523465735
# Iteration 848: ||Δw|| = 3.231959190
# Iteration 849: ||Δw|| = 6.917477555
# Iteration 850: ||Δw|| = 3.477017143
# Iteration 851: ||Δw|| = 1.523465735
# Iteration 852: ||Δw|| = 3.231959190
# Iteration 853: ||Δw|| = 6.917477555
# Iteration 854: ||Δw|| = 3.477017143
# Iteration 855: ||Δw|| = 1.523465735
# Iteration 856: ||Δw|| = 3.231959190
# Iteration 857: ||Δw|| = 6.917477555
# Iteration 858: ||Δw|| = 3.477017143
# Iteration 859: ||Δw|| = 1.523465735
# Iteration 860: ||Δw|| = 3.231959190
# Iteration 861: ||Δw|| = 6.917477555
# Iteration 862: ||Δw|| = 3.477017143
# Iteration 863: ||Δw|| = 1.523465735
# Iteration 864: ||Δw|| = 3.231959190
# Iteration 865: ||Δw|| = 6.917477555
# Iteration 866: ||Δw|| = 3.477017143
# Iteration 867: ||Δw|| = 1.523465735
# Iteration 868: ||Δw|| = 3.231959190
# Iteration 869: ||Δw|| = 6.917477555
# Iteration 870: ||Δw|| = 3.477017143
# Iteration 871: ||Δw|| = 1.523465735
# Iteration 872: ||Δw|| = 3.231959190
# Iteration 873: ||Δw|| = 6.917477555
# Iteration 874: ||Δw|| = 3.477017143
# Iteration 875: ||Δw|| = 1.523465735
# Iteration 876: ||Δw|| = 3.231959190
# Iteration 877: ||Δw|| = 6.917477555
# Iteration 878: ||Δw|| = 3.477017143
# Iteration 879: ||Δw|| = 1.523465735
# Iteration 880: ||Δw|| = 3.231959190
# Iteration 881: ||Δw|| = 6.917477555
# Iteration 882: ||Δw|| = 3.477017143
# Iteration 883: ||Δw|| = 1.523465735
# Iteration 884: ||Δw|| = 3.231959190
# Iteration 885: ||Δw|| = 6.917477555
# Iteration 886: ||Δw|| = 3.477017143
# Iteration 887: ||Δw|| = 1.523465735
# Iteration 888: ||Δw|| = 3.231959190
# Iteration 889: ||Δw|| = 6.917477555
# Iteration 890: ||Δw|| = 3.477017143
# Iteration 891: ||Δw|| = 1.523465735
# Iteration 892: ||Δw|| = 3.231959190
# Iteration 893: ||Δw|| = 6.917477555
# Iteration 894: ||Δw|| = 3.477017143
# Iteration 895: ||Δw|| = 1.523465735
# Iteration 896: ||Δw|| = 3.231959190
# Iteration 897: ||Δw|| = 6.917477555
# Iteration 898: ||Δw|| = 3.477017143
# Iteration 899: ||Δw|| = 1.523465735
# Iteration 900: ||Δw|| = 3.231959190
# Iteration 901: ||Δw|| = 6.917477555
# Iteration 902: ||Δw|| = 3.477017143
# Iteration 903: ||Δw|| = 1.523465735
# Iteration 904: ||Δw|| = 3.231959190
# Iteration 905: ||Δw|| = 6.917477555
# Iteration 906: ||Δw|| = 3.477017143
# Iteration 907: ||Δw|| = 1.523465735
# Iteration 908: ||Δw|| = 3.231959190
# Iteration 909: ||Δw|| = 6.917477555
# Iteration 910: ||Δw|| = 3.477017143
# Iteration 911: ||Δw|| = 1.523465735
# Iteration 912: ||Δw|| = 3.231959190
# Iteration 913: ||Δw|| = 6.917477555
# Iteration 914: ||Δw|| = 3.477017143
# Iteration 915: ||Δw|| = 1.523465735
# Iteration 916: ||Δw|| = 3.231959190
# Iteration 917: ||Δw|| = 6.917477555
# Iteration 918: ||Δw|| = 3.477017143
# Iteration 919: ||Δw|| = 1.523465735
# Iteration 920: ||Δw|| = 3.231959190
# Iteration 921: ||Δw|| = 6.917477555
# Iteration 922: ||Δw|| = 3.477017143
# Iteration 923: ||Δw|| = 1.523465735
# Iteration 924: ||Δw|| = 3.231959190
# Iteration 925: ||Δw|| = 6.917477555
# Iteration 926: ||Δw|| = 3.477017143
# Iteration 927: ||Δw|| = 1.523465735
# Iteration 928: ||Δw|| = 3.231959190
# Iteration 929: ||Δw|| = 6.917477555
# Iteration 930: ||Δw|| = 3.477017143
# Iteration 931: ||Δw|| = 1.523465735
# Iteration 932: ||Δw|| = 3.231959190
# Iteration 933: ||Δw|| = 6.917477555
# Iteration 934: ||Δw|| = 3.477017143
# Iteration 935: ||Δw|| = 1.523465735
# Iteration 936: ||Δw|| = 3.231959190
# Iteration 937: ||Δw|| = 6.917477555
# Iteration 938: ||Δw|| = 3.477017143
# Iteration 939: ||Δw|| = 1.523465735
# Iteration 940: ||Δw|| = 3.231959190
# Iteration 941: ||Δw|| = 6.917477555
# Iteration 942: ||Δw|| = 3.477017143
# Iteration 943: ||Δw|| = 1.523465735
# Iteration 944: ||Δw|| = 3.231959190
# Iteration 945: ||Δw|| = 6.917477555
# Iteration 946: ||Δw|| = 3.477017143
# Iteration 947: ||Δw|| = 1.523465735
# Iteration 948: ||Δw|| = 3.231959190
# Iteration 949: ||Δw|| = 6.917477555
# Iteration 950: ||Δw|| = 3.477017143
# Iteration 951: ||Δw|| = 1.523465735
# Iteration 952: ||Δw|| = 3.231959190
# Iteration 953: ||Δw|| = 6.917477555
# Iteration 954: ||Δw|| = 3.477017143
# Iteration 955: ||Δw|| = 1.523465735
# Iteration 956: ||Δw|| = 3.231959190
# Iteration 957: ||Δw|| = 6.917477555
# Iteration 958: ||Δw|| = 3.477017143
# Iteration 959: ||Δw|| = 1.523465735
# Iteration 960: ||Δw|| = 3.231959190
# Iteration 961: ||Δw|| = 6.917477555
# Iteration 962: ||Δw|| = 3.477017143
# Iteration 963: ||Δw|| = 1.523465735
# Iteration 964: ||Δw|| = 3.231959190
# Iteration 965: ||Δw|| = 6.917477555
# Iteration 966: ||Δw|| = 3.477017143
# Iteration 967: ||Δw|| = 1.523465735
# Iteration 968: ||Δw|| = 3.231959190
# Iteration 969: ||Δw|| = 6.917477555
# Iteration 970: ||Δw|| = 3.477017143
# Iteration 971: ||Δw|| = 1.523465735
# Iteration 972: ||Δw|| = 3.231959190
# Iteration 973: ||Δw|| = 6.917477555
# Iteration 974: ||Δw|| = 3.477017143
# Iteration 975: ||Δw|| = 1.523465735
# Iteration 976: ||Δw|| = 3.231959190
# Iteration 977: ||Δw|| = 6.917477555
# Iteration 978: ||Δw|| = 3.477017143
# Iteration 979: ||Δw|| = 1.523465735
# Iteration 980: ||Δw|| = 3.231959190
# Iteration 981: ||Δw|| = 6.917477555
# Iteration 982: ||Δw|| = 3.477017143
# Iteration 983: ||Δw|| = 1.523465735
# Iteration 984: ||Δw|| = 3.231959190
# Iteration 985: ||Δw|| = 6.917477555
# Iteration 986: ||Δw|| = 3.477017143
# Iteration 987: ||Δw|| = 1.523465735
# Iteration 988: ||Δw|| = 3.231959190
# Iteration 989: ||Δw|| = 6.917477555
# Iteration 990: ||Δw|| = 3.477017143
# Iteration 991: ||Δw|| = 1.523465735
# Iteration 992: ||Δw|| = 3.231959190
# Iteration 993: ||Δw|| = 6.917477555
# Iteration 994: ||Δw|| = 3.477017143
# Iteration 995: ||Δw|| = 1.523465735
# Iteration 996: ||Δw|| = 3.231959190
# Iteration 997: ||Δw|| = 6.917477555
# Iteration 998: ||Δw|| = 3.477017143
# Iteration 999: ||Δw|| = 1.523465735
# q-value at 0: 15.066109226090243
# Option price: 5.598504840023153
# array([5.59850484])

# %%
K = sampler.strike
T = sampler.time_grid[-1]
r = -np.log(sampler.discount_factor[0, 1] / sampler.discount_factor[0, 0]) / sampler.time_deltas[0]
n_paths, n_times, _ = sampler.markov_state.shape
gamma = np.exp(-r * sampler.time_deltas[0])
S_paths = sampler.markov_state[:, :, 0]
time_grid_expanded = np.tile(sampler.time_grid, (n_paths, 1))
phi_all_raw = pricer._basis_functions_raw(S_paths, K, time_grid_expanded, T)
phi_all = pricer._scale_features(phi_all_raw, fit=True)

phi_curr = phi_all[:, :-1, :]  # Текущие состояния (t)
phi_next = phi_all[:, 1:, :]   # Следующие состояния (t+1)
payoff = sampler.payoff
payoff_next = sampler.payoff[:, 1:]  # Выплаты в t+1

# Выравнивание в 1D
n_features = phi_all.shape[-1]
phi_all_flat = phi_all.reshape(-1, n_features)
phi_curr_flat = phi_curr.reshape(-1, n_features)
phi_next_flat = phi_next.reshape(-1, n_features)
payoff_flat = payoff.reshape(-1)
payoff_next_flat = payoff_next.reshape(-1)

# %%
def bellman_opt_eq(phi_curr, phi_next, payoff_next, w, gamma, w_next=None):
    if w_next is None:
        w_next = w
    return ((
        phi_curr @ w - 
        gamma * np.max(
            np.concat([
                payoff_next[np.newaxis], 
                (phi_next @ w_next)[np.newaxis] \
                    * np.array(
                        (([1] * (n_times - 2)) + [0]) * n_paths
                    )
            ]), 
            axis=0
        )
    ) ** 2).mean()

# %%
bellman_opt_eq(
    phi_curr_flat, 
    phi_next_flat, 
    payoff_next_flat, 
    pricer.w, 
    gamma
)
# Out:
# np.float64(0.1691104323247614)

# %%
bellman_opt_eq(
    phi_curr_flat, 
    phi_next_flat, 
    payoff_next_flat, 
    pricer.w * 0.99, 
    gamma
)
# Out:
# np.float64(0.16947528288001956)

# %%
bellman_opt_eq(
    phi_curr_flat, 
    phi_next_flat, 
    payoff_next_flat, 
    pricer.w * 0.99, 
    gamma,
    pricer.w
)
# Out:
# np.float64(0.18850083782406357)

# %%
def price(phi_all, n_paths, payoff, w, gamma):
    pv_payoffs = np.zeros(n_paths)
    for p in range(n_paths):
        for t in range(n_times):
            phi_t = phi_all[p, t]
            Q_cont = phi_t @ w
            payoff_t = payoff[p, t]
            
            disc_factor = gamma**t
            if payoff_t >= Q_cont or t == n_times - 1:
                pv_payoffs[p] = disc_factor * payoff_t
                break
    return pv_payoffs.mean()

# %%
price(
    phi_all,
    n_paths, 
    sampler.payoff,
    pricer.w,
    gamma
)
# Out:
# np.float64(5.598504840023049)

# %%
price(
    phi_all,
    n_paths, 
    sampler.payoff,
    pricer.w * 0.99,
    gamma
)
# Out:
# np.float64(5.677014030549818)

# %%
pricer.w
# Out:
# array([  13.94873312,  206.16979676, -277.23382866,   76.5046833 ,
#          18.38606535,    4.63679733,   20.49058699])

# %%
import numpy as np
from numba import njit

@njit
def spread_with_gamma(arr, gamma):
    result = np.zeros_like(arr)
    rows, cols = np.where(np.abs(arr) > 1e-6)
    
    for i, j in zip(rows, cols):
        if arr[i, j] == 0:
            continue
            
        # Создаем диапазон для влияния
        k_values = np.arange(j + 1)
        powers = j - k_values
        influences = (gamma ** powers) * arr[i, j]
        
        # Находим позиции, которые еще не заполнены
        target_pos = k_values[result[i, k_values] == 0]
        result[i, target_pos] = influences[target_pos]
        
        # Обнуляем где power == 0
        result[i, j] = 0
        
    return result

# %%
a = np.array([
    [0, 0, 0, 1, 0, 0],
    [0,1,0,3,0,0]
])
gamma = 2

# %%
spread_with_gamma(a, gamma)

# %%
from copy import deepcopy
import numpy as np
from typing import Optional
from sklearn.preprocessing import StandardScaler
from src.pricers.abstract_pricer import PricerAbstract
from src.samplers.abstract_sampler import SamplerAbstract


import numpy as np
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from tqdm.auto import tqdm
import matplotlib.pyplot as plt

# %%
from src.samplers.geometric_brownian_motion_put_sampler import GeometricBrownianMotionPutSampler
sampler = GeometricBrownianMotionPutSampler(**{
    "asset0": 100.0,
    "sigma": 0.2,
    "r": 0.05,
    "strike": 100.0,
    "t": 1.0,
    "cnt_times": 60,
    "seed": None, 
    "cnt_trajectories": 1_000_000
})

# %% [markdown]
# # LSPI

# %%
from dataclasses import dataclass
@dataclass 
class A:
    _: int

self = A(0)

def _create_features(self, markov_state: np.ndarray, time_grid: np.ndarray) -> np.ndarray:
    n_paths, n_times, state_dim = markov_state.shape
    T = time_grid[-1]
    
    # Нормализованное время до экспирации
    time_to_exp = (T - time_grid) / T
    time_to_exp = np.tile(time_to_exp, (n_paths, 1))[..., None]
    
    # Объединяем время и состояние
    features = np.concatenate([time_to_exp, markov_state], axis=-1)
    flat_features = features.reshape(-1, features.shape[-1])
    
    # Первый вызов - инициализируем и фитим трансформеры
    if not self.is_fitted_:
        self.scaler_ = StandardScaler()
        self.poly_ = PolynomialFeatures(degree=self.degree, include_bias=True)
        
        scaled = self.scaler_.fit_transform(flat_features)
        poly_features = self.poly_.fit_transform(scaled)
        self.n_features_ = poly_features.shape[1]
        self.is_fitted_ = True
    else:
        # Используем обученные трансформеры
        scaled = self.scaler_.transform(flat_features)
        poly_features = self.poly_.transform(scaled)
    
    return poly_features.reshape(n_paths, n_times, -1)

def _create_features(self, markov_state: np.ndarray, time_grid: np.ndarray) -> np.ndarray:
    M = markov_state[:, :, 0] / 100.
    exp_term = np.exp(-M / 2.0)
    T = time_grid[-1]
    t = time_grid

    phi = np.zeros((*markov_state[:, :, 0].shape, 7), dtype = float)
    phi[:, :, 0] = 1.0
    phi[:, :, 1] = exp_term
    phi[:, :, 2] = exp_term * (1.0 - M)
    phi[:, :, 3] = exp_term * (1.0 - 2.0 * M + 0.5 * M * M)
    phi[:, :, 4] = np.sin(np.pi * (T - t) / (2.0 * T))
    phi[:, :, 5] = np.log(np.maximum(T - t, 1e-10)) # 1e-10 чтобы не было log(0)
    phi[:, :, 6] = (t / T) ** 2

    scaler = StandardScaler()
    phi_reshaped = phi[:, :, 1:].reshape(-1, 6)
    phi_scaled = scaler.fit_transform(phi_reshaped)
    phi_scaled = phi_scaled.reshape(phi.shape[0], phi.shape[1], 6)


    phi_final = np.zeros_like(phi)
    phi_final[:, :, 0] = phi[:, :, 0]
    phi_final[:, :, 1:] = phi_scaled

    return phi_final

# %%
self.sampler = sampler
self.sampler.sample()

# %%
r = -np.log(self.sampler.discount_factor[0, 1] / self.sampler.discount_factor[0, 0]) / (self.sampler.time_deltas[0])
self.dt = sampler.time_deltas[0]
self.is_fitted_ = False
self.degree = 3
self.iterations = 100
self.tol = 1e-6
self.reg_alpha = 1e-2
quiet = False

# %%
# Параметры
n_paths, n_times, _ = self.sampler.markov_state.shape
gamma = np.exp(-r * self.dt)  # Коэффициент дисконтирования

# Создаем признаки
phi_all = _create_features(self,
    self.sampler.markov_state, 
    self.sampler.time_grid
)
n_features = phi_all.shape[-1]


w = np.zeros(n_features)

# Подготовка данных
phi_curr = phi_all[:, :-1, :]  # Текущие состояния (t)
phi_next = phi_all[:, 1:, :]    # Следующие состояния (t+1)
payoff_next = self.sampler.payoff[:, 1:]  # Выплаты в t+1

# Выравнивание в 1D
phi_curr_flat = phi_curr.reshape(-1, n_features)
phi_next_flat = phi_next.reshape(-1, n_features)
payoff_next_flat = payoff_next.reshape(-1)

# Флаг нетерминальных состояний
non_terminal = np.tile(
    np.arange(n_times-1, dtype=int) < n_times-2, 
    (n_paths, 1)
)
non_terminal_flat = non_terminal.reshape(-1)

# Итерации LSPI
for it in tqdm(range(self.iterations), desc="LSPI iterations"):
    prev_w = deepcopy(w)
    
    # Вычисляем Q-значения продолжения
    Q_cont_next = phi_next_flat @ w
    
    # Условие продолжения
    continue_cond = non_terminal_flat & (Q_cont_next >= payoff_next_flat)
    
    # Формируем систему уравнений
    diff_phi = phi_curr_flat - gamma * continue_cond[:, None] * phi_next_flat
    A = phi_curr_flat.T @ diff_phi
    b = gamma * phi_curr_flat.T @ ((~continue_cond) * payoff_next_flat)

    if self.reg_alpha is not None:
        A += np.eye(A.shape[0]) * self.reg_alpha
    w = np.linalg.solve(A, b)
    
    # Проверка сходимости
    diff_norm = np.linalg.norm(w - prev_w)
    if not quiet:
        print(f"Iteration {it}: ||Δw|| = {diff_norm:.9f}")
    if diff_norm < self.tol:
        if not quiet:
            print(f"Converged after {it} iterations")
        break

self.w = w

# %%
pv_payoffs = np.zeros(n_paths)
for p in range(n_paths):
    for t in range(n_times):
        # Признаки текущего состояния
        phi_t = phi_all[p, t]
        Q_cont = phi_t @ w
        payoff_t = self.sampler.payoff[p, t]
        
        # Условие исполнения
        if payoff_t >= Q_cont or t == n_times - 1:
            disc_factor = self.sampler.discount_factor[p, t]
            pv_payoffs[p] = disc_factor * payoff_t
            break
mean = pv_payoffs.mean()

plt.figure(figsize=(10, 6))
plt.hist(pv_payoffs)
plt.axvline(mean)
plt.title("Train")
plt.grid()
plt.show()
mean

# %%
self.sampler.sample()

# %%
phi_all = _create_features(self,
    self.sampler.markov_state, 
    self.sampler.time_grid
)
pv_payoffs = np.zeros(n_paths)
for p in range(n_paths):
    for t in range(n_times):
        # Признаки текущего состояния
        phi_t = phi_all[p, t]
        Q_cont = phi_t @ w
        payoff_t = self.sampler.payoff[p, t]
        
        # Условие исполнения
        if payoff_t >= Q_cont or t == n_times - 1:
            disc_factor = self.sampler.discount_factor[p, t]
            pv_payoffs[p] = disc_factor * payoff_t
            break
mean = pv_payoffs.mean()

plt.figure(figsize=(10, 6))
plt.hist(pv_payoffs)
plt.axvline(mean)
plt.title("Test")
plt.grid()
plt.show()
mean

# %%
n_traj = 10

plt.figure(figsize=(10, 6))
plt.plot(self.sampler.time_grid, self.sampler.payoff[:n_traj, :].T)
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(self.sampler.time_grid, (self.sampler.payoff[:, :] * self.sampler.discount_factor)[:n_traj, :].T)
plt.show()

# %% [markdown]
# # LSMC

# %%
from src.pricers.american_monte_carlo import AmericanMonteCarloPricer
pricer = AmericanMonteCarloPricer(sampler, degree=3)
pricer.price();
pricer.result

# %%
import scipy
exercise_boundary_lsmc = []
for i, t in tqdm(list(
    enumerate(sampler.time_grid)
)):
    if pricer.weights[i] is None:
        print("None")
        exercise_boundary_lsmc.append(None)
        continue

    func_to_find_root = lambda x: (
        sampler.discount_factor[0, i] * max(0, 100. - x) - 
        (
            pricer.basis_functions_transformer.transform(
                pricer.scalers[i].transform([[x]])
            ) @ pricer.weights[i]
        ).reshape(-1)[0]
    )

    root = scipy.optimize.minimize_scalar(
        lambda x: func_to_find_root(x)**2,
        bounds=[np.percentile(sampler.markov_state[:, i, 0], 0.99), 100]
    )["x"]
    
    if abs(func_to_find_root(root)) < 1e-6:
        exercise_boundary_lsmc.append(
            root
        )
    else:
        exercise_boundary_lsmc.append(
            None
        )

    payoff = np.vectorize(lambda x: sampler.discount_factor[0, i] * max(0, 100. - x))
    continuation_value = np.vectorize(lambda x: (
        pricer.basis_functions_transformer.transform(
            pricer.scalers[i].transform([[x]])
        ) @ pricer.weights[i]
    ).reshape(-1)[0])
    plt.figure(figsize=(10, 6))
    plt.title(f"Continuation value at t={t}")
    grid = np.linspace(np.percentile(sampler.markov_state[:, i, 0], 0.99), 100, 30)
    plt.plot(grid, continuation_value(grid), label="CV")
    plt.plot(grid, payoff(grid), label="Payoff")
    plt.legend()
    plt.grid()
    plt.show()

plt.figure(figsize=(10, 6))
plt.plot(sampler.time_grid, exercise_boundary_lsmc, "-o", markersize=2)
plt.show()

# %%
exercise_boundary_lsmc

# %%
sampler.discount_factor[0, i]

# %%
exercise_boundary_lsmc

# %%
# import scipy
# exercise_boundary_lsmc = []
# for i, t in tqdm(list(enumerate(range(len(sampler.time_grid))))):
#     if pricer.weights[i] is None:
#         exercise_boundary_lsmc.append(None)
#         continue
#     exercise_boundary_lsmc.append(
#         scipy.optimize.minimize_scalar(
#             lambda x: (
#                 sampler.discount_factor[0, i] * max(0, 100. - x) - 
#                 (
#                     pricer.basis_functions_transformer.transform([[x]]) @ pricer.weights[i]
#                 ).reshape(-1)[0]
#             )**2,
#             bounds=[0, 100]
#         )["x"]
#     )

# plt.figure(figsize=(10, 6))
# plt.plot(sampler.time_grid, exercise_boundary_lsmc)
# plt.show()

# %%
pricer.weights
