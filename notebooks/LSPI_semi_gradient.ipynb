# %%
if 'already_executed' not in globals():
    already_executed = False

if not already_executed:
    import os
    os.chdir("../")
    # %load_ext autoreload
    # %autoreload 2
    already_executed = True

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from src.pricers.pricers import LSPISemiGradientPricer as LSPIPricer
from src.samplers.samplers import GeometricBrownianMotionPutSampler

# %%
sampler = GeometricBrownianMotionPutSampler(**{
    "asset0": 100.0,
    "sigma": 0.2,
    "r": 0.05,
    "strike": 100.0,
    "t": 1.0,
    "cnt_times": 365,
    "seed": 42, 
    "cnt_trajectories": 1_000_0
})

# %%
pricer = LSPIPricer(sampler=sampler, **{
    "iterations": 1000,
    "lambda_reg": 0,
    "tol": 1e-9
})

# %%
pricer.price(test=False, quiet=False)
# Out:
# GBM sampling:   0%|          | 0/364 [00:00<?, ?it/s]
# Iteration 0: ||Δw|| = 479.697118313
# Iteration 1: ||Δw|| = 30.119505059
# Iteration 2: ||Δw|| = 12.996886984
# Iteration 3: ||Δw|| = 6.148981096
# Iteration 4: ||Δw|| = 2.780896740
# Iteration 5: ||Δw|| = 1.111612474
# Iteration 6: ||Δw|| = 0.958354360
# Iteration 7: ||Δw|| = 1.431149540
# Iteration 8: ||Δw|| = 1.810868634
# Iteration 9: ||Δw|| = 2.051255763
# Iteration 10: ||Δw|| = 2.197181298
# Iteration 11: ||Δw|| = 2.293825256
# Iteration 12: ||Δw|| = 2.358399841
# Iteration 13: ||Δw|| = 2.397392862
# Iteration 14: ||Δw|| = 2.411402062
# Iteration 15: ||Δw|| = 2.411730011
# Iteration 16: ||Δw|| = 2.400349815
# Iteration 17: ||Δw|| = 2.379824320
# Iteration 18: ||Δw|| = 2.350103497
# Iteration 19: ||Δw|| = 2.313812211
# Iteration 20: ||Δw|| = 2.274080365
# Iteration 21: ||Δw|| = 2.233810117
# Iteration 22: ||Δw|| = 2.192187441
# Iteration 23: ||Δw|| = 2.149991082
# Iteration 24: ||Δw|| = 2.106386204
# Iteration 25: ||Δw|| = 2.062025762
# Iteration 26: ||Δw|| = 2.016271091
# Iteration 27: ||Δw|| = 1.969253157
# Iteration 28: ||Δw|| = 1.922924699
# Iteration 29: ||Δw|| = 1.876710974
# Iteration 30: ||Δw|| = 1.830563346
# Iteration 31: ||Δw|| = 1.784932975
# Iteration 32: ||Δw|| = 1.738737074
# Iteration 33: ||Δw|| = 1.692225470
# Iteration 34: ||Δw|| = 1.647196636
# Iteration 35: ||Δw|| = 1.605840002
# Iteration 36: ||Δw|| = 1.568005687
# Iteration 37: ||Δw|| = 1.532941543
# Iteration 38: ||Δw|| = 1.500484763
# Iteration 39: ||Δw|| = 1.470190339
# Iteration 40: ||Δw|| = 1.441838095
# Iteration 41: ||Δw|| = 1.415394242
# Iteration 42: ||Δw|| = 1.390970141
# Iteration 43: ||Δw|| = 1.367823381
# Iteration 44: ||Δw|| = 1.345813050
# Iteration 45: ||Δw|| = 1.324948326
# Iteration 46: ||Δw|| = 1.305180125
# Iteration 47: ||Δw|| = 1.286323418
# Iteration 48: ||Δw|| = 1.268370612
# Iteration 49: ||Δw|| = 1.251218172
# Iteration 50: ||Δw|| = 1.234741509
# Iteration 51: ||Δw|| = 1.218892072
# Iteration 52: ||Δw|| = 1.203641027
# Iteration 53: ||Δw|| = 1.188894212
# Iteration 54: ||Δw|| = 1.174623173
# Iteration 55: ||Δw|| = 1.160795783
# Iteration 56: ||Δw|| = 1.147371057
# Iteration 57: ||Δw|| = 1.134318572
# Iteration 58: ||Δw|| = 1.121606501
# Iteration 59: ||Δw|| = 1.109212347
# Iteration 60: ||Δw|| = 1.097135047
# Iteration 61: ||Δw|| = 1.085373292
# Iteration 62: ||Δw|| = 1.073854165
# Iteration 63: ||Δw|| = 1.062565334
# Iteration 64: ||Δw|| = 1.051482541
# Iteration 65: ||Δw|| = 1.040590229
# Iteration 66: ||Δw|| = 1.029875036
# Iteration 67: ||Δw|| = 1.019314677
# Iteration 68: ||Δw|| = 1.008912050
# Iteration 69: ||Δw|| = 0.998672659
# Iteration 70: ||Δw|| = 0.988580223
# Iteration 71: ||Δw|| = 0.978627250
# Iteration 72: ||Δw|| = 0.968802640
# Iteration 73: ||Δw|| = 0.959112115
# Iteration 74: ||Δw|| = 0.949546973
# Iteration 75: ||Δw|| = 0.940100642
# Iteration 76: ||Δw|| = 0.930760513
# Iteration 77: ||Δw|| = 0.921523941
# Iteration 78: ||Δw|| = 0.912389634
# Iteration 79: ||Δw|| = 0.903343806
# Iteration 80: ||Δw|| = 0.894375520
# Iteration 81: ||Δw|| = 0.885472545
# Iteration 82: ||Δw|| = 0.876634412
# Iteration 83: ||Δw|| = 0.867861957
# Iteration 84: ||Δw|| = 0.859163265
# Iteration 85: ||Δw|| = 0.850532080
# Iteration 86: ||Δw|| = 0.841963105
# Iteration 87: ||Δw|| = 0.833450721
# Iteration 88: ||Δw|| = 0.824989232
# Iteration 89: ||Δw|| = 0.816576727
# Iteration 90: ||Δw|| = 0.808221533
# Iteration 91: ||Δw|| = 0.799902919
# Iteration 92: ||Δw|| = 0.791623323
# Iteration 93: ||Δw|| = 0.783386528
# Iteration 94: ||Δw|| = 0.775198203
# Iteration 95: ||Δw|| = 0.767049468
# Iteration 96: ||Δw|| = 0.758933821
# Iteration 97: ||Δw|| = 0.750847777
# Iteration 98: ||Δw|| = 0.742789652
# Iteration 99: ||Δw|| = 0.734755809
# Iteration 100: ||Δw|| = 0.726750503
# Iteration 101: ||Δw|| = 0.718775373
# Iteration 102: ||Δw|| = 0.710830736
# Iteration 103: ||Δw|| = 0.702903342
# Iteration 104: ||Δw|| = 0.695014318
# Iteration 105: ||Δw|| = 0.687139160
# Iteration 106: ||Δw|| = 0.679285686
# Iteration 107: ||Δw|| = 0.671456649
# Iteration 108: ||Δw|| = 0.663653037
# Iteration 109: ||Δw|| = 0.655868934
# Iteration 110: ||Δw|| = 0.648114606
# Iteration 111: ||Δw|| = 0.640404803
# Iteration 112: ||Δw|| = 0.632741507
# Iteration 113: ||Δw|| = 0.625116008
# Iteration 114: ||Δw|| = 0.617535716
# Iteration 115: ||Δw|| = 0.610007752
# Iteration 116: ||Δw|| = 0.602533492
# Iteration 117: ||Δw|| = 0.595116574
# Iteration 118: ||Δw|| = 0.587752427
# Iteration 119: ||Δw|| = 0.580443050
# Iteration 120: ||Δw|| = 0.573189803
# Iteration 121: ||Δw|| = 0.565995087
# Iteration 122: ||Δw|| = 0.558869458
# Iteration 123: ||Δw|| = 0.551811563
# Iteration 124: ||Δw|| = 0.544819798
# Iteration 125: ||Δw|| = 0.537885399
# Iteration 126: ||Δw|| = 0.531020366
# Iteration 127: ||Δw|| = 0.524224976
# Iteration 128: ||Δw|| = 0.517503119
# Iteration 129: ||Δw|| = 0.510847923
# Iteration 130: ||Δw|| = 0.504260240
# Iteration 131: ||Δw|| = 0.497743489
# Iteration 132: ||Δw|| = 0.491297276
# Iteration 133: ||Δw|| = 0.484923602
# Iteration 134: ||Δw|| = 0.478619063
# Iteration 135: ||Δw|| = 0.472383082
# Iteration 136: ||Δw|| = 0.466219874
# Iteration 137: ||Δw|| = 0.460133984
# Iteration 138: ||Δw|| = 0.454120529
# Iteration 139: ||Δw|| = 0.448175629
# Iteration 140: ||Δw|| = 0.442298089
# Iteration 141: ||Δw|| = 0.436488313
# Iteration 142: ||Δw|| = 0.430744926
# Iteration 143: ||Δw|| = 0.425070997
# Iteration 144: ||Δw|| = 0.419462372
# Iteration 145: ||Δw|| = 0.413918289
# Iteration 146: ||Δw|| = 0.408439827
# Iteration 147: ||Δw|| = 0.403026251
# Iteration 148: ||Δw|| = 0.397677842
# Iteration 149: ||Δw|| = 0.392397452
# Iteration 150: ||Δw|| = 0.387181766
# Iteration 151: ||Δw|| = 0.382026487
# Iteration 152: ||Δw|| = 0.376936169
# Iteration 153: ||Δw|| = 0.371911913
# Iteration 154: ||Δw|| = 0.366948725
# Iteration 155: ||Δw|| = 0.362046214
# Iteration 156: ||Δw|| = 0.357204984
# Iteration 157: ||Δw|| = 0.352425684
# Iteration 158: ||Δw|| = 0.347710726
# Iteration 159: ||Δw|| = 0.343054701
# Iteration 160: ||Δw|| = 0.338457458
# Iteration 161: ||Δw|| = 0.333919866
# Iteration 162: ||Δw|| = 0.329442845
# Iteration 163: ||Δw|| = 0.325023274
# Iteration 164: ||Δw|| = 0.320660891
# Iteration 165: ||Δw|| = 0.316354607
# Iteration 166: ||Δw|| = 0.312105664
# Iteration 167: ||Δw|| = 0.307913369
# Iteration 168: ||Δw|| = 0.303775314
# Iteration 169: ||Δw|| = 0.299693605
# Iteration 170: ||Δw|| = 0.295665555
# Iteration 171: ||Δw|| = 0.291693887
# Iteration 172: ||Δw|| = 0.287776422
# Iteration 173: ||Δw|| = 0.283910223
# Iteration 174: ||Δw|| = 0.280096543
# Iteration 175: ||Δw|| = 0.276335313
# Iteration 176: ||Δw|| = 0.272626032
# Iteration 177: ||Δw|| = 0.268966149
# Iteration 178: ||Δw|| = 0.265357923
# Iteration 179: ||Δw|| = 0.261800487
# Iteration 180: ||Δw|| = 0.258291056
# Iteration 181: ||Δw|| = 0.254828438
# Iteration 182: ||Δw|| = 0.251411452
# Iteration 183: ||Δw|| = 0.248039220
# Iteration 184: ||Δw|| = 0.244713361
# Iteration 185: ||Δw|| = 0.241434921
# Iteration 186: ||Δw|| = 0.238202575
# Iteration 187: ||Δw|| = 0.235014632
# Iteration 188: ||Δw|| = 0.231869866
# Iteration 189: ||Δw|| = 0.228768026
# Iteration 190: ||Δw|| = 0.225710238
# Iteration 191: ||Δw|| = 0.222695010
# Iteration 192: ||Δw|| = 0.219721952
# Iteration 193: ||Δw|| = 0.216791561
# Iteration 194: ||Δw|| = 0.213901104
# Iteration 195: ||Δw|| = 0.211052344
# Iteration 196: ||Δw|| = 0.208245801
# Iteration 197: ||Δw|| = 0.205480572
# Iteration 198: ||Δw|| = 0.202755467
# Iteration 199: ||Δw|| = 0.200068636
# Iteration 200: ||Δw|| = 0.197420761
# Iteration 201: ||Δw|| = 0.194812675
# Iteration 202: ||Δw|| = 0.192242575
# Iteration 203: ||Δw|| = 0.189709722
# Iteration 204: ||Δw|| = 0.187212296
# Iteration 205: ||Δw|| = 0.184750179
# Iteration 206: ||Δw|| = 0.182325805
# Iteration 207: ||Δw|| = 0.179937013
# Iteration 208: ||Δw|| = 0.177583673
# Iteration 209: ||Δw|| = 0.175265182
# Iteration 210: ||Δw|| = 0.172983194
# Iteration 211: ||Δw|| = 0.170737961
# Iteration 212: ||Δw|| = 0.168527231
# Iteration 213: ||Δw|| = 0.166350062
# Iteration 214: ||Δw|| = 0.164205017
# Iteration 215: ||Δw|| = 0.162091547
# Iteration 216: ||Δw|| = 0.160011433
# Iteration 217: ||Δw|| = 0.157963960
# Iteration 218: ||Δw|| = 0.155947219
# Iteration 219: ||Δw|| = 0.153961509
# Iteration 220: ||Δw|| = 0.152005883
# Iteration 221: ||Δw|| = 0.150079976
# Iteration 222: ||Δw|| = 0.148183804
# Iteration 223: ||Δw|| = 0.146316916
# Iteration 224: ||Δw|| = 0.144479115
# Iteration 225: ||Δw|| = 0.142670571
# Iteration 226: ||Δw|| = 0.140889414
# Iteration 227: ||Δw|| = 0.139135848
# Iteration 228: ||Δw|| = 0.137409481
# Iteration 229: ||Δw|| = 0.135710485
# Iteration 230: ||Δw|| = 0.134037459
# Iteration 231: ||Δw|| = 0.132390330
# Iteration 232: ||Δw|| = 0.130769235
# Iteration 233: ||Δw|| = 0.129174556
# Iteration 234: ||Δw|| = 0.127605130
# Iteration 235: ||Δw|| = 0.126061580
# Iteration 236: ||Δw|| = 0.124543535
# Iteration 237: ||Δw|| = 0.123050307
# Iteration 238: ||Δw|| = 0.121581269
# Iteration 239: ||Δw|| = 0.120136063
# Iteration 240: ||Δw|| = 0.118714222
# Iteration 241: ||Δw|| = 0.117315830
# Iteration 242: ||Δw|| = 0.115940904
# Iteration 243: ||Δw|| = 0.114588445
# Iteration 244: ||Δw|| = 0.113257918
# Iteration 245: ||Δw|| = 0.111949621
# Iteration 246: ||Δw|| = 0.110663569
# Iteration 247: ||Δw|| = 0.109399184
# Iteration 248: ||Δw|| = 0.108156756
# Iteration 249: ||Δw|| = 0.106935696
# Iteration 250: ||Δw|| = 0.105735152
# Iteration 251: ||Δw|| = 0.104555108
# Iteration 252: ||Δw|| = 0.103394832
# Iteration 253: ||Δw|| = 0.102253908
# Iteration 254: ||Δw|| = 0.101132926
# Iteration 255: ||Δw|| = 0.100030970
# Iteration 256: ||Δw|| = 0.098947828
# Iteration 257: ||Δw|| = 0.097883435
# Iteration 258: ||Δw|| = 0.096837102
# Iteration 259: ||Δw|| = 0.095809319
# Iteration 260: ||Δw|| = 0.094799715
# Iteration 261: ||Δw|| = 0.093807345
# Iteration 262: ||Δw|| = 0.092832663
# Iteration 263: ||Δw|| = 0.091874644
# Iteration 264: ||Δw|| = 0.090933859
# Iteration 265: ||Δw|| = 0.090010485
# Iteration 266: ||Δw|| = 0.089103935
# Iteration 267: ||Δw|| = 0.088213746
# Iteration 268: ||Δw|| = 0.087339198
# Iteration 269: ||Δw|| = 0.086480503
# Iteration 270: ||Δw|| = 0.085637427
# Iteration 271: ||Δw|| = 0.084809794
# Iteration 272: ||Δw|| = 0.083997570
# Iteration 273: ||Δw|| = 0.083199757
# Iteration 274: ||Δw|| = 0.082416520
# Iteration 275: ||Δw|| = 0.081647485
# Iteration 276: ||Δw|| = 0.080892461
# Iteration 277: ||Δw|| = 0.080151168
# Iteration 278: ||Δw|| = 0.079423453
# Iteration 279: ||Δw|| = 0.078708911
# Iteration 280: ||Δw|| = 0.078007314
# Iteration 281: ||Δw|| = 0.077318645
# Iteration 282: ||Δw|| = 0.076642684
# Iteration 283: ||Δw|| = 0.075979021
# Iteration 284: ||Δw|| = 0.075327485
# Iteration 285: ||Δw|| = 0.074688120
# Iteration 286: ||Δw|| = 0.074061055
# Iteration 287: ||Δw|| = 0.073445935
# Iteration 288: ||Δw|| = 0.072841897
# Iteration 289: ||Δw|| = 0.072249168
# Iteration 290: ||Δw|| = 0.071667333
# Iteration 291: ||Δw|| = 0.071096372
# Iteration 292: ||Δw|| = 0.070535219
# Iteration 293: ||Δw|| = 0.069984006
# Iteration 294: ||Δw|| = 0.069442374
# Iteration 295: ||Δw|| = 0.068910527
# Iteration 296: ||Δw|| = 0.068388416
# Iteration 297: ||Δw|| = 0.067876151
# Iteration 298: ||Δw|| = 0.067372776
# Iteration 299: ||Δw|| = 0.066877755
# Iteration 300: ||Δw|| = 0.066391390
# Iteration 301: ||Δw|| = 0.065913728
# Iteration 302: ||Δw|| = 0.065443656
# Iteration 303: ||Δw|| = 0.064979820
# Iteration 304: ||Δw|| = 0.064521760
# Iteration 305: ||Δw|| = 0.064073198
# Iteration 306: ||Δw|| = 0.063633663
# Iteration 307: ||Δw|| = 0.063202767
# Iteration 308: ||Δw|| = 0.062780283
# Iteration 309: ||Δw|| = 0.062365650
# Iteration 310: ||Δw|| = 0.061959072
# Iteration 311: ||Δw|| = 0.061559872
# Iteration 312: ||Δw|| = 0.061168366
# Iteration 313: ||Δw|| = 0.060784450
# Iteration 314: ||Δw|| = 0.060407467
# Iteration 315: ||Δw|| = 0.060037640
# Iteration 316: ||Δw|| = 0.059677620
# Iteration 317: ||Δw|| = 0.059323859
# Iteration 318: ||Δw|| = 0.058975957
# Iteration 319: ||Δw|| = 0.058634262
# Iteration 320: ||Δw|| = 0.058297907
# Iteration 321: ||Δw|| = 0.057967915
# Iteration 322: ||Δw|| = 0.057643804
# Iteration 323: ||Δw|| = 0.057325752
# Iteration 324: ||Δw|| = 0.057013079
# Iteration 325: ||Δw|| = 0.056706018
# Iteration 326: ||Δw|| = 0.056404160
# Iteration 327: ||Δw|| = 0.056107391
# Iteration 328: ||Δw|| = 0.055815479
# Iteration 329: ||Δw|| = 0.055528447
# Iteration 330: ||Δw|| = 0.055246086
# Iteration 331: ||Δw|| = 0.054968265
# Iteration 332: ||Δw|| = 0.054695109
# Iteration 333: ||Δw|| = 0.054426131
# Iteration 334: ||Δw|| = 0.054161418
# Iteration 335: ||Δw|| = 0.053900954
# Iteration 336: ||Δw|| = 0.053644596
# Iteration 337: ||Δw|| = 0.053392005
# Iteration 338: ||Δw|| = 0.053142709
# Iteration 339: ||Δw|| = 0.052896884
# Iteration 340: ||Δw|| = 0.052654755
# Iteration 341: ||Δw|| = 0.052416499
# Iteration 342: ||Δw|| = 0.052182155
# Iteration 343: ||Δw|| = 0.051951395
# Iteration 344: ||Δw|| = 0.051724360
# Iteration 345: ||Δw|| = 0.051501762
# Iteration 346: ||Δw|| = 0.051282256
# Iteration 347: ||Δw|| = 0.051065403
# Iteration 348: ||Δw|| = 0.050851332
# Iteration 349: ||Δw|| = 0.050639704
# Iteration 350: ||Δw|| = 0.050430498
# Iteration 351: ||Δw|| = 0.050223729
# Iteration 352: ||Δw|| = 0.050019347
# Iteration 353: ||Δw|| = 0.049816775
# Iteration 354: ||Δw|| = 0.049615928
# Iteration 355: ||Δw|| = 0.049417275
# Iteration 356: ||Δw|| = 0.049220278
# Iteration 357: ||Δw|| = 0.049024763
# Iteration 358: ||Δw|| = 0.048831219
# Iteration 359: ||Δw|| = 0.048639858
# Iteration 360: ||Δw|| = 0.048450424
# Iteration 361: ||Δw|| = 0.048262799
# Iteration 362: ||Δw|| = 0.048076593
# Iteration 363: ||Δw|| = 0.047892252
# Iteration 364: ||Δw|| = 0.047709653
# Iteration 365: ||Δw|| = 0.047528375
# Iteration 366: ||Δw|| = 0.047348229
# Iteration 367: ||Δw|| = 0.047169419
# Iteration 368: ||Δw|| = 0.046992185
# Iteration 369: ||Δw|| = 0.046816282
# Iteration 370: ||Δw|| = 0.046641477
# Iteration 371: ||Δw|| = 0.046467529
# Iteration 372: ||Δw|| = 0.046294746
# Iteration 373: ||Δw|| = 0.046123106
# Iteration 374: ||Δw|| = 0.045952102
# Iteration 375: ||Δw|| = 0.045782276
# Iteration 376: ||Δw|| = 0.045612961
# Iteration 377: ||Δw|| = 0.045444764
# Iteration 378: ||Δw|| = 0.045277400
# Iteration 379: ||Δw|| = 0.045110912
# Iteration 380: ||Δw|| = 0.044944929
# Iteration 381: ||Δw|| = 0.044779720
# Iteration 382: ||Δw|| = 0.044614956
# Iteration 383: ||Δw|| = 0.044450456
# Iteration 384: ||Δw|| = 0.044286521
# Iteration 385: ||Δw|| = 0.044122735
# Iteration 386: ||Δw|| = 0.043958398
# Iteration 387: ||Δw|| = 0.043793598
# Iteration 388: ||Δw|| = 0.043627387
# Iteration 389: ||Δw|| = 0.043461732
# Iteration 390: ||Δw|| = 0.043297878
# Iteration 391: ||Δw|| = 0.043135539
# Iteration 392: ||Δw|| = 0.042974408
# Iteration 393: ||Δw|| = 0.042814276
# Iteration 394: ||Δw|| = 0.042655183
# Iteration 395: ||Δw|| = 0.042497557
# Iteration 396: ||Δw|| = 0.042341060
# Iteration 397: ||Δw|| = 0.042185397
# Iteration 398: ||Δw|| = 0.042030439
# Iteration 399: ||Δw|| = 0.041876331
# Iteration 400: ||Δw|| = 0.041722778
# Iteration 401: ||Δw|| = 0.041570008
# Iteration 402: ||Δw|| = 0.041417479
# Iteration 403: ||Δw|| = 0.041265628
# Iteration 404: ||Δw|| = 0.041114341
# Iteration 405: ||Δw|| = 0.040963641
# Iteration 406: ||Δw|| = 0.040813671
# Iteration 407: ||Δw|| = 0.040664308
# Iteration 408: ||Δw|| = 0.040515353
# Iteration 409: ||Δw|| = 0.040366769
# Iteration 410: ||Δw|| = 0.040218312
# Iteration 411: ||Δw|| = 0.040070170
# Iteration 412: ||Δw|| = 0.039922101
# Iteration 413: ||Δw|| = 0.039773988
# Iteration 414: ||Δw|| = 0.039626291
# Iteration 415: ||Δw|| = 0.039478637
# Iteration 416: ||Δw|| = 0.039331376
# Iteration 417: ||Δw|| = 0.039184433
# Iteration 418: ||Δw|| = 0.039037731
# Iteration 419: ||Δw|| = 0.038891168
# Iteration 420: ||Δw|| = 0.038744826
# Iteration 421: ||Δw|| = 0.038598605
# Iteration 422: ||Δw|| = 0.038452422
# Iteration 423: ||Δw|| = 0.038306498
# Iteration 424: ||Δw|| = 0.038160317
# Iteration 425: ||Δw|| = 0.038014031
# Iteration 426: ||Δw|| = 0.037867760
# Iteration 427: ||Δw|| = 0.037721669
# Iteration 428: ||Δw|| = 0.037575484
# Iteration 429: ||Δw|| = 0.037429503
# Iteration 430: ||Δw|| = 0.037283624
# Iteration 431: ||Δw|| = 0.037137859
# Iteration 432: ||Δw|| = 0.036991958
# Iteration 433: ||Δw|| = 0.036846044
# Iteration 434: ||Δw|| = 0.036700161
# Iteration 435: ||Δw|| = 0.036554000
# Iteration 436: ||Δw|| = 0.036407757
# Iteration 437: ||Δw|| = 0.036261438
# Iteration 438: ||Δw|| = 0.036115079
# Iteration 439: ||Δw|| = 0.035968830
# Iteration 440: ||Δw|| = 0.035822607
# Iteration 441: ||Δw|| = 0.035676338
# Iteration 442: ||Δw|| = 0.035529637
# Iteration 443: ||Δw|| = 0.035382905
# Iteration 444: ||Δw|| = 0.035235845
# Iteration 445: ||Δw|| = 0.035088742
# Iteration 446: ||Δw|| = 0.034941489
# Iteration 447: ||Δw|| = 0.034794058
# Iteration 448: ||Δw|| = 0.034646646
# Iteration 449: ||Δw|| = 0.034499133
# Iteration 450: ||Δw|| = 0.034351425
# Iteration 451: ||Δw|| = 0.034203594
# Iteration 452: ||Δw|| = 0.034055705
# Iteration 453: ||Δw|| = 0.033907666
# Iteration 454: ||Δw|| = 0.033759277
# Iteration 455: ||Δw|| = 0.033610640
# Iteration 456: ||Δw|| = 0.033461880
# Iteration 457: ||Δw|| = 0.033313151
# Iteration 458: ||Δw|| = 0.033164507
# Iteration 459: ||Δw|| = 0.033015575
# Iteration 460: ||Δw|| = 0.032866526
# Iteration 461: ||Δw|| = 0.032717199
# Iteration 462: ||Δw|| = 0.032567859
# Iteration 463: ||Δw|| = 0.032418571
# Iteration 464: ||Δw|| = 0.032269291
# Iteration 465: ||Δw|| = 0.032119780
# Iteration 466: ||Δw|| = 0.031969833
# Iteration 467: ||Δw|| = 0.031819507
# Iteration 468: ||Δw|| = 0.031668458
# Iteration 469: ||Δw|| = 0.031517158
# Iteration 470: ||Δw|| = 0.031365260
# Iteration 471: ||Δw|| = 0.031213001
# Iteration 472: ||Δw|| = 0.031060475
# Iteration 473: ||Δw|| = 0.030907861
# Iteration 474: ||Δw|| = 0.030754800
# Iteration 475: ||Δw|| = 0.030600583
# Iteration 476: ||Δw|| = 0.030445062
# Iteration 477: ||Δw|| = 0.030290343
# Iteration 478: ||Δw|| = 0.030136427
# Iteration 479: ||Δw|| = 0.029982959
# Iteration 480: ||Δw|| = 0.029830226
# Iteration 481: ||Δw|| = 0.029677688
# Iteration 482: ||Δw|| = 0.029525544
# Iteration 483: ||Δw|| = 0.029373946
# Iteration 484: ||Δw|| = 0.029222807
# Iteration 485: ||Δw|| = 0.029072036
# Iteration 486: ||Δw|| = 0.028921531
# Iteration 487: ||Δw|| = 0.028771338
# Iteration 488: ||Δw|| = 0.028621358
# Iteration 489: ||Δw|| = 0.028471456
# Iteration 490: ||Δw|| = 0.028321891
# Iteration 491: ||Δw|| = 0.028172532
# Iteration 492: ||Δw|| = 0.028023493
# Iteration 493: ||Δw|| = 0.027874708
# Iteration 494: ||Δw|| = 0.027726093
# Iteration 495: ||Δw|| = 0.027577591
# Iteration 496: ||Δw|| = 0.027428889
# Iteration 497: ||Δw|| = 0.027280428
# Iteration 498: ||Δw|| = 0.027132017
# Iteration 499: ||Δw|| = 0.026983894
# Iteration 500: ||Δw|| = 0.026835994
# Iteration 501: ||Δw|| = 0.026688141
# Iteration 502: ||Δw|| = 0.026540468
# Iteration 503: ||Δw|| = 0.026392741
# Iteration 504: ||Δw|| = 0.026245056
# Iteration 505: ||Δw|| = 0.026097592
# Iteration 506: ||Δw|| = 0.025950558
# Iteration 507: ||Δw|| = 0.025803931
# Iteration 508: ||Δw|| = 0.025657511
# Iteration 509: ||Δw|| = 0.025511429
# Iteration 510: ||Δw|| = 0.025365496
# Iteration 511: ||Δw|| = 0.025219722
# Iteration 512: ||Δw|| = 0.025074136
# Iteration 513: ||Δw|| = 0.024928696
# Iteration 514: ||Δw|| = 0.024783376
# Iteration 515: ||Δw|| = 0.024638115
# Iteration 516: ||Δw|| = 0.024493262
# Iteration 517: ||Δw|| = 0.024348514
# Iteration 518: ||Δw|| = 0.024203789
# Iteration 519: ||Δw|| = 0.024059281
# Iteration 520: ||Δw|| = 0.023914825
# Iteration 521: ||Δw|| = 0.023770482
# Iteration 522: ||Δw|| = 0.023626337
# Iteration 523: ||Δw|| = 0.023482455
# Iteration 524: ||Δw|| = 0.023338918
# Iteration 525: ||Δw|| = 0.023195664
# Iteration 526: ||Δw|| = 0.023052693
# Iteration 527: ||Δw|| = 0.022909889
# Iteration 528: ||Δw|| = 0.022767166
# Iteration 529: ||Δw|| = 0.022624549
# Iteration 530: ||Δw|| = 0.022481905
# Iteration 531: ||Δw|| = 0.022339636
# Iteration 532: ||Δw|| = 0.022197338
# Iteration 533: ||Δw|| = 0.022055263
# Iteration 534: ||Δw|| = 0.021913498
# Iteration 535: ||Δw|| = 0.021771951
# Iteration 536: ||Δw|| = 0.021630644
# Iteration 537: ||Δw|| = 0.021489695
# Iteration 538: ||Δw|| = 0.021348790
# Iteration 539: ||Δw|| = 0.021208182
# Iteration 540: ||Δw|| = 0.021067937
# Iteration 541: ||Δw|| = 0.020928028
# Iteration 542: ||Δw|| = 0.020788493
# Iteration 543: ||Δw|| = 0.020649377
# Iteration 544: ||Δw|| = 0.020510697
# Iteration 545: ||Δw|| = 0.020372347
# Iteration 546: ||Δw|| = 0.020234264
# Iteration 547: ||Δw|| = 0.020096306
# Iteration 548: ||Δw|| = 0.019958471
# Iteration 549: ||Δw|| = 0.019820860
# Iteration 550: ||Δw|| = 0.019683597
# Iteration 551: ||Δw|| = 0.019546582
# Iteration 552: ||Δw|| = 0.019409932
# Iteration 553: ||Δw|| = 0.019273502
# Iteration 554: ||Δw|| = 0.019137453
# Iteration 555: ||Δw|| = 0.019001805
# Iteration 556: ||Δw|| = 0.018866550
# Iteration 557: ||Δw|| = 0.018731662
# Iteration 558: ||Δw|| = 0.018596884
# Iteration 559: ||Δw|| = 0.018462404
# Iteration 560: ||Δw|| = 0.018328361
# Iteration 561: ||Δw|| = 0.018194730
# Iteration 562: ||Δw|| = 0.018061265
# Iteration 563: ||Δw|| = 0.017928204
# Iteration 564: ||Δw|| = 0.017795568
# Iteration 565: ||Δw|| = 0.017663281
# Iteration 566: ||Δw|| = 0.017531421
# Iteration 567: ||Δw|| = 0.017400030
# Iteration 568: ||Δw|| = 0.017269182
# Iteration 569: ||Δw|| = 0.017138736
# Iteration 570: ||Δw|| = 0.017008784
# Iteration 571: ||Δw|| = 0.016879302
# Iteration 572: ||Δw|| = 0.016750186
# Iteration 573: ||Δw|| = 0.016621520
# Iteration 574: ||Δw|| = 0.016493221
# Iteration 575: ||Δw|| = 0.016365273
# Iteration 576: ||Δw|| = 0.016237661
# Iteration 577: ||Δw|| = 0.016110329
# Iteration 578: ||Δw|| = 0.015983399
# Iteration 579: ||Δw|| = 0.015856816
# Iteration 580: ||Δw|| = 0.015730675
# Iteration 581: ||Δw|| = 0.015605035
# Iteration 582: ||Δw|| = 0.015479817
# Iteration 583: ||Δw|| = 0.015355013
# Iteration 584: ||Δw|| = 0.015230659
# Iteration 585: ||Δw|| = 0.015106704
# Iteration 586: ||Δw|| = 0.014983126
# Iteration 587: ||Δw|| = 0.014860011
# Iteration 588: ||Δw|| = 0.014737294
# Iteration 589: ||Δw|| = 0.014615005
# Iteration 590: ||Δw|| = 0.014493066
# Iteration 591: ||Δw|| = 0.014371568
# Iteration 592: ||Δw|| = 0.014250547
# Iteration 593: ||Δw|| = 0.014130060
# Iteration 594: ||Δw|| = 0.014010012
# Iteration 595: ||Δw|| = 0.013890384
# Iteration 596: ||Δw|| = 0.013771222
# Iteration 597: ||Δw|| = 0.013652616
# Iteration 598: ||Δw|| = 0.013534517
# Iteration 599: ||Δw|| = 0.013416911
# Iteration 600: ||Δw|| = 0.013299501
# Iteration 601: ||Δw|| = 0.013182599
# Iteration 602: ||Δw|| = 0.013066254
# Iteration 603: ||Δw|| = 0.012950520
# Iteration 604: ||Δw|| = 0.012835383
# Iteration 605: ||Δw|| = 0.012720817
# Iteration 606: ||Δw|| = 0.012606757
# Iteration 607: ||Δw|| = 0.012493217
# Iteration 608: ||Δw|| = 0.012380173
# Iteration 609: ||Δw|| = 0.012267413
# Iteration 610: ||Δw|| = 0.012155057
# Iteration 611: ||Δw|| = 0.012043274
# Iteration 612: ||Δw|| = 0.011932059
# Iteration 613: ||Δw|| = 0.011821316
# Iteration 614: ||Δw|| = 0.011711046
# Iteration 615: ||Δw|| = 0.011601240
# Iteration 616: ||Δw|| = 0.011491961
# Iteration 617: ||Δw|| = 0.011383063
# Iteration 618: ||Δw|| = 0.011274700
# Iteration 619: ||Δw|| = 0.011166794
# Iteration 620: ||Δw|| = 0.011059413
# Iteration 621: ||Δw|| = 0.010952549
# Iteration 622: ||Δw|| = 0.010846299
# Iteration 623: ||Δw|| = 0.010740437
# Iteration 624: ||Δw|| = 0.010634769
# Iteration 625: ||Δw|| = 0.010529556
# Iteration 626: ||Δw|| = 0.010424737
# Iteration 627: ||Δw|| = 0.010319936
# Iteration 628: ||Δw|| = 0.010214918
# Iteration 629: ||Δw|| = 0.010109753
# Iteration 630: ||Δw|| = 0.010005598
# Iteration 631: ||Δw|| = 0.009902180
# Iteration 632: ||Δw|| = 0.009799675
# Iteration 633: ||Δw|| = 0.009698032
# Iteration 634: ||Δw|| = 0.009597122
# Iteration 635: ||Δw|| = 0.009496823
# Iteration 636: ||Δw|| = 0.009397308
# Iteration 637: ||Δw|| = 0.009298573
# Iteration 638: ||Δw|| = 0.009200570
# Iteration 639: ||Δw|| = 0.009103349
# Iteration 640: ||Δw|| = 0.009006902
# Iteration 641: ||Δw|| = 0.008911195
# Iteration 642: ||Δw|| = 0.008816199
# Iteration 643: ||Δw|| = 0.008721936
# Iteration 644: ||Δw|| = 0.008628374
# Iteration 645: ||Δw|| = 0.008535553
# Iteration 646: ||Δw|| = 0.008443411
# Iteration 647: ||Δw|| = 0.008351949
# Iteration 648: ||Δw|| = 0.008261189
# Iteration 649: ||Δw|| = 0.008171085
# Iteration 650: ||Δw|| = 0.008081643
# Iteration 651: ||Δw|| = 0.007992878
# Iteration 652: ||Δw|| = 0.007904835
# Iteration 653: ||Δw|| = 0.007817491
# Iteration 654: ||Δw|| = 0.007730826
# Iteration 655: ||Δw|| = 0.007644817
# Iteration 656: ||Δw|| = 0.007559470
# Iteration 657: ||Δw|| = 0.007474782
# Iteration 658: ||Δw|| = 0.007390754
# Iteration 659: ||Δw|| = 0.007307421
# Iteration 660: ||Δw|| = 0.007224830
# Iteration 661: ||Δw|| = 0.007143356
# Iteration 662: ||Δw|| = 0.007062546
# Iteration 663: ||Δw|| = 0.006982389
# Iteration 664: ||Δw|| = 0.006902850
# Iteration 665: ||Δw|| = 0.006823919
# Iteration 666: ||Δw|| = 0.006745586
# Iteration 667: ||Δw|| = 0.006667905
# Iteration 668: ||Δw|| = 0.006590915
# Iteration 669: ||Δw|| = 0.006514620
# Iteration 670: ||Δw|| = 0.006438972
# Iteration 671: ||Δw|| = 0.006363944
# Iteration 672: ||Δw|| = 0.006289555
# Iteration 673: ||Δw|| = 0.006215822
# Iteration 674: ||Δw|| = 0.006142761
# Iteration 675: ||Δw|| = 0.006070401
# Iteration 676: ||Δw|| = 0.005998674
# Iteration 677: ||Δw|| = 0.005927571
# Iteration 678: ||Δw|| = 0.005857134
# Iteration 679: ||Δw|| = 0.005787380
# Iteration 680: ||Δw|| = 0.005718309
# Iteration 681: ||Δw|| = 0.005649941
# Iteration 682: ||Δw|| = 0.005582257
# Iteration 683: ||Δw|| = 0.005515256
# Iteration 684: ||Δw|| = 0.005448969
# Iteration 685: ||Δw|| = 0.005383393
# Iteration 686: ||Δw|| = 0.005318540
# Iteration 687: ||Δw|| = 0.005254379
# Iteration 688: ||Δw|| = 0.005190938
# Iteration 689: ||Δw|| = 0.005128155
# Iteration 690: ||Δw|| = 0.005065978
# Iteration 691: ||Δw|| = 0.005004547
# Iteration 692: ||Δw|| = 0.004943838
# Iteration 693: ||Δw|| = 0.004883794
# Iteration 694: ||Δw|| = 0.004824432
# Iteration 695: ||Δw|| = 0.004765805
# Iteration 696: ||Δw|| = 0.004707891
# Iteration 697: ||Δw|| = 0.004650722
# Iteration 698: ||Δw|| = 0.004594313
# Iteration 699: ||Δw|| = 0.004538611
# Iteration 700: ||Δw|| = 0.004483637
# Iteration 701: ||Δw|| = 0.004429382
# Iteration 702: ||Δw|| = 0.004375866
# Iteration 703: ||Δw|| = 0.004323085
# Iteration 704: ||Δw|| = 0.004270968
# Iteration 705: ||Δw|| = 0.004219620
# Iteration 706: ||Δw|| = 0.004169001
# Iteration 707: ||Δw|| = 0.004119128
# Iteration 708: ||Δw|| = 0.004070017
# Iteration 709: ||Δw|| = 0.004021674
# Iteration 710: ||Δw|| = 0.003974082
# Iteration 711: ||Δw|| = 0.003927255
# Iteration 712: ||Δw|| = 0.003881203
# Iteration 713: ||Δw|| = 0.003835923
# Iteration 714: ||Δw|| = 0.003791391
# Iteration 715: ||Δw|| = 0.003747557
# Iteration 716: ||Δw|| = 0.003704466
# Iteration 717: ||Δw|| = 0.003662110
# Iteration 718: ||Δw|| = 0.003620536
# Iteration 719: ||Δw|| = 0.003579745
# Iteration 720: ||Δw|| = 0.003539740
# Iteration 721: ||Δw|| = 0.003500523
# Iteration 722: ||Δw|| = 0.003462090
# Iteration 723: ||Δw|| = 0.003424444
# Iteration 724: ||Δw|| = 0.003387583
# Iteration 725: ||Δw|| = 0.003351511
# Iteration 726: ||Δw|| = 0.003316212
# Iteration 727: ||Δw|| = 0.003281702
# Iteration 728: ||Δw|| = 0.003247951
# Iteration 729: ||Δw|| = 0.003214976
# Iteration 730: ||Δw|| = 0.003182775
# Iteration 731: ||Δw|| = 0.003151345
# Iteration 732: ||Δw|| = 0.003120686
# Iteration 733: ||Δw|| = 0.003090789
# Iteration 734: ||Δw|| = 0.003061634
# Iteration 735: ||Δw|| = 0.003033246
# Iteration 736: ||Δw|| = 0.003005620
# Iteration 737: ||Δw|| = 0.002978757
# Iteration 738: ||Δw|| = 0.002952655
# Iteration 739: ||Δw|| = 0.002927311
# Iteration 740: ||Δw|| = 0.002902718
# Iteration 741: ||Δw|| = 0.002878873
# Iteration 742: ||Δw|| = 0.002855761
# Iteration 743: ||Δw|| = 0.002833376
# Iteration 744: ||Δw|| = 0.002811703
# Iteration 745: ||Δw|| = 0.002790752
# Iteration 746: ||Δw|| = 0.002770505
# Iteration 747: ||Δw|| = 0.002750953
# Iteration 748: ||Δw|| = 0.002732100
# Iteration 749: ||Δw|| = 0.002713938
# Iteration 750: ||Δw|| = 0.002696451
# Iteration 751: ||Δw|| = 0.002679645
# Iteration 752: ||Δw|| = 0.002663493
# Iteration 753: ||Δw|| = 0.002647995
# Iteration 754: ||Δw|| = 0.002633146
# Iteration 755: ||Δw|| = 0.002618937
# Iteration 756: ||Δw|| = 0.002605356
# Iteration 757: ||Δw|| = 0.002592387
# Iteration 758: ||Δw|| = 0.002580021
# Iteration 759: ||Δw|| = 0.002568250
# Iteration 760: ||Δw|| = 0.002557058
# Iteration 761: ||Δw|| = 0.002546436
# Iteration 762: ||Δw|| = 0.002536373
# Iteration 763: ||Δw|| = 0.002526857
# Iteration 764: ||Δw|| = 0.002517870
# Iteration 765: ||Δw|| = 0.002509409
# Iteration 766: ||Δw|| = 0.002501449
# Iteration 767: ||Δw|| = 0.002493979
# Iteration 768: ||Δw|| = 0.002486990
# Iteration 769: ||Δw|| = 0.002480467
# Iteration 770: ||Δw|| = 0.002474405
# Iteration 771: ||Δw|| = 0.002468774
# Iteration 772: ||Δw|| = 0.002463561
# Iteration 773: ||Δw|| = 0.002458768
# Iteration 774: ||Δw|| = 0.002454380
# Iteration 775: ||Δw|| = 0.002450384
# Iteration 776: ||Δw|| = 0.002446764
# Iteration 777: ||Δw|| = 0.002443510
# Iteration 778: ||Δw|| = 0.002440600
# Iteration 779: ||Δw|| = 0.002438031
# Iteration 780: ||Δw|| = 0.002435783
# Iteration 781: ||Δw|| = 0.002433852
# Iteration 782: ||Δw|| = 0.002432219
# Iteration 783: ||Δw|| = 0.002430875
# Iteration 784: ||Δw|| = 0.002429801
# Iteration 785: ||Δw|| = 0.002428990
# Iteration 786: ||Δw|| = 0.002428430
# Iteration 787: ||Δw|| = 0.002428111
# Iteration 788: ||Δw|| = 0.002428017
# Iteration 789: ||Δw|| = 0.002428140
# Iteration 790: ||Δw|| = 0.002428467
# Iteration 791: ||Δw|| = 0.002428987
# Iteration 792: ||Δw|| = 0.002429689
# Iteration 793: ||Δw|| = 0.002430562
# Iteration 794: ||Δw|| = 0.002431595
# Iteration 795: ||Δw|| = 0.002432780
# Iteration 796: ||Δw|| = 0.002434105
# Iteration 797: ||Δw|| = 0.002435563
# Iteration 798: ||Δw|| = 0.002437145
# Iteration 799: ||Δw|| = 0.002438836
# Iteration 800: ||Δw|| = 0.002440634
# Iteration 801: ||Δw|| = 0.002442526
# Iteration 802: ||Δw|| = 0.002444505
# Iteration 803: ||Δw|| = 0.002446560
# Iteration 804: ||Δw|| = 0.002448687
# Iteration 805: ||Δw|| = 0.002450874
# Iteration 806: ||Δw|| = 0.002453116
# Iteration 807: ||Δw|| = 0.002455406
# Iteration 808: ||Δw|| = 0.002457736
# Iteration 809: ||Δw|| = 0.002460100
# Iteration 810: ||Δw|| = 0.002462490
# Iteration 811: ||Δw|| = 0.002464902
# Iteration 812: ||Δw|| = 0.002467327
# Iteration 813: ||Δw|| = 0.002469762
# Iteration 814: ||Δw|| = 0.002472198
# Iteration 815: ||Δw|| = 0.002474633
# Iteration 816: ||Δw|| = 0.002477059
# Iteration 817: ||Δw|| = 0.002479466
# Iteration 818: ||Δw|| = 0.002481856
# Iteration 819: ||Δw|| = 0.002484223
# Iteration 820: ||Δw|| = 0.002486566
# Iteration 821: ||Δw|| = 0.002488877
# Iteration 822: ||Δw|| = 0.002491148
# Iteration 823: ||Δw|| = 0.002493380
# Iteration 824: ||Δw|| = 0.002495566
# Iteration 825: ||Δw|| = 0.002497705
# Iteration 826: ||Δw|| = 0.002499791
# Iteration 827: ||Δw|| = 0.002501823
# Iteration 828: ||Δw|| = 0.002503793
# Iteration 829: ||Δw|| = 0.002505702
# Iteration 830: ||Δw|| = 0.002507545
# Iteration 831: ||Δw|| = 0.002509319
# Iteration 832: ||Δw|| = 0.002511024
# Iteration 833: ||Δw|| = 0.002512657
# Iteration 834: ||Δw|| = 0.002514214
# Iteration 835: ||Δw|| = 0.002515693
# Iteration 836: ||Δw|| = 0.002517091
# Iteration 837: ||Δw|| = 0.002518408
# Iteration 838: ||Δw|| = 0.002519642
# Iteration 839: ||Δw|| = 0.002520789
# Iteration 840: ||Δw|| = 0.002521847
# Iteration 841: ||Δw|| = 0.002522815
# Iteration 842: ||Δw|| = 0.002523692
# Iteration 843: ||Δw|| = 0.002524475
# Iteration 844: ||Δw|| = 0.002525163
# Iteration 845: ||Δw|| = 0.002525757
# Iteration 846: ||Δw|| = 0.002526255
# Iteration 847: ||Δw|| = 0.002526655
# Iteration 848: ||Δw|| = 0.002526957
# Iteration 849: ||Δw|| = 0.002527155
# Iteration 850: ||Δw|| = 0.002527251
# Iteration 851: ||Δw|| = 0.002527243
# Iteration 852: ||Δw|| = 0.002527133
# Iteration 853: ||Δw|| = 0.002526923
# Iteration 854: ||Δw|| = 0.002526609
# Iteration 855: ||Δw|| = 0.002526190
# Iteration 856: ||Δw|| = 0.002525665
# Iteration 857: ||Δw|| = 0.002525035
# Iteration 858: ||Δw|| = 0.002524300
# Iteration 859: ||Δw|| = 0.002523458
# Iteration 860: ||Δw|| = 0.002522510
# Iteration 861: ||Δw|| = 0.002521456
# Iteration 862: ||Δw|| = 0.002520293
# Iteration 863: ||Δw|| = 0.002519026
# Iteration 864: ||Δw|| = 0.002517651
# Iteration 865: ||Δw|| = 0.002516170
# Iteration 866: ||Δw|| = 0.002514581
# Iteration 867: ||Δw|| = 0.002512883
# Iteration 868: ||Δw|| = 0.002511078
# Iteration 869: ||Δw|| = 0.002509164
# Iteration 870: ||Δw|| = 0.002507145
# Iteration 871: ||Δw|| = 0.002505018
# Iteration 872: ||Δw|| = 0.002502786
# Iteration 873: ||Δw|| = 0.002500448
# Iteration 874: ||Δw|| = 0.002498004
# Iteration 875: ||Δw|| = 0.002495452
# Iteration 876: ||Δw|| = 0.002492795
# Iteration 877: ||Δw|| = 0.002490034
# Iteration 878: ||Δw|| = 0.002487169
# Iteration 879: ||Δw|| = 0.002484201
# Iteration 880: ||Δw|| = 0.002481131
# Iteration 881: ||Δw|| = 0.002477959
# Iteration 882: ||Δw|| = 0.002474687
# Iteration 883: ||Δw|| = 0.002471315
# Iteration 884: ||Δw|| = 0.002467843
# Iteration 885: ||Δw|| = 0.002464272
# Iteration 886: ||Δw|| = 0.002460602
# Iteration 887: ||Δw|| = 0.002456848
# Iteration 888: ||Δw|| = 0.002453007
# Iteration 889: ||Δw|| = 0.002449065
# Iteration 890: ||Δw|| = 0.002445023
# Iteration 891: ||Δw|| = 0.002440883
# Iteration 892: ||Δw|| = 0.002436644
# Iteration 893: ||Δw|| = 0.002432309
# Iteration 894: ||Δw|| = 0.002427877
# Iteration 895: ||Δw|| = 0.002423349
# Iteration 896: ||Δw|| = 0.002418728
# Iteration 897: ||Δw|| = 0.002414014
# Iteration 898: ||Δw|| = 0.002409208
# Iteration 899: ||Δw|| = 0.002404311
# Iteration 900: ||Δw|| = 0.002399323
# Iteration 901: ||Δw|| = 0.002394247
# Iteration 902: ||Δw|| = 0.002389082
# Iteration 903: ||Δw|| = 0.002383829
# Iteration 904: ||Δw|| = 0.002378489
# Iteration 905: ||Δw|| = 0.002373065
# Iteration 906: ||Δw|| = 0.002367555
# Iteration 907: ||Δw|| = 0.002361962
# Iteration 908: ||Δw|| = 0.002356290
# Iteration 909: ||Δw|| = 0.002350536
# Iteration 910: ||Δw|| = 0.002344701
# Iteration 911: ||Δw|| = 0.002338786
# Iteration 912: ||Δw|| = 0.002332793
# Iteration 913: ||Δw|| = 0.002326723
# Iteration 914: ||Δw|| = 0.002320576
# Iteration 915: ||Δw|| = 0.002314353
# Iteration 916: ||Δw|| = 0.002308056
# Iteration 917: ||Δw|| = 0.002301683
# Iteration 918: ||Δw|| = 0.002295236
# Iteration 919: ||Δw|| = 0.002288718
# Iteration 920: ||Δw|| = 0.002282129
# Iteration 921: ||Δw|| = 0.002275470
# Iteration 922: ||Δw|| = 0.002268742
# Iteration 923: ||Δw|| = 0.002261947
# Iteration 924: ||Δw|| = 0.002255086
# Iteration 925: ||Δw|| = 0.002248160
# Iteration 926: ||Δw|| = 0.002241169
# Iteration 927: ||Δw|| = 0.002234112
# Iteration 928: ||Δw|| = 0.002226993
# Iteration 929: ||Δw|| = 0.002219811
# Iteration 930: ||Δw|| = 0.002212569
# Iteration 931: ||Δw|| = 0.002205266
# Iteration 932: ||Δw|| = 0.002197904
# Iteration 933: ||Δw|| = 0.002190485
# Iteration 934: ||Δw|| = 0.002183009
# Iteration 935: ||Δw|| = 0.002175477
# Iteration 936: ||Δw|| = 0.002167891
# Iteration 937: ||Δw|| = 0.002160250
# Iteration 938: ||Δw|| = 0.002152555
# Iteration 939: ||Δw|| = 0.002144807
# Iteration 940: ||Δw|| = 0.002137008
# Iteration 941: ||Δw|| = 0.002129159
# Iteration 942: ||Δw|| = 0.002121261
# Iteration 943: ||Δw|| = 0.002113314
# Iteration 944: ||Δw|| = 0.002105319
# Iteration 945: ||Δw|| = 0.002097278
# Iteration 946: ||Δw|| = 0.002089190
# Iteration 947: ||Δw|| = 0.002081057
# Iteration 948: ||Δw|| = 0.002072880
# Iteration 949: ||Δw|| = 0.002064659
# Iteration 950: ||Δw|| = 0.002056396
# Iteration 951: ||Δw|| = 0.002048092
# Iteration 952: ||Δw|| = 0.002039746
# Iteration 953: ||Δw|| = 0.002031360
# Iteration 954: ||Δw|| = 0.002022936
# Iteration 955: ||Δw|| = 0.002014474
# Iteration 956: ||Δw|| = 0.002005976
# Iteration 957: ||Δw|| = 0.001997442
# Iteration 958: ||Δw|| = 0.001988873
# Iteration 959: ||Δw|| = 0.001980269
# Iteration 960: ||Δw|| = 0.001971632
# Iteration 961: ||Δw|| = 0.001962963
# Iteration 962: ||Δw|| = 0.001954264
# Iteration 963: ||Δw|| = 0.001945533
# Iteration 964: ||Δw|| = 0.001936773
# Iteration 965: ||Δw|| = 0.001927985
# Iteration 966: ||Δw|| = 0.001919168
# Iteration 967: ||Δw|| = 0.001910323
# Iteration 968: ||Δw|| = 0.001901451
# Iteration 969: ||Δw|| = 0.001892551
# Iteration 970: ||Δw|| = 0.001883627
# Iteration 971: ||Δw|| = 0.001874678
# Iteration 972: ||Δw|| = 0.001865707
# Iteration 973: ||Δw|| = 0.001856712
# Iteration 974: ||Δw|| = 0.001847696
# Iteration 975: ||Δw|| = 0.001838659
# Iteration 976: ||Δw|| = 0.001829603
# Iteration 977: ||Δw|| = 0.001820527
# Iteration 978: ||Δw|| = 0.001811432
# Iteration 979: ||Δw|| = 0.001802319
# Iteration 980: ||Δw|| = 0.001793188
# Iteration 981: ||Δw|| = 0.001784042
# Iteration 982: ||Δw|| = 0.001774882
# Iteration 983: ||Δw|| = 0.001765712
# Iteration 984: ||Δw|| = 0.001756529
# Iteration 985: ||Δw|| = 0.001747333
# Iteration 986: ||Δw|| = 0.001738123
# Iteration 987: ||Δw|| = 0.001728900
# Iteration 988: ||Δw|| = 0.001719665
# Iteration 989: ||Δw|| = 0.001710421
# Iteration 990: ||Δw|| = 0.001701165
# Iteration 991: ||Δw|| = 0.001691900
# Iteration 992: ||Δw|| = 0.001682627
# Iteration 993: ||Δw|| = 0.001673347
# Iteration 994: ||Δw|| = 0.001664061
# Iteration 995: ||Δw|| = 0.001654769
# Iteration 996: ||Δw|| = 0.001645471
# Iteration 997: ||Δw|| = 0.001636169
# Iteration 998: ||Δw|| = 0.001626865
# Iteration 999: ||Δw|| = 0.001617557
# q-value at 0: 7.395904940930719
# Option price: 5.618367520369603
# array([5.61836752])

# %%
K = sampler.strike
T = sampler.time_grid[-1]
r = -np.log(sampler.discount_factor[0, 1] / sampler.discount_factor[0, 0]) / sampler.time_deltas[0]
n_paths, n_times, _ = sampler.markov_state.shape
gamma = np.exp(-r * sampler.time_deltas[0])
S_paths = sampler.markov_state[:, :, 0]
time_grid_expanded = np.tile(sampler.time_grid, (n_paths, 1))
phi_all_raw = pricer._basis_functions_raw(S_paths, K, time_grid_expanded, T)
phi_all = pricer._scale_features(phi_all_raw, fit=True)

phi_curr = phi_all[:, :-1, :]  # Текущие состояния (t)
phi_next = phi_all[:, 1:, :]   # Следующие состояния (t+1)
payoff = sampler.payoff
payoff_next = sampler.payoff[:, 1:]  # Выплаты в t+1

# Выравнивание в 1D
n_features = phi_all.shape[-1]
phi_all_flat = phi_all.reshape(-1, n_features)
phi_curr_flat = phi_curr.reshape(-1, n_features)
phi_next_flat = phi_next.reshape(-1, n_features)
payoff_flat = payoff.reshape(-1)
payoff_next_flat = payoff_next.reshape(-1)

# %%
def bellman_opt_eq(phi_curr, phi_next, payoff_next, w, gamma, w_next=None):
    if w_next is None:
        w_next = w
    return ((
        phi_curr @ w - 
        gamma * np.max(
            np.concat([
                payoff_next[np.newaxis], 
                (phi_next @ w_next)[np.newaxis] \
                    * np.array(
                        (([1] * (n_times - 2)) + [0]) * n_paths
                    )
            ]), 
            axis=0
        )
    ) ** 2).mean()

# %%
bellman_opt_eq(
    phi_curr_flat, 
    phi_next_flat, 
    payoff_next_flat, 
    pricer.w, 
    gamma
)
# Out:
# np.float64(0.2655582090657397)

# %%
bellman_opt_eq(
    phi_curr_flat, 
    phi_next_flat, 
    payoff_next_flat, 
    pricer.w * 0.99, 
    gamma
)
# Out:
# np.float64(0.2617855715432927)

# %%
bellman_opt_eq(
    phi_curr_flat, 
    phi_next_flat, 
    payoff_next_flat, 
    pricer.w * 0.99, 
    gamma,
    pricer.w
)
# Out:
# np.float64(0.27526519771312635)

# %%
def price(phi_all, n_paths, payoff, w, gamma):
    pv_payoffs = np.zeros(n_paths)
    for p in range(n_paths):
        for t in range(n_times):
            phi_t = phi_all[p, t]
            Q_cont = phi_t @ w
            payoff_t = payoff[p, t]
            
            disc_factor = gamma**t
            if payoff_t >= Q_cont or t == n_times - 1:
                pv_payoffs[p] = disc_factor * payoff_t
                break
    return pv_payoffs.mean()

# %%
price(
    phi_all,
    n_paths, 
    sampler.payoff,
    pricer.w,
    gamma
)
# Out:
# np.float64(5.618367520369498)

# %%
price(
    phi_all,
    n_paths, 
    sampler.payoff,
    pricer.w * 0.99,
    gamma
)
# Out:
# np.float64(5.829835298211789)

# %%
pricer.w
# Out:
# array([   7.54240469,  198.68624736, -269.96836358,   78.93667263,
#           6.33361448,    1.27138567,    6.50162853])

# %%
import numpy as np
from numba import njit

@njit
def spread_with_gamma(arr, gamma):
    result = np.zeros_like(arr)
    rows, cols = np.where(np.abs(arr) > 1e-6)
    
    for i, j in zip(rows, cols):
        if arr[i, j] == 0:
            continue
            
        # Создаем диапазон для влияния
        k_values = np.arange(j + 1)
        powers = j - k_values
        influences = (gamma ** powers) * arr[i, j]
        
        # Находим позиции, которые еще не заполнены
        target_pos = k_values[result[i, k_values] == 0]
        result[i, target_pos] = influences[target_pos]
        
        # Обнуляем где power == 0
        result[i, j] = 0
        
    return result

# %%
a = np.array([
    [0, 0, 0, 1, 0, 0],
    [0,1,0,3,0,0]
])
gamma = 2

# %%
spread_with_gamma(a, gamma)

# %%
from copy import deepcopy
import numpy as np
from typing import Optional
from sklearn.preprocessing import StandardScaler
from src.pricers.abstract_pricer import PricerAbstract
from src.samplers.abstract_sampler import SamplerAbstract


import numpy as np
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from tqdm.auto import tqdm
import matplotlib.pyplot as plt

# %%
from src.samplers.geometric_brownian_motion_put_sampler import GeometricBrownianMotionPutSampler
sampler = GeometricBrownianMotionPutSampler(**{
    "asset0": 100.0,
    "sigma": 0.2,
    "r": 0.05,
    "strike": 100.0,
    "t": 1.0,
    "cnt_times": 60,
    "seed": None, 
    "cnt_trajectories": 1_000_000
})

# %% [markdown]
# # LSPI

# %%
from dataclasses import dataclass
@dataclass 
class A:
    _: int

self = A(0)

def _create_features(self, markov_state: np.ndarray, time_grid: np.ndarray) -> np.ndarray:
    n_paths, n_times, state_dim = markov_state.shape
    T = time_grid[-1]
    
    # Нормализованное время до экспирации
    time_to_exp = (T - time_grid) / T
    time_to_exp = np.tile(time_to_exp, (n_paths, 1))[..., None]
    
    # Объединяем время и состояние
    features = np.concatenate([time_to_exp, markov_state], axis=-1)
    flat_features = features.reshape(-1, features.shape[-1])
    
    # Первый вызов - инициализируем и фитим трансформеры
    if not self.is_fitted_:
        self.scaler_ = StandardScaler()
        self.poly_ = PolynomialFeatures(degree=self.degree, include_bias=True)
        
        scaled = self.scaler_.fit_transform(flat_features)
        poly_features = self.poly_.fit_transform(scaled)
        self.n_features_ = poly_features.shape[1]
        self.is_fitted_ = True
    else:
        # Используем обученные трансформеры
        scaled = self.scaler_.transform(flat_features)
        poly_features = self.poly_.transform(scaled)
    
    return poly_features.reshape(n_paths, n_times, -1)

def _create_features(self, markov_state: np.ndarray, time_grid: np.ndarray) -> np.ndarray:
    M = markov_state[:, :, 0] / 100.
    exp_term = np.exp(-M / 2.0)
    T = time_grid[-1]
    t = time_grid

    phi = np.zeros((*markov_state[:, :, 0].shape, 7), dtype = float)
    phi[:, :, 0] = 1.0
    phi[:, :, 1] = exp_term
    phi[:, :, 2] = exp_term * (1.0 - M)
    phi[:, :, 3] = exp_term * (1.0 - 2.0 * M + 0.5 * M * M)
    phi[:, :, 4] = np.sin(np.pi * (T - t) / (2.0 * T))
    phi[:, :, 5] = np.log(np.maximum(T - t, 1e-10)) # 1e-10 чтобы не было log(0)
    phi[:, :, 6] = (t / T) ** 2

    scaler = StandardScaler()
    phi_reshaped = phi[:, :, 1:].reshape(-1, 6)
    phi_scaled = scaler.fit_transform(phi_reshaped)
    phi_scaled = phi_scaled.reshape(phi.shape[0], phi.shape[1], 6)


    phi_final = np.zeros_like(phi)
    phi_final[:, :, 0] = phi[:, :, 0]
    phi_final[:, :, 1:] = phi_scaled

    return phi_final

# %%
self.sampler = sampler
self.sampler.sample()

# %%
r = -np.log(self.sampler.discount_factor[0, 1] / self.sampler.discount_factor[0, 0]) / (self.sampler.time_deltas[0])
self.dt = sampler.time_deltas[0]
self.is_fitted_ = False
self.degree = 3
self.iterations = 100
self.tol = 1e-6
self.reg_alpha = 1e-2
quiet = False

# %%
# Параметры
n_paths, n_times, _ = self.sampler.markov_state.shape
gamma = np.exp(-r * self.dt)  # Коэффициент дисконтирования

# Создаем признаки
phi_all = _create_features(self,
    self.sampler.markov_state, 
    self.sampler.time_grid
)
n_features = phi_all.shape[-1]


w = np.zeros(n_features)

# Подготовка данных
phi_curr = phi_all[:, :-1, :]  # Текущие состояния (t)
phi_next = phi_all[:, 1:, :]    # Следующие состояния (t+1)
payoff_next = self.sampler.payoff[:, 1:]  # Выплаты в t+1

# Выравнивание в 1D
phi_curr_flat = phi_curr.reshape(-1, n_features)
phi_next_flat = phi_next.reshape(-1, n_features)
payoff_next_flat = payoff_next.reshape(-1)

# Флаг нетерминальных состояний
non_terminal = np.tile(
    np.arange(n_times-1, dtype=int) < n_times-2, 
    (n_paths, 1)
)
non_terminal_flat = non_terminal.reshape(-1)

# Итерации LSPI
for it in tqdm(range(self.iterations), desc="LSPI iterations"):
    prev_w = deepcopy(w)
    
    # Вычисляем Q-значения продолжения
    Q_cont_next = phi_next_flat @ w
    
    # Условие продолжения
    continue_cond = non_terminal_flat & (Q_cont_next >= payoff_next_flat)
    
    # Формируем систему уравнений
    diff_phi = phi_curr_flat - gamma * continue_cond[:, None] * phi_next_flat
    A = phi_curr_flat.T @ diff_phi
    b = gamma * phi_curr_flat.T @ ((~continue_cond) * payoff_next_flat)

    if self.reg_alpha is not None:
        A += np.eye(A.shape[0]) * self.reg_alpha
    w = np.linalg.solve(A, b)
    
    # Проверка сходимости
    diff_norm = np.linalg.norm(w - prev_w)
    if not quiet:
        print(f"Iteration {it}: ||Δw|| = {diff_norm:.9f}")
    if diff_norm < self.tol:
        if not quiet:
            print(f"Converged after {it} iterations")
        break

self.w = w

# %%
pv_payoffs = np.zeros(n_paths)
for p in range(n_paths):
    for t in range(n_times):
        # Признаки текущего состояния
        phi_t = phi_all[p, t]
        Q_cont = phi_t @ w
        payoff_t = self.sampler.payoff[p, t]
        
        # Условие исполнения
        if payoff_t >= Q_cont or t == n_times - 1:
            disc_factor = self.sampler.discount_factor[p, t]
            pv_payoffs[p] = disc_factor * payoff_t
            break
mean = pv_payoffs.mean()

plt.figure(figsize=(10, 6))
plt.hist(pv_payoffs)
plt.axvline(mean)
plt.title("Train")
plt.grid()
plt.show()
mean

# %%
self.sampler.sample()

# %%
phi_all = _create_features(self,
    self.sampler.markov_state, 
    self.sampler.time_grid
)
pv_payoffs = np.zeros(n_paths)
for p in range(n_paths):
    for t in range(n_times):
        # Признаки текущего состояния
        phi_t = phi_all[p, t]
        Q_cont = phi_t @ w
        payoff_t = self.sampler.payoff[p, t]
        
        # Условие исполнения
        if payoff_t >= Q_cont or t == n_times - 1:
            disc_factor = self.sampler.discount_factor[p, t]
            pv_payoffs[p] = disc_factor * payoff_t
            break
mean = pv_payoffs.mean()

plt.figure(figsize=(10, 6))
plt.hist(pv_payoffs)
plt.axvline(mean)
plt.title("Test")
plt.grid()
plt.show()
mean

# %%
n_traj = 10

plt.figure(figsize=(10, 6))
plt.plot(self.sampler.time_grid, self.sampler.payoff[:n_traj, :].T)
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(self.sampler.time_grid, (self.sampler.payoff[:, :] * self.sampler.discount_factor)[:n_traj, :].T)
plt.show()

# %% [markdown]
# # LSMC

# %%
from src.pricers.american_monte_carlo import AmericanMonteCarloPricer
pricer = AmericanMonteCarloPricer(sampler, degree=3)
pricer.price();
pricer.result

# %%
import scipy
exercise_boundary_lsmc = []
for i, t in tqdm(list(
    enumerate(sampler.time_grid)
)):
    if pricer.weights[i] is None:
        print("None")
        exercise_boundary_lsmc.append(None)
        continue

    func_to_find_root = lambda x: (
        sampler.discount_factor[0, i] * max(0, 100. - x) - 
        (
            pricer.basis_functions_transformer.transform(
                pricer.scalers[i].transform([[x]])
            ) @ pricer.weights[i]
        ).reshape(-1)[0]
    )

    root = scipy.optimize.minimize_scalar(
        lambda x: func_to_find_root(x)**2,
        bounds=[np.percentile(sampler.markov_state[:, i, 0], 0.99), 100]
    )["x"]
    
    if abs(func_to_find_root(root)) < 1e-6:
        exercise_boundary_lsmc.append(
            root
        )
    else:
        exercise_boundary_lsmc.append(
            None
        )

    payoff = np.vectorize(lambda x: sampler.discount_factor[0, i] * max(0, 100. - x))
    continuation_value = np.vectorize(lambda x: (
        pricer.basis_functions_transformer.transform(
            pricer.scalers[i].transform([[x]])
        ) @ pricer.weights[i]
    ).reshape(-1)[0])
    plt.figure(figsize=(10, 6))
    plt.title(f"Continuation value at t={t}")
    grid = np.linspace(np.percentile(sampler.markov_state[:, i, 0], 0.99), 100, 30)
    plt.plot(grid, continuation_value(grid), label="CV")
    plt.plot(grid, payoff(grid), label="Payoff")
    plt.legend()
    plt.grid()
    plt.show()

plt.figure(figsize=(10, 6))
plt.plot(sampler.time_grid, exercise_boundary_lsmc, "-o", markersize=2)
plt.show()

# %%
exercise_boundary_lsmc

# %%
sampler.discount_factor[0, i]

# %%
exercise_boundary_lsmc

# %%
# import scipy
# exercise_boundary_lsmc = []
# for i, t in tqdm(list(enumerate(range(len(sampler.time_grid))))):
#     if pricer.weights[i] is None:
#         exercise_boundary_lsmc.append(None)
#         continue
#     exercise_boundary_lsmc.append(
#         scipy.optimize.minimize_scalar(
#             lambda x: (
#                 sampler.discount_factor[0, i] * max(0, 100. - x) - 
#                 (
#                     pricer.basis_functions_transformer.transform([[x]]) @ pricer.weights[i]
#                 ).reshape(-1)[0]
#             )**2,
#             bounds=[0, 100]
#         )["x"]
#     )

# plt.figure(figsize=(10, 6))
# plt.plot(sampler.time_grid, exercise_boundary_lsmc)
# plt.show()

# %%
pricer.weights
