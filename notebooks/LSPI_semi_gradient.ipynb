# %%
if 'already_executed' not in globals():
    already_executed = False

if not already_executed:
    import os
    os.chdir("../")
    # %load_ext autoreload
    # %autoreload 2
    already_executed = True

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from src.pricers.pricers import LSPISemiGradientPricer as LSPIPricer
from src.samplers.samplers import GeometricBrownianMotionPutSampler

# %%
sampler = GeometricBrownianMotionPutSampler(**{
    "asset0": 100.0,
    "sigma": 0.2,
    "r": 0.05,
    "strike": 100.0,
    "t": 1.0,
    "cnt_times": 365,
    "seed": None, 
    "cnt_trajectories": 1_000_0
})

# %%
pricer = LSPIPricer(sampler=sampler, **{
    "iterations": 1000,
    "lambda_reg": 0,
    "tol": 1e-9
})

# %%
pricer.price(test=False, quiet=False)
# Out:
# GBM sampling:   0%|          | 0/364 [00:00<?, ?it/s]
# Iteration 0: ||Δw|| = 520.640801398
# Iteration 1: ||Δw|| = 32.100551662
# Iteration 2: ||Δw|| = 13.441596708
# Iteration 3: ||Δw|| = 6.096826936
# Iteration 4: ||Δw|| = 2.548319922
# Iteration 5: ||Δw|| = 0.953443067
# Iteration 6: ||Δw|| = 1.156776703
# Iteration 7: ||Δw|| = 1.735432880
# Iteration 8: ||Δw|| = 2.146858842
# Iteration 9: ||Δw|| = 2.402443039
# Iteration 10: ||Δw|| = 2.551440721
# Iteration 11: ||Δw|| = 2.648237680
# Iteration 12: ||Δw|| = 2.712566317
# Iteration 13: ||Δw|| = 2.753880747
# Iteration 14: ||Δw|| = 2.774284330
# Iteration 15: ||Δw|| = 2.773745230
# Iteration 16: ||Δw|| = 2.760575885
# Iteration 17: ||Δw|| = 2.734155836
# Iteration 18: ||Δw|| = 2.700323181
# Iteration 19: ||Δw|| = 2.661411466
# Iteration 20: ||Δw|| = 2.617293834
# Iteration 21: ||Δw|| = 2.569466550
# Iteration 22: ||Δw|| = 2.521286853
# Iteration 23: ||Δw|| = 2.471901707
# Iteration 24: ||Δw|| = 2.421206511
# Iteration 25: ||Δw|| = 2.370370796
# Iteration 26: ||Δw|| = 2.319200168
# Iteration 27: ||Δw|| = 2.268223689
# Iteration 28: ||Δw|| = 2.217024834
# Iteration 29: ||Δw|| = 2.165846410
# Iteration 30: ||Δw|| = 2.114249644
# Iteration 31: ||Δw|| = 2.063243897
# Iteration 32: ||Δw|| = 2.012668036
# Iteration 33: ||Δw|| = 1.961762639
# Iteration 34: ||Δw|| = 1.912774168
# Iteration 35: ||Δw|| = 1.866923345
# Iteration 36: ||Δw|| = 1.824332629
# Iteration 37: ||Δw|| = 1.784797099
# Iteration 38: ||Δw|| = 1.748008632
# Iteration 39: ||Δw|| = 1.713191767
# Iteration 40: ||Δw|| = 1.680068181
# Iteration 41: ||Δw|| = 1.648575222
# Iteration 42: ||Δw|| = 1.618683122
# Iteration 43: ||Δw|| = 1.590082482
# Iteration 44: ||Δw|| = 1.562664444
# Iteration 45: ||Δw|| = 1.536336325
# Iteration 46: ||Δw|| = 1.511011526
# Iteration 47: ||Δw|| = 1.486779415
# Iteration 48: ||Δw|| = 1.463459914
# Iteration 49: ||Δw|| = 1.441024316
# Iteration 50: ||Δw|| = 1.419352884
# Iteration 51: ||Δw|| = 1.398381127
# Iteration 52: ||Δw|| = 1.378109016
# Iteration 53: ||Δw|| = 1.358481241
# Iteration 54: ||Δw|| = 1.339509518
# Iteration 55: ||Δw|| = 1.321090274
# Iteration 56: ||Δw|| = 1.303212876
# Iteration 57: ||Δw|| = 1.285833569
# Iteration 58: ||Δw|| = 1.268922971
# Iteration 59: ||Δw|| = 1.252453560
# Iteration 60: ||Δw|| = 1.236406326
# Iteration 61: ||Δw|| = 1.220760868
# Iteration 62: ||Δw|| = 1.205557898
# Iteration 63: ||Δw|| = 1.190766775
# Iteration 64: ||Δw|| = 1.176341476
# Iteration 65: ||Δw|| = 1.162217428
# Iteration 66: ||Δw|| = 1.148433360
# Iteration 67: ||Δw|| = 1.134914195
# Iteration 68: ||Δw|| = 1.121624741
# Iteration 69: ||Δw|| = 1.108615126
# Iteration 70: ||Δw|| = 1.095842055
# Iteration 71: ||Δw|| = 1.083314357
# Iteration 72: ||Δw|| = 1.071015729
# Iteration 73: ||Δw|| = 1.058937570
# Iteration 74: ||Δw|| = 1.047053529
# Iteration 75: ||Δw|| = 1.035363492
# Iteration 76: ||Δw|| = 1.023861279
# Iteration 77: ||Δw|| = 1.012536188
# Iteration 78: ||Δw|| = 1.001377778
# Iteration 79: ||Δw|| = 0.990386177
# Iteration 80: ||Δw|| = 0.979596294
# Iteration 81: ||Δw|| = 0.968988007
# Iteration 82: ||Δw|| = 0.958544602
# Iteration 83: ||Δw|| = 0.948253308
# Iteration 84: ||Δw|| = 0.938092403
# Iteration 85: ||Δw|| = 0.928057791
# Iteration 86: ||Δw|| = 0.918141486
# Iteration 87: ||Δw|| = 0.908342012
# Iteration 88: ||Δw|| = 0.898653731
# Iteration 89: ||Δw|| = 0.889071355
# Iteration 90: ||Δw|| = 0.879617569
# Iteration 91: ||Δw|| = 0.870257236
# Iteration 92: ||Δw|| = 0.860989614
# Iteration 93: ||Δw|| = 0.851817243
# Iteration 94: ||Δw|| = 0.842728652
# Iteration 95: ||Δw|| = 0.833729799
# Iteration 96: ||Δw|| = 0.824832046
# Iteration 97: ||Δw|| = 0.816043536
# Iteration 98: ||Δw|| = 0.807330951
# Iteration 99: ||Δw|| = 0.798697761
# Iteration 100: ||Δw|| = 0.790149344
# Iteration 101: ||Δw|| = 0.781667973
# Iteration 102: ||Δw|| = 0.773260486
# Iteration 103: ||Δw|| = 0.764921145
# Iteration 104: ||Δw|| = 0.756647211
# Iteration 105: ||Δw|| = 0.748442284
# Iteration 106: ||Δw|| = 0.740287547
# Iteration 107: ||Δw|| = 0.732192169
# Iteration 108: ||Δw|| = 0.724152650
# Iteration 109: ||Δw|| = 0.716158814
# Iteration 110: ||Δw|| = 0.708201045
# Iteration 111: ||Δw|| = 0.700280559
# Iteration 112: ||Δw|| = 0.692405074
# Iteration 113: ||Δw|| = 0.684574114
# Iteration 114: ||Δw|| = 0.676795726
# Iteration 115: ||Δw|| = 0.669072482
# Iteration 116: ||Δw|| = 0.661385165
# Iteration 117: ||Δw|| = 0.653732418
# Iteration 118: ||Δw|| = 0.646105801
# Iteration 119: ||Δw|| = 0.638516673
# Iteration 120: ||Δw|| = 0.630958100
# Iteration 121: ||Δw|| = 0.623431414
# Iteration 122: ||Δw|| = 0.615929312
# Iteration 123: ||Δw|| = 0.608457767
# Iteration 124: ||Δw|| = 0.601012037
# Iteration 125: ||Δw|| = 0.593592740
# Iteration 126: ||Δw|| = 0.586201427
# Iteration 127: ||Δw|| = 0.578849284
# Iteration 128: ||Δw|| = 0.571548250
# Iteration 129: ||Δw|| = 0.564296963
# Iteration 130: ||Δw|| = 0.557104562
# Iteration 131: ||Δw|| = 0.549969193
# Iteration 132: ||Δw|| = 0.542897945
# Iteration 133: ||Δw|| = 0.535887671
# Iteration 134: ||Δw|| = 0.528942058
# Iteration 135: ||Δw|| = 0.522059285
# Iteration 136: ||Δw|| = 0.515243286
# Iteration 137: ||Δw|| = 0.508499087
# Iteration 138: ||Δw|| = 0.501822195
# Iteration 139: ||Δw|| = 0.495213631
# Iteration 140: ||Δw|| = 0.488670915
# Iteration 141: ||Δw|| = 0.482198947
# Iteration 142: ||Δw|| = 0.475795918
# Iteration 143: ||Δw|| = 0.469462590
# Iteration 144: ||Δw|| = 0.463197597
# Iteration 145: ||Δw|| = 0.457003559
# Iteration 146: ||Δw|| = 0.450877211
# Iteration 147: ||Δw|| = 0.444817824
# Iteration 148: ||Δw|| = 0.438831996
# Iteration 149: ||Δw|| = 0.432919929
# Iteration 150: ||Δw|| = 0.427079319
# Iteration 151: ||Δw|| = 0.421308736
# Iteration 152: ||Δw|| = 0.415615311
# Iteration 153: ||Δw|| = 0.409997476
# Iteration 154: ||Δw|| = 0.404440523
# Iteration 155: ||Δw|| = 0.398952930
# Iteration 156: ||Δw|| = 0.393534577
# Iteration 157: ||Δw|| = 0.388183445
# Iteration 158: ||Δw|| = 0.382899024
# Iteration 159: ||Δw|| = 0.377682339
# Iteration 160: ||Δw|| = 0.372531452
# Iteration 161: ||Δw|| = 0.367447150
# Iteration 162: ||Δw|| = 0.362429375
# Iteration 163: ||Δw|| = 0.357474584
# Iteration 164: ||Δw|| = 0.352587621
# Iteration 165: ||Δw|| = 0.347767233
# Iteration 166: ||Δw|| = 0.343009356
# Iteration 167: ||Δw|| = 0.338313535
# Iteration 168: ||Δw|| = 0.333679865
# Iteration 169: ||Δw|| = 0.329107891
# Iteration 170: ||Δw|| = 0.324593307
# Iteration 171: ||Δw|| = 0.320139887
# Iteration 172: ||Δw|| = 0.315747946
# Iteration 173: ||Δw|| = 0.311416988
# Iteration 174: ||Δw|| = 0.307143603
# Iteration 175: ||Δw|| = 0.302926672
# Iteration 176: ||Δw|| = 0.298764781
# Iteration 177: ||Δw|| = 0.294660451
# Iteration 178: ||Δw|| = 0.290610537
# Iteration 179: ||Δw|| = 0.286612867
# Iteration 180: ||Δw|| = 0.282669959
# Iteration 181: ||Δw|| = 0.278780878
# Iteration 182: ||Δw|| = 0.274944791
# Iteration 183: ||Δw|| = 0.271161705
# Iteration 184: ||Δw|| = 0.267428779
# Iteration 185: ||Δw|| = 0.263748242
# Iteration 186: ||Δw|| = 0.260120024
# Iteration 187: ||Δw|| = 0.256544048
# Iteration 188: ||Δw|| = 0.253018203
# Iteration 189: ||Δw|| = 0.249540924
# Iteration 190: ||Δw|| = 0.246113098
# Iteration 191: ||Δw|| = 0.242734148
# Iteration 192: ||Δw|| = 0.239404399
# Iteration 193: ||Δw|| = 0.236122530
# Iteration 194: ||Δw|| = 0.232885941
# Iteration 195: ||Δw|| = 0.229695529
# Iteration 196: ||Δw|| = 0.226552388
# Iteration 197: ||Δw|| = 0.223456483
# Iteration 198: ||Δw|| = 0.220404458
# Iteration 199: ||Δw|| = 0.217394486
# Iteration 200: ||Δw|| = 0.214425804
# Iteration 201: ||Δw|| = 0.211499723
# Iteration 202: ||Δw|| = 0.208615103
# Iteration 203: ||Δw|| = 0.205771831
# Iteration 204: ||Δw|| = 0.202969063
# Iteration 205: ||Δw|| = 0.200207274
# Iteration 206: ||Δw|| = 0.197485279
# Iteration 207: ||Δw|| = 0.194803667
# Iteration 208: ||Δw|| = 0.192161170
# Iteration 209: ||Δw|| = 0.189557599
# Iteration 210: ||Δw|| = 0.186993102
# Iteration 211: ||Δw|| = 0.184467319
# Iteration 212: ||Δw|| = 0.181979241
# Iteration 213: ||Δw|| = 0.179528050
# Iteration 214: ||Δw|| = 0.177112944
# Iteration 215: ||Δw|| = 0.174735033
# Iteration 216: ||Δw|| = 0.172392985
# Iteration 217: ||Δw|| = 0.170085104
# Iteration 218: ||Δw|| = 0.167812455
# Iteration 219: ||Δw|| = 0.165574512
# Iteration 220: ||Δw|| = 0.163371088
# Iteration 221: ||Δw|| = 0.161201483
# Iteration 222: ||Δw|| = 0.159065368
# Iteration 223: ||Δw|| = 0.156962265
# Iteration 224: ||Δw|| = 0.154892107
# Iteration 225: ||Δw|| = 0.152854047
# Iteration 226: ||Δw|| = 0.150847320
# Iteration 227: ||Δw|| = 0.148871822
# Iteration 228: ||Δw|| = 0.146926659
# Iteration 229: ||Δw|| = 0.145012049
# Iteration 230: ||Δw|| = 0.143126817
# Iteration 231: ||Δw|| = 0.141271238
# Iteration 232: ||Δw|| = 0.139445258
# Iteration 233: ||Δw|| = 0.137647939
# Iteration 234: ||Δw|| = 0.135878931
# Iteration 235: ||Δw|| = 0.134136792
# Iteration 236: ||Δw|| = 0.132422021
# Iteration 237: ||Δw|| = 0.130734198
# Iteration 238: ||Δw|| = 0.129073613
# Iteration 239: ||Δw|| = 0.127438775
# Iteration 240: ||Δw|| = 0.125829584
# Iteration 241: ||Δw|| = 0.124246163
# Iteration 242: ||Δw|| = 0.122688089
# Iteration 243: ||Δw|| = 0.121154951
# Iteration 244: ||Δw|| = 0.119646136
# Iteration 245: ||Δw|| = 0.118161885
# Iteration 246: ||Δw|| = 0.116702366
# Iteration 247: ||Δw|| = 0.115266619
# Iteration 248: ||Δw|| = 0.113855157
# Iteration 249: ||Δw|| = 0.112467480
# Iteration 250: ||Δw|| = 0.111103146
# Iteration 251: ||Δw|| = 0.109761477
# Iteration 252: ||Δw|| = 0.108441871
# Iteration 253: ||Δw|| = 0.107144151
# Iteration 254: ||Δw|| = 0.105868166
# Iteration 255: ||Δw|| = 0.104613501
# Iteration 256: ||Δw|| = 0.103380101
# Iteration 257: ||Δw|| = 0.102167666
# Iteration 258: ||Δw|| = 0.100976015
# Iteration 259: ||Δw|| = 0.099804773
# Iteration 260: ||Δw|| = 0.098653258
# Iteration 261: ||Δw|| = 0.097521325
# Iteration 262: ||Δw|| = 0.096409100
# Iteration 263: ||Δw|| = 0.095316376
# Iteration 264: ||Δw|| = 0.094242656
# Iteration 265: ||Δw|| = 0.093188060
# Iteration 266: ||Δw|| = 0.092151317
# Iteration 267: ||Δw|| = 0.091132537
# Iteration 268: ||Δw|| = 0.090132033
# Iteration 269: ||Δw|| = 0.089149457
# Iteration 270: ||Δw|| = 0.088184171
# Iteration 271: ||Δw|| = 0.087236085
# Iteration 272: ||Δw|| = 0.086305234
# Iteration 273: ||Δw|| = 0.085391079
# Iteration 274: ||Δw|| = 0.084493198
# Iteration 275: ||Δw|| = 0.083611237
# Iteration 276: ||Δw|| = 0.082744900
# Iteration 277: ||Δw|| = 0.081894176
# Iteration 278: ||Δw|| = 0.081059044
# Iteration 279: ||Δw|| = 0.080239087
# Iteration 280: ||Δw|| = 0.079434347
# Iteration 281: ||Δw|| = 0.078644488
# Iteration 282: ||Δw|| = 0.077869389
# Iteration 283: ||Δw|| = 0.077108691
# Iteration 284: ||Δw|| = 0.076361710
# Iteration 285: ||Δw|| = 0.075628172
# Iteration 286: ||Δw|| = 0.074908307
# Iteration 287: ||Δw|| = 0.074201283
# Iteration 288: ||Δw|| = 0.073507555
# Iteration 289: ||Δw|| = 0.072826627
# Iteration 290: ||Δw|| = 0.072157947
# Iteration 291: ||Δw|| = 0.071502194
# Iteration 292: ||Δw|| = 0.070864067
# Iteration 293: ||Δw|| = 0.070237878
# Iteration 294: ||Δw|| = 0.069623065
# Iteration 295: ||Δw|| = 0.069019722
# Iteration 296: ||Δw|| = 0.068427510
# Iteration 297: ||Δw|| = 0.067846212
# Iteration 298: ||Δw|| = 0.067275856
# Iteration 299: ||Δw|| = 0.066716139
# Iteration 300: ||Δw|| = 0.066166769
# Iteration 301: ||Δw|| = 0.065627912
# Iteration 302: ||Δw|| = 0.065099402
# Iteration 303: ||Δw|| = 0.064580832
# Iteration 304: ||Δw|| = 0.064071711
# Iteration 305: ||Δw|| = 0.063572183
# Iteration 306: ||Δw|| = 0.063082183
# Iteration 307: ||Δw|| = 0.062600302
# Iteration 308: ||Δw|| = 0.062127175
# Iteration 309: ||Δw|| = 0.061662817
# Iteration 310: ||Δw|| = 0.061206851
# Iteration 311: ||Δw|| = 0.060760663
# Iteration 312: ||Δw|| = 0.060322861
# Iteration 313: ||Δw|| = 0.059893481
# Iteration 314: ||Δw|| = 0.059471941
# Iteration 315: ||Δw|| = 0.059058100
# Iteration 316: ||Δw|| = 0.058651745
# Iteration 317: ||Δw|| = 0.058252529
# Iteration 318: ||Δw|| = 0.057860594
# Iteration 319: ||Δw|| = 0.057476069
# Iteration 320: ||Δw|| = 0.057098544
# Iteration 321: ||Δw|| = 0.056727983
# Iteration 322: ||Δw|| = 0.056363943
# Iteration 323: ||Δw|| = 0.056006269
# Iteration 324: ||Δw|| = 0.055655394
# Iteration 325: ||Δw|| = 0.055310560
# Iteration 326: ||Δw|| = 0.054972000
# Iteration 327: ||Δw|| = 0.054639709
# Iteration 328: ||Δw|| = 0.054313255
# Iteration 329: ||Δw|| = 0.053991963
# Iteration 330: ||Δw|| = 0.053676162
# Iteration 331: ||Δw|| = 0.053366102
# Iteration 332: ||Δw|| = 0.053061427
# Iteration 333: ||Δw|| = 0.052761982
# Iteration 334: ||Δw|| = 0.052467339
# Iteration 335: ||Δw|| = 0.052177529
# Iteration 336: ||Δw|| = 0.051892685
# Iteration 337: ||Δw|| = 0.051612465
# Iteration 338: ||Δw|| = 0.051337232
# Iteration 339: ||Δw|| = 0.051066351
# Iteration 340: ||Δw|| = 0.050799704
# Iteration 341: ||Δw|| = 0.050537383
# Iteration 342: ||Δw|| = 0.050279028
# Iteration 343: ||Δw|| = 0.050024069
# Iteration 344: ||Δw|| = 0.049772710
# Iteration 345: ||Δw|| = 0.049525055
# Iteration 346: ||Δw|| = 0.049281050
# Iteration 347: ||Δw|| = 0.049040425
# Iteration 348: ||Δw|| = 0.048803251
# Iteration 349: ||Δw|| = 0.048569273
# Iteration 350: ||Δw|| = 0.048337992
# Iteration 351: ||Δw|| = 0.048109745
# Iteration 352: ||Δw|| = 0.047884229
# Iteration 353: ||Δw|| = 0.047660649
# Iteration 354: ||Δw|| = 0.047437421
# Iteration 355: ||Δw|| = 0.047217122
# Iteration 356: ||Δw|| = 0.047000647
# Iteration 357: ||Δw|| = 0.046787528
# Iteration 358: ||Δw|| = 0.046577639
# Iteration 359: ||Δw|| = 0.046370842
# Iteration 360: ||Δw|| = 0.046166847
# Iteration 361: ||Δw|| = 0.045965782
# Iteration 362: ||Δw|| = 0.045767661
# Iteration 363: ||Δw|| = 0.045572604
# Iteration 364: ||Δw|| = 0.045380398
# Iteration 365: ||Δw|| = 0.045191211
# Iteration 366: ||Δw|| = 0.045004668
# Iteration 367: ||Δw|| = 0.044820705
# Iteration 368: ||Δw|| = 0.044639205
# Iteration 369: ||Δw|| = 0.044459879
# Iteration 370: ||Δw|| = 0.044282606
# Iteration 371: ||Δw|| = 0.044107450
# Iteration 372: ||Δw|| = 0.043934516
# Iteration 373: ||Δw|| = 0.043763373
# Iteration 374: ||Δw|| = 0.043593864
# Iteration 375: ||Δw|| = 0.043425990
# Iteration 376: ||Δw|| = 0.043259882
# Iteration 377: ||Δw|| = 0.043095523
# Iteration 378: ||Δw|| = 0.042932648
# Iteration 379: ||Δw|| = 0.042771145
# Iteration 380: ||Δw|| = 0.042611259
# Iteration 381: ||Δw|| = 0.042453079
# Iteration 382: ||Δw|| = 0.042296150
# Iteration 383: ||Δw|| = 0.042140598
# Iteration 384: ||Δw|| = 0.041986357
# Iteration 385: ||Δw|| = 0.041832956
# Iteration 386: ||Δw|| = 0.041680791
# Iteration 387: ||Δw|| = 0.041529694
# Iteration 388: ||Δw|| = 0.041379666
# Iteration 389: ||Δw|| = 0.041231003
# Iteration 390: ||Δw|| = 0.041083227
# Iteration 391: ||Δw|| = 0.040936472
# Iteration 392: ||Δw|| = 0.040790754
# Iteration 393: ||Δw|| = 0.040645303
# Iteration 394: ||Δw|| = 0.040500524
# Iteration 395: ||Δw|| = 0.040356569
# Iteration 396: ||Δw|| = 0.040213392
# Iteration 397: ||Δw|| = 0.040071268
# Iteration 398: ||Δw|| = 0.039929700
# Iteration 399: ||Δw|| = 0.039788574
# Iteration 400: ||Δw|| = 0.039648195
# Iteration 401: ||Δw|| = 0.039508696
# Iteration 402: ||Δw|| = 0.039369946
# Iteration 403: ||Δw|| = 0.039232058
# Iteration 404: ||Δw|| = 0.039094696
# Iteration 405: ||Δw|| = 0.038957701
# Iteration 406: ||Δw|| = 0.038821246
# Iteration 407: ||Δw|| = 0.038685325
# Iteration 408: ||Δw|| = 0.038549932
# Iteration 409: ||Δw|| = 0.038414860
# Iteration 410: ||Δw|| = 0.038280066
# Iteration 411: ||Δw|| = 0.038145613
# Iteration 412: ||Δw|| = 0.038011443
# Iteration 413: ||Δw|| = 0.037877757
# Iteration 414: ||Δw|| = 0.037744525
# Iteration 415: ||Δw|| = 0.037611840
# Iteration 416: ||Δw|| = 0.037479615
# Iteration 417: ||Δw|| = 0.037347181
# Iteration 418: ||Δw|| = 0.037214610
# Iteration 419: ||Δw|| = 0.037082442
# Iteration 420: ||Δw|| = 0.036950390
# Iteration 421: ||Δw|| = 0.036817921
# Iteration 422: ||Δw|| = 0.036685604
# Iteration 423: ||Δw|| = 0.036553268
# Iteration 424: ||Δw|| = 0.036421070
# Iteration 425: ||Δw|| = 0.036288934
# Iteration 426: ||Δw|| = 0.036156898
# Iteration 427: ||Δw|| = 0.036024780
# Iteration 428: ||Δw|| = 0.035892333
# Iteration 429: ||Δw|| = 0.035759783
# Iteration 430: ||Δw|| = 0.035626971
# Iteration 431: ||Δw|| = 0.035494282
# Iteration 432: ||Δw|| = 0.035361768
# Iteration 433: ||Δw|| = 0.035229367
# Iteration 434: ||Δw|| = 0.035096794
# Iteration 435: ||Δw|| = 0.034964356
# Iteration 436: ||Δw|| = 0.034832105
# Iteration 437: ||Δw|| = 0.034699991
# Iteration 438: ||Δw|| = 0.034567528
# Iteration 439: ||Δw|| = 0.034434657
# Iteration 440: ||Δw|| = 0.034301887
# Iteration 441: ||Δw|| = 0.034168914
# Iteration 442: ||Δw|| = 0.034034928
# Iteration 443: ||Δw|| = 0.033900762
# Iteration 444: ||Δw|| = 0.033766229
# Iteration 445: ||Δw|| = 0.033631391
# Iteration 446: ||Δw|| = 0.033496337
# Iteration 447: ||Δw|| = 0.033361121
# Iteration 448: ||Δw|| = 0.033227013
# Iteration 449: ||Δw|| = 0.033094016
# Iteration 450: ||Δw|| = 0.032960547
# Iteration 451: ||Δw|| = 0.032826637
# Iteration 452: ||Δw|| = 0.032690874
# Iteration 453: ||Δw|| = 0.032553040
# Iteration 454: ||Δw|| = 0.032415893
# Iteration 455: ||Δw|| = 0.032279432
# Iteration 456: ||Δw|| = 0.032143168
# Iteration 457: ||Δw|| = 0.032007066
# Iteration 458: ||Δw|| = 0.031871385
# Iteration 459: ||Δw|| = 0.031735937
# Iteration 460: ||Δw|| = 0.031600737
# Iteration 461: ||Δw|| = 0.031465659
# Iteration 462: ||Δw|| = 0.031330708
# Iteration 463: ||Δw|| = 0.031195864
# Iteration 464: ||Δw|| = 0.031061244
# Iteration 465: ||Δw|| = 0.030926800
# Iteration 466: ||Δw|| = 0.030792533
# Iteration 467: ||Δw|| = 0.030658478
# Iteration 468: ||Δw|| = 0.030524819
# Iteration 469: ||Δw|| = 0.030391518
# Iteration 470: ||Δw|| = 0.030258262
# Iteration 471: ||Δw|| = 0.030124796
# Iteration 472: ||Δw|| = 0.029991181
# Iteration 473: ||Δw|| = 0.029857705
# Iteration 474: ||Δw|| = 0.029724293
# Iteration 475: ||Δw|| = 0.029590794
# Iteration 476: ||Δw|| = 0.029457420
# Iteration 477: ||Δw|| = 0.029323941
# Iteration 478: ||Δw|| = 0.029190638
# Iteration 479: ||Δw|| = 0.029057503
# Iteration 480: ||Δw|| = 0.028924453
# Iteration 481: ||Δw|| = 0.028791493
# Iteration 482: ||Δw|| = 0.028658637
# Iteration 483: ||Δw|| = 0.028525820
# Iteration 484: ||Δw|| = 0.028392978
# Iteration 485: ||Δw|| = 0.028260016
# Iteration 486: ||Δw|| = 0.028127092
# Iteration 487: ||Δw|| = 0.027994015
# Iteration 488: ||Δw|| = 0.027860678
# Iteration 489: ||Δw|| = 0.027727510
# Iteration 490: ||Δw|| = 0.027594441
# Iteration 491: ||Δw|| = 0.027461347
# Iteration 492: ||Δw|| = 0.027328313
# Iteration 493: ||Δw|| = 0.027195141
# Iteration 494: ||Δw|| = 0.027061911
# Iteration 495: ||Δw|| = 0.026928525
# Iteration 496: ||Δw|| = 0.026795424
# Iteration 497: ||Δw|| = 0.026662361
# Iteration 498: ||Δw|| = 0.026529403
# Iteration 499: ||Δw|| = 0.026396781
# Iteration 500: ||Δw|| = 0.026264241
# Iteration 501: ||Δw|| = 0.026131800
# Iteration 502: ||Δw|| = 0.025999467
# Iteration 503: ||Δw|| = 0.025867325
# Iteration 504: ||Δw|| = 0.025735152
# Iteration 505: ||Δw|| = 0.025604703
# Iteration 506: ||Δw|| = 0.025474648
# Iteration 507: ||Δw|| = 0.025344438
# Iteration 508: ||Δw|| = 0.025214387
# Iteration 509: ||Δw|| = 0.025084354
# Iteration 510: ||Δw|| = 0.024954280
# Iteration 511: ||Δw|| = 0.024824201
# Iteration 512: ||Δw|| = 0.024694110
# Iteration 513: ||Δw|| = 0.024563875
# Iteration 514: ||Δw|| = 0.024434385
# Iteration 515: ||Δw|| = 0.024305371
# Iteration 516: ||Δw|| = 0.024176267
# Iteration 517: ||Δw|| = 0.024047140
# Iteration 518: ||Δw|| = 0.023917796
# Iteration 519: ||Δw|| = 0.023788332
# Iteration 520: ||Δw|| = 0.023658903
# Iteration 521: ||Δw|| = 0.023529512
# Iteration 522: ||Δw|| = 0.023400050
# Iteration 523: ||Δw|| = 0.023270790
# Iteration 524: ||Δw|| = 0.023141611
# Iteration 525: ||Δw|| = 0.023012259
# Iteration 526: ||Δw|| = 0.022883149
# Iteration 527: ||Δw|| = 0.022754249
# Iteration 528: ||Δw|| = 0.022625115
# Iteration 529: ||Δw|| = 0.022496070
# Iteration 530: ||Δw|| = 0.022367025
# Iteration 531: ||Δw|| = 0.022238113
# Iteration 532: ||Δw|| = 0.022109326
# Iteration 533: ||Δw|| = 0.021980767
# Iteration 534: ||Δw|| = 0.021852330
# Iteration 535: ||Δw|| = 0.021724048
# Iteration 536: ||Δw|| = 0.021595957
# Iteration 537: ||Δw|| = 0.021467929
# Iteration 538: ||Δw|| = 0.021339908
# Iteration 539: ||Δw|| = 0.021211878
# Iteration 540: ||Δw|| = 0.021084062
# Iteration 541: ||Δw|| = 0.020956293
# Iteration 542: ||Δw|| = 0.020828696
# Iteration 543: ||Δw|| = 0.020701319
# Iteration 544: ||Δw|| = 0.020574012
# Iteration 545: ||Δw|| = 0.020446791
# Iteration 546: ||Δw|| = 0.020319723
# Iteration 547: ||Δw|| = 0.020192776
# Iteration 548: ||Δw|| = 0.020066073
# Iteration 549: ||Δw|| = 0.019939483
# Iteration 550: ||Δw|| = 0.019812971
# Iteration 551: ||Δw|| = 0.019686542
# Iteration 552: ||Δw|| = 0.019560109
# Iteration 553: ||Δw|| = 0.019433946
# Iteration 554: ||Δw|| = 0.019308184
# Iteration 555: ||Δw|| = 0.019182730
# Iteration 556: ||Δw|| = 0.019057538
# Iteration 557: ||Δw|| = 0.018932513
# Iteration 558: ||Δw|| = 0.018807580
# Iteration 559: ||Δw|| = 0.018682942
# Iteration 560: ||Δw|| = 0.018558534
# Iteration 561: ||Δw|| = 0.018434320
# Iteration 562: ||Δw|| = 0.018310319
# Iteration 563: ||Δw|| = 0.018187865
# Iteration 564: ||Δw|| = 0.018065628
# Iteration 565: ||Δw|| = 0.017943415
# Iteration 566: ||Δw|| = 0.017821313
# Iteration 567: ||Δw|| = 0.017699214
# Iteration 568: ||Δw|| = 0.017577367
# Iteration 569: ||Δw|| = 0.017455732
# Iteration 570: ||Δw|| = 0.017334291
# Iteration 571: ||Δw|| = 0.017213117
# Iteration 572: ||Δw|| = 0.017092429
# Iteration 573: ||Δw|| = 0.016972068
# Iteration 574: ||Δw|| = 0.016851918
# Iteration 575: ||Δw|| = 0.016731939
# Iteration 576: ||Δw|| = 0.016612087
# Iteration 577: ||Δw|| = 0.016492561
# Iteration 578: ||Δw|| = 0.016373345
# Iteration 579: ||Δw|| = 0.016254280
# Iteration 580: ||Δw|| = 0.016135448
# Iteration 581: ||Δw|| = 0.016016825
# Iteration 582: ||Δw|| = 0.015898449
# Iteration 583: ||Δw|| = 0.015780355
# Iteration 584: ||Δw|| = 0.015662584
# Iteration 585: ||Δw|| = 0.015544997
# Iteration 586: ||Δw|| = 0.015427596
# Iteration 587: ||Δw|| = 0.015310281
# Iteration 588: ||Δw|| = 0.015193089
# Iteration 589: ||Δw|| = 0.015075910
# Iteration 590: ||Δw|| = 0.014958669
# Iteration 591: ||Δw|| = 0.014841598
# Iteration 592: ||Δw|| = 0.014724539
# Iteration 593: ||Δw|| = 0.014607316
# Iteration 594: ||Δw|| = 0.014488929
# Iteration 595: ||Δw|| = 0.014371015
# Iteration 596: ||Δw|| = 0.014253743
# Iteration 597: ||Δw|| = 0.014137260
# Iteration 598: ||Δw|| = 0.014021453
# Iteration 599: ||Δw|| = 0.013906228
# Iteration 600: ||Δw|| = 0.013791675
# Iteration 601: ||Δw|| = 0.013677794
# Iteration 602: ||Δw|| = 0.013564330
# Iteration 603: ||Δw|| = 0.013451427
# Iteration 604: ||Δw|| = 0.013339108
# Iteration 605: ||Δw|| = 0.013227422
# Iteration 606: ||Δw|| = 0.013116429
# Iteration 607: ||Δw|| = 0.013006065
# Iteration 608: ||Δw|| = 0.012896327
# Iteration 609: ||Δw|| = 0.012787111
# Iteration 610: ||Δw|| = 0.012678444
# Iteration 611: ||Δw|| = 0.012570291
# Iteration 612: ||Δw|| = 0.012462660
# Iteration 613: ||Δw|| = 0.012355567
# Iteration 614: ||Δw|| = 0.012249024
# Iteration 615: ||Δw|| = 0.012143017
# Iteration 616: ||Δw|| = 0.012037406
# Iteration 617: ||Δw|| = 0.011932336
# Iteration 618: ||Δw|| = 0.011827835
# Iteration 619: ||Δw|| = 0.011723883
# Iteration 620: ||Δw|| = 0.011620492
# Iteration 621: ||Δw|| = 0.011517642
# Iteration 622: ||Δw|| = 0.011415327
# Iteration 623: ||Δw|| = 0.011313451
# Iteration 624: ||Δw|| = 0.011212126
# Iteration 625: ||Δw|| = 0.011111323
# Iteration 626: ||Δw|| = 0.011011044
# Iteration 627: ||Δw|| = 0.010911281
# Iteration 628: ||Δw|| = 0.010812045
# Iteration 629: ||Δw|| = 0.010713334
# Iteration 630: ||Δw|| = 0.010615199
# Iteration 631: ||Δw|| = 0.010517592
# Iteration 632: ||Δw|| = 0.010420478
# Iteration 633: ||Δw|| = 0.010323900
# Iteration 634: ||Δw|| = 0.010227848
# Iteration 635: ||Δw|| = 0.010132274
# Iteration 636: ||Δw|| = 0.010037140
# Iteration 637: ||Δw|| = 0.009942519
# Iteration 638: ||Δw|| = 0.009848457
# Iteration 639: ||Δw|| = 0.009754906
# Iteration 640: ||Δw|| = 0.009661831
# Iteration 641: ||Δw|| = 0.009569254
# Iteration 642: ||Δw|| = 0.009477125
# Iteration 643: ||Δw|| = 0.009385535
# Iteration 644: ||Δw|| = 0.009294505
# Iteration 645: ||Δw|| = 0.009204015
# Iteration 646: ||Δw|| = 0.009114019
# Iteration 647: ||Δw|| = 0.009024392
# Iteration 648: ||Δw|| = 0.008935301
# Iteration 649: ||Δw|| = 0.008846783
# Iteration 650: ||Δw|| = 0.008758809
# Iteration 651: ||Δw|| = 0.008671260
# Iteration 652: ||Δw|| = 0.008584189
# Iteration 653: ||Δw|| = 0.008497624
# Iteration 654: ||Δw|| = 0.008411573
# Iteration 655: ||Δw|| = 0.008326033
# Iteration 656: ||Δw|| = 0.008241029
# Iteration 657: ||Δw|| = 0.008156541
# Iteration 658: ||Δw|| = 0.008072566
# Iteration 659: ||Δw|| = 0.007989124
# Iteration 660: ||Δw|| = 0.007906268
# Iteration 661: ||Δw|| = 0.007823999
# Iteration 662: ||Δw|| = 0.007742261
# Iteration 663: ||Δw|| = 0.007660995
# Iteration 664: ||Δw|| = 0.007580158
# Iteration 665: ||Δw|| = 0.007499789
# Iteration 666: ||Δw|| = 0.007419989
# Iteration 667: ||Δw|| = 0.007340705
# Iteration 668: ||Δw|| = 0.007261852
# Iteration 669: ||Δw|| = 0.007183542
# Iteration 670: ||Δw|| = 0.007105771
# Iteration 671: ||Δw|| = 0.007028548
# Iteration 672: ||Δw|| = 0.006951902
# Iteration 673: ||Δw|| = 0.006875784
# Iteration 674: ||Δw|| = 0.006800194
# Iteration 675: ||Δw|| = 0.006725165
# Iteration 676: ||Δw|| = 0.006650706
# Iteration 677: ||Δw|| = 0.006576773
# Iteration 678: ||Δw|| = 0.006503381
# Iteration 679: ||Δw|| = 0.006430557
# Iteration 680: ||Δw|| = 0.006358167
# Iteration 681: ||Δw|| = 0.006286359
# Iteration 682: ||Δw|| = 0.006215102
# Iteration 683: ||Δw|| = 0.006144390
# Iteration 684: ||Δw|| = 0.006074246
# Iteration 685: ||Δw|| = 0.006004680
# Iteration 686: ||Δw|| = 0.005935648
# Iteration 687: ||Δw|| = 0.005867134
# Iteration 688: ||Δw|| = 0.005799143
# Iteration 689: ||Δw|| = 0.005731746
# Iteration 690: ||Δw|| = 0.005664803
# Iteration 691: ||Δw|| = 0.005598397
# Iteration 692: ||Δw|| = 0.005532542
# Iteration 693: ||Δw|| = 0.005467271
# Iteration 694: ||Δw|| = 0.005402601
# Iteration 695: ||Δw|| = 0.005338519
# Iteration 696: ||Δw|| = 0.005275045
# Iteration 697: ||Δw|| = 0.005212112
# Iteration 698: ||Δw|| = 0.005149758
# Iteration 699: ||Δw|| = 0.005087987
# Iteration 700: ||Δw|| = 0.005026795
# Iteration 701: ||Δw|| = 0.004966114
# Iteration 702: ||Δw|| = 0.004906019
# Iteration 703: ||Δw|| = 0.004846432
# Iteration 704: ||Δw|| = 0.004787422
# Iteration 705: ||Δw|| = 0.004729006
# Iteration 706: ||Δw|| = 0.004671199
# Iteration 707: ||Δw|| = 0.004613999
# Iteration 708: ||Δw|| = 0.004557362
# Iteration 709: ||Δw|| = 0.004501331
# Iteration 710: ||Δw|| = 0.004445887
# Iteration 711: ||Δw|| = 0.004391029
# Iteration 712: ||Δw|| = 0.004336769
# Iteration 713: ||Δw|| = 0.004283087
# Iteration 714: ||Δw|| = 0.004230010
# Iteration 715: ||Δw|| = 0.004177560
# Iteration 716: ||Δw|| = 0.004125712
# Iteration 717: ||Δw|| = 0.004074471
# Iteration 718: ||Δw|| = 0.004023834
# Iteration 719: ||Δw|| = 0.003973816
# Iteration 720: ||Δw|| = 0.003924393
# Iteration 721: ||Δw|| = 0.003875576
# Iteration 722: ||Δw|| = 0.003827364
# Iteration 723: ||Δw|| = 0.003779772
# Iteration 724: ||Δw|| = 0.003732799
# Iteration 725: ||Δw|| = 0.003686431
# Iteration 726: ||Δw|| = 0.003640684
# Iteration 727: ||Δw|| = 0.003595551
# Iteration 728: ||Δw|| = 0.003551038
# Iteration 729: ||Δw|| = 0.003507158
# Iteration 730: ||Δw|| = 0.003463907
# Iteration 731: ||Δw|| = 0.003421284
# Iteration 732: ||Δw|| = 0.003379268
# Iteration 733: ||Δw|| = 0.003337863
# Iteration 734: ||Δw|| = 0.003297077
# Iteration 735: ||Δw|| = 0.003256912
# Iteration 736: ||Δw|| = 0.003217377
# Iteration 737: ||Δw|| = 0.003178481
# Iteration 738: ||Δw|| = 0.003140228
# Iteration 739: ||Δw|| = 0.003102621
# Iteration 740: ||Δw|| = 0.003065659
# Iteration 741: ||Δw|| = 0.003029321
# Iteration 742: ||Δw|| = 0.002993563
# Iteration 743: ||Δw|| = 0.002958452
# Iteration 744: ||Δw|| = 0.002924002
# Iteration 745: ||Δw|| = 0.002890203
# Iteration 746: ||Δw|| = 0.002857053
# Iteration 747: ||Δw|| = 0.002824547
# Iteration 748: ||Δw|| = 0.002792677
# Iteration 749: ||Δw|| = 0.002761426
# Iteration 750: ||Δw|| = 0.002730830
# Iteration 751: ||Δw|| = 0.002700893
# Iteration 752: ||Δw|| = 0.002671615
# Iteration 753: ||Δw|| = 0.002642997
# Iteration 754: ||Δw|| = 0.002615036
# Iteration 755: ||Δw|| = 0.002587712
# Iteration 756: ||Δw|| = 0.002561050
# Iteration 757: ||Δw|| = 0.002535043
# Iteration 758: ||Δw|| = 0.002509684
# Iteration 759: ||Δw|| = 0.002484970
# Iteration 760: ||Δw|| = 0.002460907
# Iteration 761: ||Δw|| = 0.002437486
# Iteration 762: ||Δw|| = 0.002414710
# Iteration 763: ||Δw|| = 0.002392571
# Iteration 764: ||Δw|| = 0.002371064
# Iteration 765: ||Δw|| = 0.002350188
# Iteration 766: ||Δw|| = 0.002329944
# Iteration 767: ||Δw|| = 0.002310322
# Iteration 768: ||Δw|| = 0.002291321
# Iteration 769: ||Δw|| = 0.002272933
# Iteration 770: ||Δw|| = 0.002255158
# Iteration 771: ||Δw|| = 0.002237995
# Iteration 772: ||Δw|| = 0.002221433
# Iteration 773: ||Δw|| = 0.002205467
# Iteration 774: ||Δw|| = 0.002190092
# Iteration 775: ||Δw|| = 0.002175293
# Iteration 776: ||Δw|| = 0.002161070
# Iteration 777: ||Δw|| = 0.002147417
# Iteration 778: ||Δw|| = 0.002134319
# Iteration 779: ||Δw|| = 0.002121779
# Iteration 780: ||Δw|| = 0.002109783
# Iteration 781: ||Δw|| = 0.002098315
# Iteration 782: ||Δw|| = 0.002087373
# Iteration 783: ||Δw|| = 0.002076951
# Iteration 784: ||Δw|| = 0.002067039
# Iteration 785: ||Δw|| = 0.002057628
# Iteration 786: ||Δw|| = 0.002048708
# Iteration 787: ||Δw|| = 0.002040270
# Iteration 788: ||Δw|| = 0.002032303
# Iteration 789: ||Δw|| = 0.002024795
# Iteration 790: ||Δw|| = 0.002017737
# Iteration 791: ||Δw|| = 0.002011119
# Iteration 792: ||Δw|| = 0.002004927
# Iteration 793: ||Δw|| = 0.001999148
# Iteration 794: ||Δw|| = 0.001993780
# Iteration 795: ||Δw|| = 0.001988806
# Iteration 796: ||Δw|| = 0.001984215
# Iteration 797: ||Δw|| = 0.001979996
# Iteration 798: ||Δw|| = 0.001976140
# Iteration 799: ||Δw|| = 0.001972630
# Iteration 800: ||Δw|| = 0.001969457
# Iteration 801: ||Δw|| = 0.001966613
# Iteration 802: ||Δw|| = 0.001964085
# Iteration 803: ||Δw|| = 0.001961861
# Iteration 804: ||Δw|| = 0.001959929
# Iteration 805: ||Δw|| = 0.001958278
# Iteration 806: ||Δw|| = 0.001956898
# Iteration 807: ||Δw|| = 0.001955776
# Iteration 808: ||Δw|| = 0.001954900
# Iteration 809: ||Δw|| = 0.001954260
# Iteration 810: ||Δw|| = 0.001953848
# Iteration 811: ||Δw|| = 0.001953653
# Iteration 812: ||Δw|| = 0.001953665
# Iteration 813: ||Δw|| = 0.001953872
# Iteration 814: ||Δw|| = 0.001954266
# Iteration 815: ||Δw|| = 0.001954838
# Iteration 816: ||Δw|| = 0.001955578
# Iteration 817: ||Δw|| = 0.001956476
# Iteration 818: ||Δw|| = 0.001957524
# Iteration 819: ||Δw|| = 0.001958712
# Iteration 820: ||Δw|| = 0.001960030
# Iteration 821: ||Δw|| = 0.001961471
# Iteration 822: ||Δw|| = 0.001963027
# Iteration 823: ||Δw|| = 0.001964687
# Iteration 824: ||Δw|| = 0.001966445
# Iteration 825: ||Δw|| = 0.001968293
# Iteration 826: ||Δw|| = 0.001970225
# Iteration 827: ||Δw|| = 0.001972233
# Iteration 828: ||Δw|| = 0.001974309
# Iteration 829: ||Δw|| = 0.001976448
# Iteration 830: ||Δw|| = 0.001978642
# Iteration 831: ||Δw|| = 0.001980885
# Iteration 832: ||Δw|| = 0.001983169
# Iteration 833: ||Δw|| = 0.001985490
# Iteration 834: ||Δw|| = 0.001987841
# Iteration 835: ||Δw|| = 0.001990214
# Iteration 836: ||Δw|| = 0.001992606
# Iteration 837: ||Δw|| = 0.001995011
# Iteration 838: ||Δw|| = 0.001997425
# Iteration 839: ||Δw|| = 0.001999842
# Iteration 840: ||Δw|| = 0.002002258
# Iteration 841: ||Δw|| = 0.002004667
# Iteration 842: ||Δw|| = 0.002007068
# Iteration 843: ||Δw|| = 0.002009453
# Iteration 844: ||Δw|| = 0.002011820
# Iteration 845: ||Δw|| = 0.002014162
# Iteration 846: ||Δw|| = 0.002016477
# Iteration 847: ||Δw|| = 0.002018763
# Iteration 848: ||Δw|| = 0.002021014
# Iteration 849: ||Δw|| = 0.002023227
# Iteration 850: ||Δw|| = 0.002025400
# Iteration 851: ||Δw|| = 0.002027529
# Iteration 852: ||Δw|| = 0.002029612
# Iteration 853: ||Δw|| = 0.002031644
# Iteration 854: ||Δw|| = 0.002033625
# Iteration 855: ||Δw|| = 0.002035551
# Iteration 856: ||Δw|| = 0.002037420
# Iteration 857: ||Δw|| = 0.002039230
# Iteration 858: ||Δw|| = 0.002040978
# Iteration 859: ||Δw|| = 0.002042663
# Iteration 860: ||Δw|| = 0.002044284
# Iteration 861: ||Δw|| = 0.002045837
# Iteration 862: ||Δw|| = 0.002047320
# Iteration 863: ||Δw|| = 0.002048732
# Iteration 864: ||Δw|| = 0.002050070
# Iteration 865: ||Δw|| = 0.002051334
# Iteration 866: ||Δw|| = 0.002052520
# Iteration 867: ||Δw|| = 0.002053629
# Iteration 868: ||Δw|| = 0.002054659
# Iteration 869: ||Δw|| = 0.002055611
# Iteration 870: ||Δw|| = 0.002056481
# Iteration 871: ||Δw|| = 0.002057269
# Iteration 872: ||Δw|| = 0.002057975
# Iteration 873: ||Δw|| = 0.002058599
# Iteration 874: ||Δw|| = 0.002059138
# Iteration 875: ||Δw|| = 0.002059591
# Iteration 876: ||Δw|| = 0.002059959
# Iteration 877: ||Δw|| = 0.002060239
# Iteration 878: ||Δw|| = 0.002060433
# Iteration 879: ||Δw|| = 0.002060538
# Iteration 880: ||Δw|| = 0.002060555
# Iteration 881: ||Δw|| = 0.002060484
# Iteration 882: ||Δw|| = 0.002060323
# Iteration 883: ||Δw|| = 0.002060074
# Iteration 884: ||Δw|| = 0.002059734
# Iteration 885: ||Δw|| = 0.002059305
# Iteration 886: ||Δw|| = 0.002058785
# Iteration 887: ||Δw|| = 0.002058176
# Iteration 888: ||Δw|| = 0.002057477
# Iteration 889: ||Δw|| = 0.002056686
# Iteration 890: ||Δw|| = 0.002055805
# Iteration 891: ||Δw|| = 0.002054834
# Iteration 892: ||Δw|| = 0.002053773
# Iteration 893: ||Δw|| = 0.002052621
# Iteration 894: ||Δw|| = 0.002051378
# Iteration 895: ||Δw|| = 0.002050046
# Iteration 896: ||Δw|| = 0.002048624
# Iteration 897: ||Δw|| = 0.002047112
# Iteration 898: ||Δw|| = 0.002045510
# Iteration 899: ||Δw|| = 0.002043820
# Iteration 900: ||Δw|| = 0.002042041
# Iteration 901: ||Δw|| = 0.002040174
# Iteration 902: ||Δw|| = 0.002038218
# Iteration 903: ||Δw|| = 0.002036174
# Iteration 904: ||Δw|| = 0.002034043
# Iteration 905: ||Δw|| = 0.002031824
# Iteration 906: ||Δw|| = 0.002029517
# Iteration 907: ||Δw|| = 0.002027125
# Iteration 908: ||Δw|| = 0.002024646
# Iteration 909: ||Δw|| = 0.002022082
# Iteration 910: ||Δw|| = 0.002019434
# Iteration 911: ||Δw|| = 0.002016701
# Iteration 912: ||Δw|| = 0.002013883
# Iteration 913: ||Δw|| = 0.002010982
# Iteration 914: ||Δw|| = 0.002007998
# Iteration 915: ||Δw|| = 0.002004932
# Iteration 916: ||Δw|| = 0.002001784
# Iteration 917: ||Δw|| = 0.001998555
# Iteration 918: ||Δw|| = 0.001995245
# Iteration 919: ||Δw|| = 0.001991855
# Iteration 920: ||Δw|| = 0.001988386
# Iteration 921: ||Δw|| = 0.001984838
# Iteration 922: ||Δw|| = 0.001981211
# Iteration 923: ||Δw|| = 0.001977507
# Iteration 924: ||Δw|| = 0.001973726
# Iteration 925: ||Δw|| = 0.001969870
# Iteration 926: ||Δw|| = 0.001965937
# Iteration 927: ||Δw|| = 0.001961930
# Iteration 928: ||Δw|| = 0.001957851
# Iteration 929: ||Δw|| = 0.001953698
# Iteration 930: ||Δw|| = 0.001949474
# Iteration 931: ||Δw|| = 0.001945178
# Iteration 932: ||Δw|| = 0.001940811
# Iteration 933: ||Δw|| = 0.001936374
# Iteration 934: ||Δw|| = 0.001931867
# Iteration 935: ||Δw|| = 0.001927291
# Iteration 936: ||Δw|| = 0.001922647
# Iteration 937: ||Δw|| = 0.001917937
# Iteration 938: ||Δw|| = 0.001913159
# Iteration 939: ||Δw|| = 0.001908317
# Iteration 940: ||Δw|| = 0.001903410
# Iteration 941: ||Δw|| = 0.001898441
# Iteration 942: ||Δw|| = 0.001893409
# Iteration 943: ||Δw|| = 0.001888314
# Iteration 944: ||Δw|| = 0.001883157
# Iteration 945: ||Δw|| = 0.001877940
# Iteration 946: ||Δw|| = 0.001872663
# Iteration 947: ||Δw|| = 0.001867327
# Iteration 948: ||Δw|| = 0.001861932
# Iteration 949: ||Δw|| = 0.001856481
# Iteration 950: ||Δw|| = 0.001850973
# Iteration 951: ||Δw|| = 0.001845411
# Iteration 952: ||Δw|| = 0.001839794
# Iteration 953: ||Δw|| = 0.001834118
# Iteration 954: ||Δw|| = 0.001828393
# Iteration 955: ||Δw|| = 0.001822615
# Iteration 956: ||Δw|| = 0.001816785
# Iteration 957: ||Δw|| = 0.001810902
# Iteration 958: ||Δw|| = 0.001804969
# Iteration 959: ||Δw|| = 0.001798985
# Iteration 960: ||Δw|| = 0.001792953
# Iteration 961: ||Δw|| = 0.001786874
# Iteration 962: ||Δw|| = 0.001780747
# Iteration 963: ||Δw|| = 0.001774572
# Iteration 964: ||Δw|| = 0.001768351
# Iteration 965: ||Δw|| = 0.001762086
# Iteration 966: ||Δw|| = 0.001755776
# Iteration 967: ||Δw|| = 0.001749424
# Iteration 968: ||Δw|| = 0.001743028
# Iteration 969: ||Δw|| = 0.001736591
# Iteration 970: ||Δw|| = 0.001730120
# Iteration 971: ||Δw|| = 0.001723611
# Iteration 972: ||Δw|| = 0.001717060
# Iteration 973: ||Δw|| = 0.001710469
# Iteration 974: ||Δw|| = 0.001703838
# Iteration 975: ||Δw|| = 0.001697168
# Iteration 976: ||Δw|| = 0.001690463
# Iteration 977: ||Δw|| = 0.001683723
# Iteration 978: ||Δw|| = 0.001676948
# Iteration 979: ||Δw|| = 0.001670138
# Iteration 980: ||Δw|| = 0.001663295
# Iteration 981: ||Δw|| = 0.001656419
# Iteration 982: ||Δw|| = 0.001649511
# Iteration 983: ||Δw|| = 0.001642571
# Iteration 984: ||Δw|| = 0.001635601
# Iteration 985: ||Δw|| = 0.001628600
# Iteration 986: ||Δw|| = 0.001621571
# Iteration 987: ||Δw|| = 0.001614513
# Iteration 988: ||Δw|| = 0.001607428
# Iteration 989: ||Δw|| = 0.001600316
# Iteration 990: ||Δw|| = 0.001593177
# Iteration 991: ||Δw|| = 0.001586013
# Iteration 992: ||Δw|| = 0.001578823
# Iteration 993: ||Δw|| = 0.001571609
# Iteration 994: ||Δw|| = 0.001564371
# Iteration 995: ||Δw|| = 0.001557110
# Iteration 996: ||Δw|| = 0.001549826
# Iteration 997: ||Δw|| = 0.001542523
# Iteration 998: ||Δw|| = 0.001535197
# Iteration 999: ||Δw|| = 0.001527852
# q-value at 0: 7.180015508445556
# Option price: 5.398069720716529
# array([5.39806972])

# %%
K = sampler.strike
T = sampler.time_grid[-1]
r = -np.log(sampler.discount_factor[0, 1] / sampler.discount_factor[0, 0]) / sampler.time_deltas[0]
n_paths, n_times, _ = sampler.markov_state.shape
gamma = np.exp(-r * sampler.time_deltas[0])
S_paths = sampler.markov_state[:, :, 0]
time_grid_expanded = np.tile(sampler.time_grid, (n_paths, 1))
phi_all_raw = pricer._basis_functions_raw(S_paths, K, time_grid_expanded, T)
phi_all = pricer._scale_features(phi_all_raw, fit=True)

phi_curr = phi_all[:, :-1, :]  # Текущие состояния (t)
phi_next = phi_all[:, 1:, :]   # Следующие состояния (t+1)
payoff = sampler.payoff
payoff_next = sampler.payoff[:, 1:]  # Выплаты в t+1

# Выравнивание в 1D
n_features = phi_all.shape[-1]
phi_all_flat = phi_all.reshape(-1, n_features)
phi_curr_flat = phi_curr.reshape(-1, n_features)
phi_next_flat = phi_next.reshape(-1, n_features)
payoff_flat = payoff.reshape(-1)
payoff_next_flat = payoff_next.reshape(-1)

# %%
def bellman_opt_eq(phi_curr, phi_next, payoff_next, w, gamma, w_next=None):
    if w_next is None:
        w_next = w
    return ((
        phi_curr @ w - 
        gamma * np.max(
            np.concat([
                payoff_next[np.newaxis], 
                (phi_next @ w_next)[np.newaxis] \
                    * np.array(
                        (([1] * (n_times - 2)) + [0]) * n_paths
                    )
            ]), 
            axis=0
        )
    ) ** 2).mean()

# %%
bellman_opt_eq(
    phi_curr_flat, 
    phi_next_flat, 
    payoff_next_flat, 
    pricer.w, 
    gamma
)
# Out:
# np.float64(0.26417768710019124)

# %%
bellman_opt_eq(
    phi_curr_flat, 
    phi_next_flat, 
    payoff_next_flat, 
    pricer.w * 0.99, 
    gamma
)
# Out:
# np.float64(0.2603730748973656)

# %%
bellman_opt_eq(
    phi_curr_flat, 
    phi_next_flat, 
    payoff_next_flat, 
    pricer.w * 0.99, 
    gamma,
    pricer.w
)
# Out:
# np.float64(0.2738952623566142)

# %%
def price(phi_all, n_paths, payoff, w, gamma):
    pv_payoffs = np.zeros(n_paths)
    for p in range(n_paths):
        for t in range(n_times):
            phi_t = phi_all[p, t]
            Q_cont = phi_t @ w
            payoff_t = payoff[p, t]
            
            disc_factor = gamma**t
            if payoff_t >= Q_cont or t == n_times - 1:
                pv_payoffs[p] = disc_factor * payoff_t
                break
    return pv_payoffs.mean()

# %%
price(
    phi_all,
    n_paths, 
    sampler.payoff,
    pricer.w,
    gamma
)
# Out:
# np.float64(5.643907275958466)

# %%
price(
    phi_all,
    n_paths, 
    sampler.payoff,
    pricer.w * 0.99,
    gamma
)
# Out:
# np.float64(6.005314630688348)

# %%
import numpy as np
from numba import njit

@njit
def spread_with_gamma(arr, gamma):
    result = np.zeros_like(arr)
    rows, cols = np.where(np.abs(arr) > 1e-6)
    
    for i, j in zip(rows, cols):
        if arr[i, j] == 0:
            continue
            
        # Создаем диапазон для влияния
        k_values = np.arange(j + 1)
        powers = j - k_values
        influences = (gamma ** powers) * arr[i, j]
        
        # Находим позиции, которые еще не заполнены
        target_pos = k_values[result[i, k_values] == 0]
        result[i, target_pos] = influences[target_pos]
        
        # Обнуляем где power == 0
        result[i, j] = 0
        
    return result

# %%
a = np.array([
    [0, 0, 0, 1, 0, 0],
    [0,1,0,3,0,0]
])
gamma = 2

# %%
spread_with_gamma(a, gamma)

# %%
from copy import deepcopy
import numpy as np
from typing import Optional
from sklearn.preprocessing import StandardScaler
from src.pricers.abstract_pricer import PricerAbstract
from src.samplers.abstract_sampler import SamplerAbstract


import numpy as np
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from tqdm.auto import tqdm
import matplotlib.pyplot as plt

# %%
from src.samplers.geometric_brownian_motion_put_sampler import GeometricBrownianMotionPutSampler
sampler = GeometricBrownianMotionPutSampler(**{
    "asset0": 100.0,
    "sigma": 0.2,
    "r": 0.05,
    "strike": 100.0,
    "t": 1.0,
    "cnt_times": 60,
    "seed": None, 
    "cnt_trajectories": 1_000_000
})

# %% [markdown]
# # LSPI

# %%
from dataclasses import dataclass
@dataclass 
class A:
    _: int

self = A(0)

def _create_features(self, markov_state: np.ndarray, time_grid: np.ndarray) -> np.ndarray:
    n_paths, n_times, state_dim = markov_state.shape
    T = time_grid[-1]
    
    # Нормализованное время до экспирации
    time_to_exp = (T - time_grid) / T
    time_to_exp = np.tile(time_to_exp, (n_paths, 1))[..., None]
    
    # Объединяем время и состояние
    features = np.concatenate([time_to_exp, markov_state], axis=-1)
    flat_features = features.reshape(-1, features.shape[-1])
    
    # Первый вызов - инициализируем и фитим трансформеры
    if not self.is_fitted_:
        self.scaler_ = StandardScaler()
        self.poly_ = PolynomialFeatures(degree=self.degree, include_bias=True)
        
        scaled = self.scaler_.fit_transform(flat_features)
        poly_features = self.poly_.fit_transform(scaled)
        self.n_features_ = poly_features.shape[1]
        self.is_fitted_ = True
    else:
        # Используем обученные трансформеры
        scaled = self.scaler_.transform(flat_features)
        poly_features = self.poly_.transform(scaled)
    
    return poly_features.reshape(n_paths, n_times, -1)

def _create_features(self, markov_state: np.ndarray, time_grid: np.ndarray) -> np.ndarray:
    M = markov_state[:, :, 0] / 100.
    exp_term = np.exp(-M / 2.0)
    T = time_grid[-1]
    t = time_grid

    phi = np.zeros((*markov_state[:, :, 0].shape, 7), dtype = float)
    phi[:, :, 0] = 1.0
    phi[:, :, 1] = exp_term
    phi[:, :, 2] = exp_term * (1.0 - M)
    phi[:, :, 3] = exp_term * (1.0 - 2.0 * M + 0.5 * M * M)
    phi[:, :, 4] = np.sin(np.pi * (T - t) / (2.0 * T))
    phi[:, :, 5] = np.log(np.maximum(T - t, 1e-10)) # 1e-10 чтобы не было log(0)
    phi[:, :, 6] = (t / T) ** 2

    scaler = StandardScaler()
    phi_reshaped = phi[:, :, 1:].reshape(-1, 6)
    phi_scaled = scaler.fit_transform(phi_reshaped)
    phi_scaled = phi_scaled.reshape(phi.shape[0], phi.shape[1], 6)


    phi_final = np.zeros_like(phi)
    phi_final[:, :, 0] = phi[:, :, 0]
    phi_final[:, :, 1:] = phi_scaled

    return phi_final

# %%
self.sampler = sampler
self.sampler.sample()

# %%
r = -np.log(self.sampler.discount_factor[0, 1] / self.sampler.discount_factor[0, 0]) / (self.sampler.time_deltas[0])
self.dt = sampler.time_deltas[0]
self.is_fitted_ = False
self.degree = 3
self.iterations = 100
self.tol = 1e-6
self.reg_alpha = 1e-2
quiet = False

# %%
# Параметры
n_paths, n_times, _ = self.sampler.markov_state.shape
gamma = np.exp(-r * self.dt)  # Коэффициент дисконтирования

# Создаем признаки
phi_all = _create_features(self,
    self.sampler.markov_state, 
    self.sampler.time_grid
)
n_features = phi_all.shape[-1]


w = np.zeros(n_features)

# Подготовка данных
phi_curr = phi_all[:, :-1, :]  # Текущие состояния (t)
phi_next = phi_all[:, 1:, :]    # Следующие состояния (t+1)
payoff_next = self.sampler.payoff[:, 1:]  # Выплаты в t+1

# Выравнивание в 1D
phi_curr_flat = phi_curr.reshape(-1, n_features)
phi_next_flat = phi_next.reshape(-1, n_features)
payoff_next_flat = payoff_next.reshape(-1)

# Флаг нетерминальных состояний
non_terminal = np.tile(
    np.arange(n_times-1, dtype=int) < n_times-2, 
    (n_paths, 1)
)
non_terminal_flat = non_terminal.reshape(-1)

# Итерации LSPI
for it in tqdm(range(self.iterations), desc="LSPI iterations"):
    prev_w = deepcopy(w)
    
    # Вычисляем Q-значения продолжения
    Q_cont_next = phi_next_flat @ w
    
    # Условие продолжения
    continue_cond = non_terminal_flat & (Q_cont_next >= payoff_next_flat)
    
    # Формируем систему уравнений
    diff_phi = phi_curr_flat - gamma * continue_cond[:, None] * phi_next_flat
    A = phi_curr_flat.T @ diff_phi
    b = gamma * phi_curr_flat.T @ ((~continue_cond) * payoff_next_flat)

    if self.reg_alpha is not None:
        A += np.eye(A.shape[0]) * self.reg_alpha
    w = np.linalg.solve(A, b)
    
    # Проверка сходимости
    diff_norm = np.linalg.norm(w - prev_w)
    if not quiet:
        print(f"Iteration {it}: ||Δw|| = {diff_norm:.9f}")
    if diff_norm < self.tol:
        if not quiet:
            print(f"Converged after {it} iterations")
        break

self.w = w

# %%
pv_payoffs = np.zeros(n_paths)
for p in range(n_paths):
    for t in range(n_times):
        # Признаки текущего состояния
        phi_t = phi_all[p, t]
        Q_cont = phi_t @ w
        payoff_t = self.sampler.payoff[p, t]
        
        # Условие исполнения
        if payoff_t >= Q_cont or t == n_times - 1:
            disc_factor = self.sampler.discount_factor[p, t]
            pv_payoffs[p] = disc_factor * payoff_t
            break
mean = pv_payoffs.mean()

plt.figure(figsize=(10, 6))
plt.hist(pv_payoffs)
plt.axvline(mean)
plt.title("Train")
plt.grid()
plt.show()
mean

# %%
self.sampler.sample()

# %%
phi_all = _create_features(self,
    self.sampler.markov_state, 
    self.sampler.time_grid
)
pv_payoffs = np.zeros(n_paths)
for p in range(n_paths):
    for t in range(n_times):
        # Признаки текущего состояния
        phi_t = phi_all[p, t]
        Q_cont = phi_t @ w
        payoff_t = self.sampler.payoff[p, t]
        
        # Условие исполнения
        if payoff_t >= Q_cont or t == n_times - 1:
            disc_factor = self.sampler.discount_factor[p, t]
            pv_payoffs[p] = disc_factor * payoff_t
            break
mean = pv_payoffs.mean()

plt.figure(figsize=(10, 6))
plt.hist(pv_payoffs)
plt.axvline(mean)
plt.title("Test")
plt.grid()
plt.show()
mean

# %%
n_traj = 10

plt.figure(figsize=(10, 6))
plt.plot(self.sampler.time_grid, self.sampler.payoff[:n_traj, :].T)
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(self.sampler.time_grid, (self.sampler.payoff[:, :] * self.sampler.discount_factor)[:n_traj, :].T)
plt.show()

# %% [markdown]
# # LSMC

# %%
from src.pricers.american_monte_carlo import AmericanMonteCarloPricer
pricer = AmericanMonteCarloPricer(sampler, degree=3)
pricer.price();
pricer.result

# %%
import scipy
exercise_boundary_lsmc = []
for i, t in tqdm(list(
    enumerate(sampler.time_grid)
)):
    if pricer.weights[i] is None:
        print("None")
        exercise_boundary_lsmc.append(None)
        continue

    func_to_find_root = lambda x: (
        sampler.discount_factor[0, i] * max(0, 100. - x) - 
        (
            pricer.basis_functions_transformer.transform(
                pricer.scalers[i].transform([[x]])
            ) @ pricer.weights[i]
        ).reshape(-1)[0]
    )

    root = scipy.optimize.minimize_scalar(
        lambda x: func_to_find_root(x)**2,
        bounds=[np.percentile(sampler.markov_state[:, i, 0], 0.99), 100]
    )["x"]
    
    if abs(func_to_find_root(root)) < 1e-6:
        exercise_boundary_lsmc.append(
            root
        )
    else:
        exercise_boundary_lsmc.append(
            None
        )

    payoff = np.vectorize(lambda x: sampler.discount_factor[0, i] * max(0, 100. - x))
    continuation_value = np.vectorize(lambda x: (
        pricer.basis_functions_transformer.transform(
            pricer.scalers[i].transform([[x]])
        ) @ pricer.weights[i]
    ).reshape(-1)[0])
    plt.figure(figsize=(10, 6))
    plt.title(f"Continuation value at t={t}")
    grid = np.linspace(np.percentile(sampler.markov_state[:, i, 0], 0.99), 100, 30)
    plt.plot(grid, continuation_value(grid), label="CV")
    plt.plot(grid, payoff(grid), label="Payoff")
    plt.legend()
    plt.grid()
    plt.show()

plt.figure(figsize=(10, 6))
plt.plot(sampler.time_grid, exercise_boundary_lsmc, "-o", markersize=2)
plt.show()

# %%
exercise_boundary_lsmc

# %%
sampler.discount_factor[0, i]

# %%
exercise_boundary_lsmc

# %%
# import scipy
# exercise_boundary_lsmc = []
# for i, t in tqdm(list(enumerate(range(len(sampler.time_grid))))):
#     if pricer.weights[i] is None:
#         exercise_boundary_lsmc.append(None)
#         continue
#     exercise_boundary_lsmc.append(
#         scipy.optimize.minimize_scalar(
#             lambda x: (
#                 sampler.discount_factor[0, i] * max(0, 100. - x) - 
#                 (
#                     pricer.basis_functions_transformer.transform([[x]]) @ pricer.weights[i]
#                 ).reshape(-1)[0]
#             )**2,
#             bounds=[0, 100]
#         )["x"]
#     )

# plt.figure(figsize=(10, 6))
# plt.plot(sampler.time_grid, exercise_boundary_lsmc)
# plt.show()

# %%
pricer.weights
