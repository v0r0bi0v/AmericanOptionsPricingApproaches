# %%
import numpy as np
from sys import path

path.append('src/')
from samplers import WienerRainbowPutOptionSampler, GeometricBrownianMotionPutSampler
from american_monte_carlo import PricerAmericanMonteCarlo
from basis_functions import PolynomialTransformer
import matplotlib.pyplot as plt
from BinomialTree import price_gbm_put

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Rainbow Wiener 2-dimensional

# %%
sampler = WienerRainbowPutOptionSampler(
    cnt_trajectories=1_000_000,
    cnt_times=3,
    t=1,
    time_grid = None,
    seed = 345,
    sigmas = [1., 1.],
    strike=0.
)

sampler.sample()
# Out:
#   0%|          | 0/1000000 [00:00<?, ?it/s]
#   0%|          | 0/1000000 [00:00<?, ?it/s]

# %%
sampler.plot(100)

# %%
in_the_money_indices = np.where(sampler.payoff[:, 1] > 1e-9)[0]
len(in_the_money_indices)
# Out:
# 749942

# %%
features = sampler.markov_state[in_the_money_indices, 1]
transformed = PolynomialTransformer(5).fit_transform(features)
transformed.shape
# Out:
# (749942, 21)

# %%
regularization = np.eye(transformed.shape[1], dtype=float) * 0.
inv = np.linalg.pinv((transformed.T @ transformed + regularization), rcond=1e-4)
weights = inv @ transformed.T @ sampler.payoff[in_the_money_indices, 2]
continuation_value = transformed @ weights

# %%
indicator = (continuation_value < sampler.payoff[in_the_money_indices, 1])
indicator.sum()
# Out:
# 1109

# %%
plt.hist(continuation_value - sampler.payoff[in_the_money_indices, 1], bins=100);
plt.grid()

# %%
amc = PricerAmericanMonteCarlo(
    sampler=WienerRainbowPutOptionSampler(
        cnt_trajectories=1_000_000,
        cnt_times=30,
        t=1,
        time_grid = None,
        seed = 345,
        sigmas = [1., 1.],
        strike=0.
    ),
    regularization_alpha=1e-4
)

# %%
amc.price(
    test=False,
    quiet=False
)
# Out:
#   0%|          | 0/1000000 [00:00<?, ?it/s]
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# /home/sasamb4ikk/sber/AmericanOptionsPricingApproaches/src/abstracts.py:45: UserWarning: We cannot plot >=2d processes
#   warnings.warn("We cannot plot >=2d processes")
#   0%|          | 0/29 [00:00<?, ?it/s]
# Time step: 28
# Time step: 27
# Time step: 26
# Time step: 25
# Time step: 24
# Time step: 23
# Time step: 22
# Time step: 21
# Time step: 20
#  28%|##7       | 8/29 [00:02<00:04,  4.21it/s]
# Time step: 19
# Time step: 18
# Time step: 17
# Time step: 16
# Time step: 15
# Time step: 14
# Time step: 13
# Time step: 12
# Time step: 11
# Time step: 10
#  62%|######2   | 18/29 [00:04<00:02,  4.13it/s]
# Time step: 9
# Time step: 8
# Time step: 7
# Time step: 6
# Time step: 5
# Time step: 4
# Time step: 3
# Time step: 2
# Time step: 1
# Time step: 0
#  97%|#########6| 28/29 [00:06<00:00,  4.66it/s]
# /home/sasamb4ikk/sber/AmericanOptionsPricingApproaches/src/abstracts.py:45: UserWarning: We cannot plot >=2d processes
#   warnings.warn("We cannot plot >=2d processes")
# [0.6671358834608613,
#  0.6671358834608613,
#  0.6671358834608613,
#  0.6671358834608613,
#  0.6671358834608613,
#  0.6671358834608613,
#  0.6671358834608613,
#  0.6671358834608613,
#  0.6671358834608613,
#  0.6671358834608613,
#  0.6671358834608613,
#  0.6671358834608613,
#  0.6671792240298596,
#  0.6673425494011413,
#  0.6676819501670815,
#  0.6681452995747887,
#  0.6687523379716842,
#  0.6695771152492019,
#  0.6704850159081243,
#  0.6716333867156102,
#  0.673040587452447,
#  0.6741430865010946,
#  0.6753764764514661,
#  0.6766592511411483,
#  0.6779137611946875,
#  0.6789973450308103,
#  0.6799350323396819,
#  0.6807266695725499,
#  0.6812867533798435,
#  0.6814759882666009]

# %%
amc.price(
    test=True,
    quiet=False
)
# Out:
#   0%|          | 0/1000000 [00:00<?, ?it/s]
#   0%|          | 0/1000000 [00:00<?, ?it/s]
#   0%|          | 0/29 [00:00<?, ?it/s]
# Time step: 28
# Time step: 27
# Time step: 26
# Time step: 25
# Time step: 24
# Time step: 23
# Time step: 22
# Time step: 21
# Time step: 20
# Time step: 19
# Time step: 18
# Time step: 17
# Time step: 16
# Time step: 15
# Time step: 14
# Time step: 13
# Time step: 12
# Time step: 11
# Time step: 10
# Time step: 9
# Time step: 8
# Time step: 7
# Time step: 6
# Time step: 5
# Time step: 4
# Time step: 3
# Time step: 2
# Time step: 1
# Time step: 0
#  66%|######5   | 19/29 [00:00<00:00, 91.23it/s]
# [0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767,
#  0.6820534005572767]

# %% [markdown]
# # Тесты AMC (Одномерный) vs Tree

# %%
import numpy as np
from sys import path

path.append('src/')
from samplers import WienerRainbowPutOptionSampler, GeometricBrownianMotionPutSampler
from american_monte_carlo import PricerAmericanMonteCarlo
from basis_functions import PolynomialTransformer
import matplotlib.pyplot as plt
from BinomialTree import price_gbm_put

# %%
option_params = {
    "asset0": 100.,
    "sigma": 0.1,
    "r": 0.5,
    "strike": 100.,
    "t": 1
}

# %%
EPSILON = 1e-1

# %% [markdown]
# #### Варьируем `r (mu)`

# %%
r_linspace = np.linspace(0, 1, num = 15)

# %%
nums = len(r_linspace)

nrows = 5
ncols = 3  
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(15, 25))
axes = axes.flatten()

for idx, r_val in enumerate(r_linspace):
    option_params["r"] = r_val
    
    amc = PricerAmericanMonteCarlo(
        sampler=GeometricBrownianMotionPutSampler(
            cnt_trajectories=1_000_000,
            cnt_times=200,
            seed=345,
            **option_params
        ),
        regularization_alpha=1e-3
    )

    ax = axes[idx]
    amc.price(test=False, quiet=False, ax=ax)  # Передаём ax в метод price
    ax.set_title(f"r = {r_val:.4f}")

plt.tight_layout()
plt.show()
# Out:
#  99%|#########9| 198/199 [00:11<00:00, 18.43it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 22
#      11     amc = PricerAmericanMonteCarlo(
#      12         sampler=GeometricBrownianMotionPutSampler(
#      13             cnt_trajectories=1_000_000,
#    (...)
#      18         regularization_alpha=1e-3
#      19     )
#      21     ax = axes[idx]
# ---> 22     amc.price(test=False, quiet=False)
#      24     ax.set_title(f"r = {r_val:.4f}")
#      26 plt.tight_layout()
#
# File ~/sber/AmericanOptionsPricingApproaches/src/american_monte_carlo.py:47, in PricerAmericanMonteCarlo.price(self, test, quiet)
#      46 def price(self, test=False, quiet=False):
# ---> 47     self.sampler.sample()
#      48     # if not quiet:
#      49         # self.sampler.plot(cnt=10, plot_mean=True, y="payoff, discount_factor, markov_state")
#      51     discounted_payoff = self.sampler.payoff * self.sampler.discount_factor
#
# File ~/sber/AmericanOptionsPricingApproaches/src/samplers.py:41, in GeometricBrownianMotionPutSampler.sample(self)
#      40 def sample(self) -> None:
# ---> 41     normals = self.random_state.normal(0, 1, (self.cnt_trajectories, self.cnt_times - 1))
#      42     self.markov_state = np.zeros((self.cnt_trajectories, self.cnt_times, 1), dtype=float)
#      43     self.markov_state[:, 0, 0] = self.asset0
#
# KeyboardInterrupt:

# %% [markdown]
# при варьировании `r` дереву нужно больше шагов, чтобы нормально приблизить цену. иногда дерево просто её зануляет, как например сейчас при `cnt_times = 100`, но если поставить `cnt_times = 200`, то уже всё будет ок

# %%
def run_value_grid(value_name, value_grid, times_counter):
    for value in value_grid:
        option_params[value_name] = value
    
        amc = PricerAmericanMonteCarlo(
        sampler = GeometricBrownianMotionPutSampler(
        cnt_trajectories = 1_000_000,
        cnt_times = times_counter,
        seed = 345,
        **option_params
        ), regularization_alpha = 1e-3)

        cashflows, tree_price_history = price_gbm_put(**option_params, cnt_times = times_counter)

        amc.price(test = False, quiet=False)

        print(f"AMC: {amc.price_history[0]} vs Tree: {tree_price_history[0]}")
        print(f"{value_name} = {value:.3f}, совпадает ли с предиктом дерева {np.abs(np.subtract(amc.price_history[0], tree_price_history[0])) < EPSILON}")
        print()

# %% [markdown]
# ### Sigma

# %%
sigma_grid = np.linspace(0.1, 2, num = 10)
CNT_TIMES = 100

# %%
run_value_grid("sigma", sigma_grid, times_counter = CNT_TIMES)
# Out:
#   0%|          | 0/99 [00:00<?, ?it/s]
#   0%|          | 0/99 [00:00<?, ?it/s]
# AMC: 0.3204194527868515 vs Tree: 0.29337317724566897
# sigma = 0.100, совпадает ли с предиктом дерева True
#   0%|          | 0/99 [00:00<?, ?it/s]
#   0%|          | 0/99 [00:00<?, ?it/s]
# AMC: 3.294076906327421 vs Tree: 3.2885654495701395
# sigma = 0.311, совпадает ли с предиктом дерева True
#   0%|          | 0/99 [00:00<?, ?it/s]
#   0%|          | 0/99 [00:00<?, ?it/s]
# AMC: 8.23694589705064 vs Tree: 8.232584022410279
# sigma = 0.522, совпадает ли с предиктом дерева True
#   0%|          | 0/99 [00:00<?, ?it/s]
#   0%|          | 0/99 [00:00<?, ?it/s]
# AMC: 13.966951459504864 vs Tree: 13.956015207468536
# sigma = 0.733, совпадает ли с предиктом дерева True
#   0%|          | 0/99 [00:00<?, ?it/s]
#   0%|          | 0/99 [00:00<?, ?it/s]
# AMC: 19.963080047700256 vs Tree: 19.97072966160143
# sigma = 0.944, совпадает ли с предиктом дерева True
#   0%|          | 0/99 [00:00<?, ?it/s]
#   0%|          | 0/99 [00:00<?, ?it/s]
# AMC: 25.977413950341578 vs Tree: 25.93508332597537
# sigma = 1.156, совпадает ли с предиктом дерева True
#   0%|          | 0/99 [00:00<?, ?it/s]
#   0%|          | 0/99 [00:00<?, ?it/s]
# AMC: 31.86346917140781 vs Tree: 31.72825140439927
# sigma = 1.367, совпадает ли с предиктом дерева False
#   0%|          | 0/99 [00:00<?, ?it/s]
#   0%|          | 0/99 [00:00<?, ?it/s]
# AMC: 37.51033214150478 vs Tree: 37.29690483538323
# sigma = 1.578, совпадает ли с предиктом дерева False
#   0%|          | 0/99 [00:00<?, ?it/s]
#   0%|          | 0/99 [00:00<?, ?it/s]
# AMC: 42.84732208414342 vs Tree: 42.608939972321984
# sigma = 1.789, совпадает ли с предиктом дерева False
#   0%|          | 0/99 [00:00<?, ?it/s]
#   0%|          | 0/99 [00:00<?, ?it/s]
# AMC: 47.82185427275815 vs Tree: 47.51805277677689
# sigma = 2.000, совпадает ли с предиктом дерева False

# %% [markdown]
# если увеличить `cnt_times`, то при бОльших значениях волатильности предикты дерева и AMC будут ближе

# %% [markdown]
# ### Время до истечения опциона

# %%
time_grid = np.linspace(0.1, 5, num = 10)

# %%
run_value_grid("t", time_grid, times_counter = CNT_TIMES)
# Out:
#   0%|          | 0/99 [00:00<?, ?it/s]
#   0%|          | 0/99 [00:00<?, ?it/s]
# AMC: 22.556232678708675 vs Tree: 22.43677449781529
# t = 0.100, совпадает ли с предиктом дерева False
#   0%|          | 0/99 [00:00<?, ?it/s]
#   0%|          | 0/99 [00:00<?, ?it/s]
# AMC: 43.57082803094603 vs Tree: 43.31889907115473
# t = 0.644, совпадает ли с предиктом дерева False
#   0%|          | 0/99 [00:00<?, ?it/s]
#   0%|          | 0/99 [00:00<?, ?it/s]
# AMC: 49.17515012070628 vs Tree: 48.87587928586455
# t = 1.189, совпадает ли с предиктом дерева False
#   0%|          | 0/99 [00:00<?, ?it/s]
#   0%|          | 0/99 [00:00<?, ?it/s]
# AMC: 51.36584518476889 vs Tree: 51.0783635793728
# t = 1.733, совпадает ли с предиктом дерева False
#   0%|          | 0/99 [00:00<?, ?it/s]
#   0%|          | 0/99 [00:00<?, ?it/s]
# AMC: 52.31914946825958 vs Tree: 52.01667793334971
# t = 2.278, совпадает ли с предиктом дерева False
#   0%|          | 0/99 [00:00<?, ?it/s]
#   0%|          | 0/99 [00:00<?, ?it/s]
# AMC: 52.74771594604471 vs Tree: 52.46403356074682
# t = 2.822, совпадает ли с предиктом дерева False
#   0%|          | 0/99 [00:00<?, ?it/s]
#   0%|          | 0/99 [00:00<?, ?it/s]
# AMC: 52.933171051620135 vs Tree: 52.64158106085959
# t = 3.367, совпадает ли с предиктом дерева False
#   0%|          | 0/99 [00:00<?, ?it/s]
#   0%|          | 0/99 [00:00<?, ?it/s]
# AMC: 52.99987837239853 vs Tree: 52.678098988987664
# t = 3.911, совпадает ли с предиктом дерева False
#   0%|          | 0/99 [00:00<?, ?it/s]
#   0%|          | 0/99 [00:00<?, ?it/s]
# AMC: 53.006643196755014 vs Tree: 52.700442793528474
# t = 4.456, совпадает ли с предиктом дерева False
#   0%|          | 0/99 [00:00<?, ?it/s]
#   0%|          | 0/99 [00:00<?, ?it/s]
# AMC: 52.98474486952363 vs Tree: 52.65539603407513
# t = 5.000, совпадает ли с предиктом дерева False

# %% [markdown]
# тоже в целом всё ок, если увеличить `cnt_times` то будем ближе

# %% [markdown]
# # Многомерный AMC

# %% [markdown]
# # ============================================ ОТСЕЧКА ==========================================

# %%
EPSILON
# Out:
# 0.1

# %%
amc.price(
    test=True,
    quiet=False
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 amc.price(
#       2     test=True,
#       3     quiet=False
#       4 )
#
# NameError: name 'amc' is not defined

# %%
# попробуе
