# %%
import numpy as np
from sys import path

path.append('../src')
from samplers import WienerRainbowPutOptionSampler, GeometricBrownianMotionPutSampler
from american_monte_carlo import AmericanMonteCarlo
from basis_functions import PolynomialTransformer
import matplotlib.pyplot as plt
from BinomialTree import price_gbm_put

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Rainbow Wiener 2-dimensional

# %%
sampler=WienerRainbowPutOptionSampler(
    cnt_trajectories=1_000_000,
    cnt_times=3,
    t=1,
    time_grid = None,
    seed = 345,
    sigmas = [1., 1.],
    strike=0.
)

sampler.sample()
# Out:
#   0%|          | 0/1000000 [00:00<?, ?it/s]
#   0%|          | 0/1000000 [00:00<?, ?it/s]

# %%
sampler.plot(100)

# %%
in_the_money_indices = np.where(sampler.payoff[:, 1] > 1e-9)[0]
len(in_the_money_indices)
# Out:
# 749942

# %%
features = sampler.markov_state[in_the_money_indices, 1]
transformed = PolynomialTransformer(5).fit_transform(features)
transformed.shape
# Out:
# (749942, 21)

# %%
regularization = np.eye(transformed.shape[1], dtype=float) * 0.
inv = np.linalg.pinv((transformed.T @ transformed + regularization), rcond=1e-4)
weights = inv @ transformed.T @ sampler.payoff[in_the_money_indices, 2]
continuation_value = transformed @ weights

# %%
indicator = (continuation_value < sampler.payoff[in_the_money_indices, 1])
indicator.sum()
# Out:
# 1109

# %%
plt.hist(continuation_value - sampler.payoff[in_the_money_indices, 1], bins=100);
plt.grid()

# %%
amc = AmericanMonteCarlo(
    sampler=WienerRainbowPutOptionSampler(
        cnt_trajectories=1_000_000,
        cnt_times=30,
        t=1,
        time_grid = None,
        seed = 345,
        sigmas = [1., 1.],
        strike=0.
    ),
    basis_functions_transformer=PolynomialTransformer(5),
    regularization_alpha=1e-4
)

# %%
amc.price(
    test=False,
    quiet=False
)
# Out:
#  97%|#########6| 28/29 [00:10<00:00,  2.92it/s]
# {'train': {'price': 0.6726677702910059,
#   'upper_bound': 1.0260844712464028,
#   'lower_bound': 0.6814759882665884,
#   'std': 0.5707386605200597}}

# %%
amc.price(
    test=True,
    quiet=False
)
# Out:
#  55%|#####5    | 16/29 [00:00<00:00, 154.41it/s]
# {'train': {'price': 0.6726677702910059,
#   'upper_bound': 1.0260844712464028,
#   'lower_bound': 0.6814759882665884,
#   'std': 0.5707386605200597},
#  'test': {'price': 0.6820534005572767,
#   'upper_bound': 1.0256895886908652,
#   'lower_bound': 0.6820534005572845,
#   'std': 0.667582621357676}}

# %% [markdown]
# # GBM put

# %%
option_params = {
    "asset0": 100.,
    "sigma": 0.1,
    "mu": 0.,
    "strike": 100.,
    "t": 1
}

# %% [markdown]
# ## Tree

# %%
cashflows, price_history = price_gbm_put(
    **option_params,
    cnt_times=8
)
# Out:
# [ 0.          0.          0.          2.09467081  7.67715887 14.39885301
#  20.63116476]
# [ 0.          0.          1.04733069  4.88590228 11.03799081 17.51499486]
# [ 0.          0.52366299  2.96660785  7.9619327  14.27647827]
# [ 0.26183032  1.74512992  5.46425904 11.11919128]
# [1.00347678 3.60468611 8.29171243]
# [2.30407559 5.94818873]
# [4.12612396]

# %%
plt.plot(price_history)

# %% [markdown]
# ## AMC

# %%
amc = AmericanMonteCarlo(
    sampler = GeometricBrownianMotionPutSampler(
        cnt_trajectories = 1_000_000,
        cnt_times = 30,
        seed = 345,
        **option_params
    ),
    basis_functions_transformer = PolynomialTransformer(4),
    regularization_alpha = 0.
)

# %%
amc.price(
    test=False,
    quiet=False
)
# Out:
#  97%|#########6| 28/29 [00:01<00:00, 15.38it/s]
# {'train': {'price': 3.391174668919148,
#   'upper_bound': 6.7941851284208035,
#   'lower_bound': 3.9894743134363355,
#   'std': 2.9628717792218677}}

# %%
amc.price(
    test=True,
    quiet=False
)
# Out:
#  59%|#####8    | 17/29 [00:00<00:00, 167.21it/s]
# {'train': {'price': 3.391174668919148,
#   'upper_bound': 6.7941851284208035,
#   'lower_bound': 3.9894743134363355,
#   'std': 2.9628717792218677},
#  'test': {'price': 3.9891347390864493,
#   'upper_bound': 6.79849225001401,
#   'lower_bound': 3.9891347390865186,
#   'std': 5.5149107477890205}}
